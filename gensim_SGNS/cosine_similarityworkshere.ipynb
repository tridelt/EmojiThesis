# %%
from __future__ import absolute_import, division, print_function

# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from numpy  import array
from scipy import stats

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
corpus_filename = '../data/extracted_emoji_sequences.txt'

# %%
corpus = open(corpus_filename).read().splitlines()

# %%
def tokenize_corpus(corpus):
    tokens = [x.split() for x in corpus]
    return tokens

# %%
def onlyEmojiSequences(tokens):
    threshold_emojis = [x for x in tokens if len(x) > 1]
    return threshold_emojis

# %%
tokenized_corpus = tokenize_corpus(corpus)
emojiSequences = onlyEmojiSequences(tokenized_corpus)

# %%
token_count = sum([len(sentence) for sentence in emojiSequences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 610,256 tokens

# %% [markdown]
# # training the model

# %%
# Dimensionality of the resulting word vectors.
num_features = 300

# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 2

# Downsample setting for frequent words.
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
seed = 1

# think of how to set those variables so that variables from different tweets are not learned from together!

# %%
thrones2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(emojiSequences)
# Out:
# 2019-01-14 10:15:48,439 : INFO : collecting all words and their counts
# 2019-01-14 10:15:48,440 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-01-14 10:15:48,447 : INFO : PROGRESS: at sentence #10000, processed 26070 words, keeping 818 word types
# 2019-01-14 10:15:48,455 : INFO : PROGRESS: at sentence #20000, processed 52738 words, keeping 935 word types
# 2019-01-14 10:15:48,463 : INFO : PROGRESS: at sentence #30000, processed 80617 words, keeping 993 word types
# 2019-01-14 10:15:48,472 : INFO : PROGRESS: at sentence #40000, processed 106997 words, keeping 1019 word types
# 2019-01-14 10:15:48,481 : INFO : PROGRESS: at sentence #50000, processed 134684 words, keeping 1038 word types
# 2019-01-14 10:15:48,490 : INFO : PROGRESS: at sentence #60000, processed 161638 words, keeping 1053 word types
# 2019-01-14 10:15:48,499 : INFO : PROGRESS: at sentence #70000, processed 189166 words, keeping 1065 word types
# 2019-01-14 10:15:48,513 : INFO : PROGRESS: at sentence #80000, processed 216247 words, keeping 1071 word types
# 2019-01-14 10:15:48,522 : INFO : PROGRESS: at sentence #90000, processed 242719 words, keeping 1086 word types
# 2019-01-14 10:15:48,531 : INFO : PROGRESS: at sentence #100000, processed 270352 words, keeping 1090 word types
# 2019-01-14 10:15:48,540 : INFO : PROGRESS: at sentence #110000, processed 297903 words, keeping 1114 word types
# 2019-01-14 10:15:48,548 : INFO : PROGRESS: at sentence #120000, processed 325655 words, keeping 1120 word types
# 2019-01-14 10:15:48,556 : INFO : PROGRESS: at sentence #130000, processed 353170 words, keeping 1130 word types
# 2019-01-14 10:15:48,564 : INFO : PROGRESS: at sentence #140000, processed 380910 words, keeping 1139 word types
# 2019-01-14 10:15:48,572 : INFO : PROGRESS: at sentence #150000, processed 408180 words, keeping 1142 word types
# 2019-01-14 10:15:48,579 : INFO : PROGRESS: at sentence #160000, processed 435571 words, keeping 1148 word types
# 2019-01-14 10:15:48,586 : INFO : PROGRESS: at sentence #170000, processed 463321 words, keeping 1150 word types
# 2019-01-14 10:15:48,594 : INFO : PROGRESS: at sentence #180000, processed 490214 words, keeping 1152 word types
# 2019-01-14 10:15:48,601 : INFO : PROGRESS: at sentence #190000, processed 516726 words, keeping 1156 word types
# 2019-01-14 10:15:48,609 : INFO : PROGRESS: at sentence #200000, processed 542786 words, keeping 1157 word types
# 2019-01-14 10:15:48,616 : INFO : PROGRESS: at sentence #210000, processed 568495 words, keeping 1158 word types
# 2019-01-14 10:15:48,623 : INFO : PROGRESS: at sentence #220000, processed 596239 words, keeping 1158 word types
# 2019-01-14 10:15:48,627 : INFO : collected 1158 word types from a corpus of 610256 raw words and 225292 sentences
# 2019-01-14 10:15:48,628 : INFO : Loading a fresh vocabulary
# 2019-01-14 10:15:48,634 : INFO : min_count=3 retains 1082 unique words (93% of original 1158, drops 76)
# 2019-01-14 10:15:48,635 : INFO : min_count=3 leaves 610147 word corpus (99% of original 610256, drops 109)
# 2019-01-14 10:15:48,638 : INFO : deleting the raw counts dictionary of 1158 items
# 2019-01-14 10:15:48,639 : INFO : sample=0.001 downsamples 83 most-common words
# 2019-01-14 10:15:48,639 : INFO : downsampling leaves estimated 388892 word corpus (63.7% of prior 610147)
# 2019-01-14 10:15:48,641 : INFO : estimated required memory for 1082 words and 300 dimensions: 3137800 bytes
# 2019-01-14 10:15:48,642 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 1082

# %%
thrones2vec.wv.vocab
# Out:
# {'⚠': <gensim.models.keyedvectors.Vocab at 0x1a1db612b0>,
#  '😀': <gensim.models.keyedvectors.Vocab at 0x1a1f1bbe48>,
#  '🎷': <gensim.models.keyedvectors.Vocab at 0x1a1f1b59e8>,
#  '🙌': <gensim.models.keyedvectors.Vocab at 0x1a1f2bacf8>,
#  '💐': <gensim.models.keyedvectors.Vocab at 0x1a1f2bacc0>,
#  '🌈': <gensim.models.keyedvectors.Vocab at 0x1a1f2bad30>,
#  '🍸': <gensim.models.keyedvectors.Vocab at 0x1a1f2ba358>,
#  '🎶': <gensim.models.keyedvectors.Vocab at 0x1a1f2ba828>,
#  '💜': <gensim.models.keyedvectors.Vocab at 0x1a1f2ba668>,
#  '🌼': <gensim.models.keyedvectors.Vocab at 0x1a1f2ba6d8>,
#  '💛': <gensim.models.keyedvectors.Vocab at 0x1a1f2ba278>,
#  '❤': <gensim.models.keyedvectors.Vocab at 0x1a1f2bad68>,
#  '☮': <gensim.models.keyedvectors.Vocab at 0x1a1f2babe0>,
#  '✨': <gensim.models.keyedvectors.Vocab at 0x1a1f2ba908>,
#  '🏕': <gensim.models.keyedvectors.Vocab at 0x1a1f2bac88>,
#  '💖': <gensim.models.keyedvectors.Vocab at 0x1a1f2baf28>,
#  '🌤': <gensim.models.keyedvectors.Vocab at 0x1a1f2ba4e0>,
#  '🌸': <gensim.models.keyedvectors.Vocab at 0x1a1f2bae80>,
#  '🌷': <gensim.models.keyedvectors.Vocab at 0x1a288f20f0>,
#  '\u200d': <gensim.models.keyedvectors.Vocab at 0x1a288f20b8>,
#  '🏔': <gensim.models.keyedvectors.Vocab at 0x1a288f2048>,
#  '️': <gensim.models.keyedvectors.Vocab at 0x1a288f2128>,
#  '🍀': <gensim.models.keyedvectors.Vocab at 0x1a288f2160>,
#  '🌎': <gensim.models.keyedvectors.Vocab at 0x1a288f2198>,
#  '🥀': <gensim.models.keyedvectors.Vocab at 0x1a288f21d0>,
#  '🌱': <gensim.models.keyedvectors.Vocab at 0x1a288f2208>,
#  '🌳': <gensim.models.keyedvectors.Vocab at 0x1a288f2240>,
#  '🚴': <gensim.models.keyedvectors.Vocab at 0x1a288f2278>,
#  '🌻': <gensim.models.keyedvectors.Vocab at 0x1a288f22b0>,
#  '♀': <gensim.models.keyedvectors.Vocab at 0x1a288f22e8>,
#  '🇦': <gensim.models.keyedvectors.Vocab at 0x1a288f2320>,
#  '🇿': <gensim.models.keyedvectors.Vocab at 0x1a288f2358>,
#  '🇸': <gensim.models.keyedvectors.Vocab at 0x1a288f2390>,
#  '🇺': <gensim.models.keyedvectors.Vocab at 0x1a288f23c8>,
#  '🇩': <gensim.models.keyedvectors.Vocab at 0x1a288f2400>,
#  '🇪': <gensim.models.keyedvectors.Vocab at 0x1a288f2438>,
#  '🇮': <gensim.models.keyedvectors.Vocab at 0x1a288f2470>,
#  '🇧': <gensim.models.keyedvectors.Vocab at 0x1a288f24a8>,
#  '😭': <gensim.models.keyedvectors.Vocab at 0x1a288f24e0>,
#  '🤦': <gensim.models.keyedvectors.Vocab at 0x1a288f2518>,
#  '♂': <gensim.models.keyedvectors.Vocab at 0x1a288f2550>,
#  '👉': <gensim.models.keyedvectors.Vocab at 0x1a288f2588>,
#  '🚖': <gensim.models.keyedvectors.Vocab at 0x1a288f25c0>,
#  '🏾': <gensim.models.keyedvectors.Vocab at 0x1a288f25f8>,
#  '🎈': <gensim.models.keyedvectors.Vocab at 0x1a288f2630>,
#  '💃': <gensim.models.keyedvectors.Vocab at 0x1a288f2668>,
#  '💞': <gensim.models.keyedvectors.Vocab at 0x1a288f26a0>,
#  '😳': <gensim.models.keyedvectors.Vocab at 0x1a288f26d8>,
#  '😉': <gensim.models.keyedvectors.Vocab at 0x1a288f2710>,
#  '⚽': <gensim.models.keyedvectors.Vocab at 0x1a288f2748>,
#  '🍬': <gensim.models.keyedvectors.Vocab at 0x1a288f2780>,
#  '🍭': <gensim.models.keyedvectors.Vocab at 0x1a288f27b8>,
#  '💕': <gensim.models.keyedvectors.Vocab at 0x1a288f27f0>,
#  '🔋': <gensim.models.keyedvectors.Vocab at 0x1a288f2828>,
#  '🙊': <gensim.models.keyedvectors.Vocab at 0x1a288f2860>,
#  '👍': <gensim.models.keyedvectors.Vocab at 0x1a288f2898>,
#  '🍳': <gensim.models.keyedvectors.Vocab at 0x1a288f28d0>,
#  '🥚': <gensim.models.keyedvectors.Vocab at 0x1a288f2908>,
#  '😞': <gensim.models.keyedvectors.Vocab at 0x1a288f2940>,
#  '😢': <gensim.models.keyedvectors.Vocab at 0x1a288f2978>,
#  '😘': <gensim.models.keyedvectors.Vocab at 0x1a288f29b0>,
#  '😍': <gensim.models.keyedvectors.Vocab at 0x1a288f29e8>,
#  '🤧': <gensim.models.keyedvectors.Vocab at 0x1a288f2a20>,
#  '🤗': <gensim.models.keyedvectors.Vocab at 0x1a288f2a58>,
#  '🎉': <gensim.models.keyedvectors.Vocab at 0x1a288f2a90>,
#  '🍾': <gensim.models.keyedvectors.Vocab at 0x1a288f2ac8>,
#  '🍷': <gensim.models.keyedvectors.Vocab at 0x1a288f2b00>,
#  '🎊': <gensim.models.keyedvectors.Vocab at 0x1a288f2b38>,
#  '📱': <gensim.models.keyedvectors.Vocab at 0x1a288f2b70>,
#  '💋': <gensim.models.keyedvectors.Vocab at 0x1a288f2ba8>,
#  '😊': <gensim.models.keyedvectors.Vocab at 0x1a288f2be0>,
#  '⃣': <gensim.models.keyedvectors.Vocab at 0x1a288f2c18>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x1a288f2c50>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x1a288f2c88>,
#  '🎵': <gensim.models.keyedvectors.Vocab at 0x1a288f2cc0>,
#  '💌': <gensim.models.keyedvectors.Vocab at 0x1a288f2cf8>,
#  '👟': <gensim.models.keyedvectors.Vocab at 0x1a288f2d30>,
#  '🎁': <gensim.models.keyedvectors.Vocab at 0x1a288f2d68>,
#  '🔥': <gensim.models.keyedvectors.Vocab at 0x1a288f2da0>,
#  '🐶': <gensim.models.keyedvectors.Vocab at 0x1a288f2dd8>,
#  '🎹': <gensim.models.keyedvectors.Vocab at 0x1a288f2e10>,
#  '😂': <gensim.models.keyedvectors.Vocab at 0x1a288f2e48>,
#  '🍑': <gensim.models.keyedvectors.Vocab at 0x1a288f2e80>,
#  '😋': <gensim.models.keyedvectors.Vocab at 0x1a288f2eb8>,
#  '🙏': <gensim.models.keyedvectors.Vocab at 0x1a288f2ef0>,
#  '💿': <gensim.models.keyedvectors.Vocab at 0x1a288f2f28>,
#  '💘': <gensim.models.keyedvectors.Vocab at 0x1a288f2f60>,
#  '🌧': <gensim.models.keyedvectors.Vocab at 0x1a288f2f98>,
#  '💙': <gensim.models.keyedvectors.Vocab at 0x1a288f2fd0>,
#  '😃': <gensim.models.keyedvectors.Vocab at 0x1a288fe048>,
#  '🏽': <gensim.models.keyedvectors.Vocab at 0x1a288fe080>,
#  '🕵': <gensim.models.keyedvectors.Vocab at 0x1a288fe0b8>,
#  '‼': <gensim.models.keyedvectors.Vocab at 0x1a288fe0f0>,
#  '📌': <gensim.models.keyedvectors.Vocab at 0x1a288fe128>,
#  '❕': <gensim.models.keyedvectors.Vocab at 0x1a288fe160>,
#  '🙆': <gensim.models.keyedvectors.Vocab at 0x1a288fe198>,
#  '😌': <gensim.models.keyedvectors.Vocab at 0x1a288fe1d0>,
#  '🎤': <gensim.models.keyedvectors.Vocab at 0x1a288fe208>,
#  '😆': <gensim.models.keyedvectors.Vocab at 0x1a288fe240>,
#  '😅': <gensim.models.keyedvectors.Vocab at 0x1a288fe278>,
#  '🙄': <gensim.models.keyedvectors.Vocab at 0x1a288fe2b0>,
#  '📹': <gensim.models.keyedvectors.Vocab at 0x1a288fe2e8>,
#  '🍽': <gensim.models.keyedvectors.Vocab at 0x1a288fe320>,
#  '🏌': <gensim.models.keyedvectors.Vocab at 0x1a288fe358>,
#  '⛳': <gensim.models.keyedvectors.Vocab at 0x1a288fe390>,
#  '👌': <gensim.models.keyedvectors.Vocab at 0x1a288fe3c8>,
#  '💪': <gensim.models.keyedvectors.Vocab at 0x1a288fe400>,
#  '🏆': <gensim.models.keyedvectors.Vocab at 0x1a288fe438>,
#  '🏻': <gensim.models.keyedvectors.Vocab at 0x1a288fe470>,
#  '♥': <gensim.models.keyedvectors.Vocab at 0x1a288fe4a8>,
#  '🤟': <gensim.models.keyedvectors.Vocab at 0x1a288fe4e0>,
#  '😈': <gensim.models.keyedvectors.Vocab at 0x1a288fe518>,
#  '🏼': <gensim.models.keyedvectors.Vocab at 0x1a288fe550>,
#  '⭐': <gensim.models.keyedvectors.Vocab at 0x1a288fe588>,
#  '🇷': <gensim.models.keyedvectors.Vocab at 0x1a288fe5c0>,
#  '🌺': <gensim.models.keyedvectors.Vocab at 0x1a288fe5f8>,
#  '🐾': <gensim.models.keyedvectors.Vocab at 0x1a288fe630>,
#  '🐠': <gensim.models.keyedvectors.Vocab at 0x1a288fe668>,
#  '🐇': <gensim.models.keyedvectors.Vocab at 0x1a288fe6a0>,
#  '👑': <gensim.models.keyedvectors.Vocab at 0x1a288fe6d8>,
#  '🐣': <gensim.models.keyedvectors.Vocab at 0x1a288fe710>,
#  '🐧': <gensim.models.keyedvectors.Vocab at 0x1a288fe748>,
#  '👣': <gensim.models.keyedvectors.Vocab at 0x1a288fe780>,
#  '🔞': <gensim.models.keyedvectors.Vocab at 0x1a288fe7b8>,
#  '📽': <gensim.models.keyedvectors.Vocab at 0x1a288fe7f0>,
#  '🤷': <gensim.models.keyedvectors.Vocab at 0x1a288fe828>,
#  '🏃': <gensim.models.keyedvectors.Vocab at 0x1a288fe860>,
#  '💨': <gensim.models.keyedvectors.Vocab at 0x1a288fe898>,
#  '🍰': <gensim.models.keyedvectors.Vocab at 0x1a288fe8d0>,
#  '💰': <gensim.models.keyedvectors.Vocab at 0x1a288fe908>,
#  '👋': <gensim.models.keyedvectors.Vocab at 0x1a288fe940>,
#  '😫': <gensim.models.keyedvectors.Vocab at 0x1a288fe978>,
#  '🎥': <gensim.models.keyedvectors.Vocab at 0x1a288fe9b0>,
#  '🙈': <gensim.models.keyedvectors.Vocab at 0x1a288fe9e8>,
#  '👏': <gensim.models.keyedvectors.Vocab at 0x1a288fea20>,
#  '🌊': <gensim.models.keyedvectors.Vocab at 0x1a288fea58>,
#  '🤴': <gensim.models.keyedvectors.Vocab at 0x1a288fea90>,
#  '👸': <gensim.models.keyedvectors.Vocab at 0x1a288feac8>,
#  '👀': <gensim.models.keyedvectors.Vocab at 0x1a288feb00>,
#  '😏': <gensim.models.keyedvectors.Vocab at 0x1a288feb38>,
#  '😩': <gensim.models.keyedvectors.Vocab at 0x1a288feb70>,
#  '📐': <gensim.models.keyedvectors.Vocab at 0x1a288feba8>,
#  '🕶': <gensim.models.keyedvectors.Vocab at 0x1a288febe0>,
#  '☀': <gensim.models.keyedvectors.Vocab at 0x1a288fec18>,
#  '😲': <gensim.models.keyedvectors.Vocab at 0x1a288fec50>,
#  '🌍': <gensim.models.keyedvectors.Vocab at 0x1a288fec88>,
#  '🇯': <gensim.models.keyedvectors.Vocab at 0x1a288fecc0>,
#  '🇵': <gensim.models.keyedvectors.Vocab at 0x1a288fecf8>,
#  '💀': <gensim.models.keyedvectors.Vocab at 0x1a288fed30>,
#  '🤭': <gensim.models.keyedvectors.Vocab at 0x1a288fed68>,
#  '😎': <gensim.models.keyedvectors.Vocab at 0x1a288feda0>,
#  '🇲': <gensim.models.keyedvectors.Vocab at 0x1a288fedd8>,
#  '💥': <gensim.models.keyedvectors.Vocab at 0x1a288fee10>,
#  '✅': <gensim.models.keyedvectors.Vocab at 0x1a288fee48>,
#  '📢': <gensim.models.keyedvectors.Vocab at 0x1a288fee80>,
#  '🚗': <gensim.models.keyedvectors.Vocab at 0x1a288feeb8>,
#  '🔑': <gensim.models.keyedvectors.Vocab at 0x1a288feef0>,
#  '🇨': <gensim.models.keyedvectors.Vocab at 0x1a288fef28>,
#  '🤞': <gensim.models.keyedvectors.Vocab at 0x1a288fef60>,
#  '📲': <gensim.models.keyedvectors.Vocab at 0x1a288fef98>,
#  '🆘': <gensim.models.keyedvectors.Vocab at 0x1a288fefd0>,
#  '🏁': <gensim.models.keyedvectors.Vocab at 0x1a28900048>,
#  '🚩': <gensim.models.keyedvectors.Vocab at 0x1a28900080>,
#  '🍃': <gensim.models.keyedvectors.Vocab at 0x1a289000b8>,
#  '🤣': <gensim.models.keyedvectors.Vocab at 0x1a289000f0>,
#  '📷': <gensim.models.keyedvectors.Vocab at 0x1a28900128>,
#  '🌴': <gensim.models.keyedvectors.Vocab at 0x1a28900160>,
#  '🤘': <gensim.models.keyedvectors.Vocab at 0x1a28900198>,
#  '🙃': <gensim.models.keyedvectors.Vocab at 0x1a289001d0>,
#  '👯': <gensim.models.keyedvectors.Vocab at 0x1a28900208>,
#  '🕺': <gensim.models.keyedvectors.Vocab at 0x1a28900240>,
#  '💚': <gensim.models.keyedvectors.Vocab at 0x1a28900278>,
#  '😱': <gensim.models.keyedvectors.Vocab at 0x1a289002b0>,
#  '⚡': <gensim.models.keyedvectors.Vocab at 0x1a289002e8>,
#  '📉': <gensim.models.keyedvectors.Vocab at 0x1a28900320>,
#  '👠': <gensim.models.keyedvectors.Vocab at 0x1a28900358>,
#  '🎓': <gensim.models.keyedvectors.Vocab at 0x1a28900390>,
#  '🐪': <gensim.models.keyedvectors.Vocab at 0x1a289003c8>,
#  '💔': <gensim.models.keyedvectors.Vocab at 0x1a28900400>,
#  '🏀': <gensim.models.keyedvectors.Vocab at 0x1a28900438>,
#  '👥': <gensim.models.keyedvectors.Vocab at 0x1a28900470>,
#  '👇': <gensim.models.keyedvectors.Vocab at 0x1a289004a8>,
#  '😒': <gensim.models.keyedvectors.Vocab at 0x1a289004e0>,
#  '🤔': <gensim.models.keyedvectors.Vocab at 0x1a28900518>,
#  '🤯': <gensim.models.keyedvectors.Vocab at 0x1a28900550>,
#  '📖': <gensim.models.keyedvectors.Vocab at 0x1a28900588>,
#  '👂': <gensim.models.keyedvectors.Vocab at 0x1a289005c0>,
#  '🧠': <gensim.models.keyedvectors.Vocab at 0x1a289005f8>,
#  '📚': <gensim.models.keyedvectors.Vocab at 0x1a28900630>,
#  '🎙': <gensim.models.keyedvectors.Vocab at 0x1a28900668>,
#  '💦': <gensim.models.keyedvectors.Vocab at 0x1a289006a0>,
#  '💯': <gensim.models.keyedvectors.Vocab at 0x1a289006d8>,
#  '💫': <gensim.models.keyedvectors.Vocab at 0x1a28900710>,
#  '🎂': <gensim.models.keyedvectors.Vocab at 0x1a28900748>,
#  '👊': <gensim.models.keyedvectors.Vocab at 0x1a28900780>,
#  '😁': <gensim.models.keyedvectors.Vocab at 0x1a289007b8>,
#  '🐎': <gensim.models.keyedvectors.Vocab at 0x1a289007f0>,
#  '😻': <gensim.models.keyedvectors.Vocab at 0x1a28900828>,
#  '🍉': <gensim.models.keyedvectors.Vocab at 0x1a28900860>,
#  '😽': <gensim.models.keyedvectors.Vocab at 0x1a28900898>,
#  '☺': <gensim.models.keyedvectors.Vocab at 0x1a289008d0>,
#  '😸': <gensim.models.keyedvectors.Vocab at 0x1a28900908>,
#  '🍫': <gensim.models.keyedvectors.Vocab at 0x1a28900940>,
#  '😔': <gensim.models.keyedvectors.Vocab at 0x1a28900978>,
#  '🔊': <gensim.models.keyedvectors.Vocab at 0x1a289009b0>,
#  '🇱': <gensim.models.keyedvectors.Vocab at 0x1a289009e8>,
#  '🌟': <gensim.models.keyedvectors.Vocab at 0x1a28900a20>,
#  '🛴': <gensim.models.keyedvectors.Vocab at 0x1a28900a58>,
#  '💟': <gensim.models.keyedvectors.Vocab at 0x1a28900a90>,
#  '🦋': <gensim.models.keyedvectors.Vocab at 0x1a28900ac8>,
#  '🖤': <gensim.models.keyedvectors.Vocab at 0x1a28900b00>,
#  '🏳': <gensim.models.keyedvectors.Vocab at 0x1a28900b38>,
#  '🤡': <gensim.models.keyedvectors.Vocab at 0x1a28900b70>,
#  '😬': <gensim.models.keyedvectors.Vocab at 0x1a28900ba8>,
#  '😠': <gensim.models.keyedvectors.Vocab at 0x1a28900be0>,
#  '✋': <gensim.models.keyedvectors.Vocab at 0x1a28900c18>,
#  '🏿': <gensim.models.keyedvectors.Vocab at 0x1a28900c50>,
#  '🧡': <gensim.models.keyedvectors.Vocab at 0x1a28900c88>,
#  '🙋': <gensim.models.keyedvectors.Vocab at 0x1a28900cc0>,
#  '🌹': <gensim.models.keyedvectors.Vocab at 0x1a28900cf8>,
#  '💗': <gensim.models.keyedvectors.Vocab at 0x1a28900d30>,
#  '😚': <gensim.models.keyedvectors.Vocab at 0x1a28900d68>,
#  '🌂': <gensim.models.keyedvectors.Vocab at 0x1a28900da0>,
#  '😕': <gensim.models.keyedvectors.Vocab at 0x1a28900dd8>,
#  '🌅': <gensim.models.keyedvectors.Vocab at 0x1a28900e10>,
#  '🛎': <gensim.models.keyedvectors.Vocab at 0x1a28900e48>,
#  '🏐': <gensim.models.keyedvectors.Vocab at 0x1a28900e80>,
#  '👈': <gensim.models.keyedvectors.Vocab at 0x1a28900eb8>,
#  '😤': <gensim.models.keyedvectors.Vocab at 0x1a28900ef0>,
#  '👨': <gensim.models.keyedvectors.Vocab at 0x1a28900f28>,
#  '🦍': <gensim.models.keyedvectors.Vocab at 0x1a28900f60>,
#  '🌦': <gensim.models.keyedvectors.Vocab at 0x1a28900f98>,
#  '🌿': <gensim.models.keyedvectors.Vocab at 0x1a28900fd0>,
#  '😮': <gensim.models.keyedvectors.Vocab at 0x1a28ace048>,
#  '🍌': <gensim.models.keyedvectors.Vocab at 0x1a28ace080>,
#  '🍞': <gensim.models.keyedvectors.Vocab at 0x1a28ace0b8>,
#  '🍆': <gensim.models.keyedvectors.Vocab at 0x1a28ace0f0>,
#  '💅': <gensim.models.keyedvectors.Vocab at 0x1a28ace128>,
#  '😜': <gensim.models.keyedvectors.Vocab at 0x1a28ace160>,
#  '🌌': <gensim.models.keyedvectors.Vocab at 0x1a28ace198>,
#  '🐈': <gensim.models.keyedvectors.Vocab at 0x1a28ace1d0>,
#  '🐱': <gensim.models.keyedvectors.Vocab at 0x1a28ace208>,
#  '➡': <gensim.models.keyedvectors.Vocab at 0x1a28ace240>,
#  '🇳': <gensim.models.keyedvectors.Vocab at 0x1a28ace278>,
#  '🌆': <gensim.models.keyedvectors.Vocab at 0x1a28ace2b0>,
#  '🌞': <gensim.models.keyedvectors.Vocab at 0x1a28ace2e8>,
#  '🤤': <gensim.models.keyedvectors.Vocab at 0x1a28ace320>,
#  '✊': <gensim.models.keyedvectors.Vocab at 0x1a28ace358>,
#  '💎': <gensim.models.keyedvectors.Vocab at 0x1a28ace390>,
#  '💷': <gensim.models.keyedvectors.Vocab at 0x1a28ace3c8>,
#  '👫': <gensim.models.keyedvectors.Vocab at 0x1a28ace400>,
#  '💓': <gensim.models.keyedvectors.Vocab at 0x1a28ace438>,
#  '🐻': <gensim.models.keyedvectors.Vocab at 0x1a28ace470>,
#  '🏩': <gensim.models.keyedvectors.Vocab at 0x1a28ace4a8>,
#  '👗': <gensim.models.keyedvectors.Vocab at 0x1a28ace4e0>,
#  '📗': <gensim.models.keyedvectors.Vocab at 0x1a28ace518>,
#  '🌚': <gensim.models.keyedvectors.Vocab at 0x1a28ace550>,
#  '🕛': <gensim.models.keyedvectors.Vocab at 0x1a28ace588>,
#  '🍋': <gensim.models.keyedvectors.Vocab at 0x1a28ace5c0>,
#  '🔅': <gensim.models.keyedvectors.Vocab at 0x1a28ace5f8>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x1a28ace630>,
#  '🤠': <gensim.models.keyedvectors.Vocab at 0x1a28ace668>,
#  '🤜': <gensim.models.keyedvectors.Vocab at 0x1a28ace6a0>,
#  '🤢': <gensim.models.keyedvectors.Vocab at 0x1a28ace6d8>,
#  '🇬': <gensim.models.keyedvectors.Vocab at 0x1a28ace710>,
#  '🇭': <gensim.models.keyedvectors.Vocab at 0x1a28ace748>,
#  '💝': <gensim.models.keyedvectors.Vocab at 0x1a28ace780>,
#  '❣': <gensim.models.keyedvectors.Vocab at 0x1a28ace7b8>,
#  '🛍': <gensim.models.keyedvectors.Vocab at 0x1a28ace7f0>,
#  '🐴': <gensim.models.keyedvectors.Vocab at 0x1a28ace828>,
#  '✔': <gensim.models.keyedvectors.Vocab at 0x1a28ace860>,
#  '❗': <gensim.models.keyedvectors.Vocab at 0x1a28ace898>,
#  '📡': <gensim.models.keyedvectors.Vocab at 0x1a28ace8d0>,
#  '🎇': <gensim.models.keyedvectors.Vocab at 0x1a28ace908>,
#  '😣': <gensim.models.keyedvectors.Vocab at 0x1a28ace940>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x1a28ace978>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x1a28ace9b0>,
#  '🔴': <gensim.models.keyedvectors.Vocab at 0x1a28ace9e8>,
#  '⚪': <gensim.models.keyedvectors.Vocab at 0x1a28acea20>,
#  '🎼': <gensim.models.keyedvectors.Vocab at 0x1a28acea58>,
#  '😑': <gensim.models.keyedvectors.Vocab at 0x1a28acea90>,
#  '🚶': <gensim.models.keyedvectors.Vocab at 0x1a28aceac8>,
#  '🚪': <gensim.models.keyedvectors.Vocab at 0x1a28aceb00>,
#  '💣': <gensim.models.keyedvectors.Vocab at 0x1a28aceb38>,
#  '🚨': <gensim.models.keyedvectors.Vocab at 0x1a28aceb70>,
#  '🍪': <gensim.models.keyedvectors.Vocab at 0x1a28aceba8>,
#  '📻': <gensim.models.keyedvectors.Vocab at 0x1a28acebe0>,
#  '🐥': <gensim.models.keyedvectors.Vocab at 0x1a28acec18>,
#  '🐔': <gensim.models.keyedvectors.Vocab at 0x1a28acec50>,
#  '🐦': <gensim.models.keyedvectors.Vocab at 0x1a28acec88>,
#  '🐤': <gensim.models.keyedvectors.Vocab at 0x1a28acecc0>,
#  '🕗': <gensim.models.keyedvectors.Vocab at 0x1a28acecf8>,
#  '😶': <gensim.models.keyedvectors.Vocab at 0x1a28aced30>,
#  '🙂': <gensim.models.keyedvectors.Vocab at 0x1a28aced68>,
#  '🏟': <gensim.models.keyedvectors.Vocab at 0x1a28aceda0>,
#  '👅': <gensim.models.keyedvectors.Vocab at 0x1a28acedd8>,
#  '🐊': <gensim.models.keyedvectors.Vocab at 0x1a28acee10>,
#  '🎖': <gensim.models.keyedvectors.Vocab at 0x1a28acee48>,
#  '🍔': <gensim.models.keyedvectors.Vocab at 0x1a28acee80>,
#  '🎸': <gensim.models.keyedvectors.Vocab at 0x1a28aceeb8>,
#  '🎆': <gensim.models.keyedvectors.Vocab at 0x1a28aceef0>,
#  '💁': <gensim.models.keyedvectors.Vocab at 0x1a28acef28>,
#  '🥂': <gensim.models.keyedvectors.Vocab at 0x1a28acef60>,
#  '🤪': <gensim.models.keyedvectors.Vocab at 0x1a28acef98>,
#  '🇾': <gensim.models.keyedvectors.Vocab at 0x1a28acefd0>,
#  '🦁': <gensim.models.keyedvectors.Vocab at 0x1a28ad3048>,
#  '🔝': <gensim.models.keyedvectors.Vocab at 0x1a28ad3080>,
#  '📸': <gensim.models.keyedvectors.Vocab at 0x1a28ad30b8>,
#  '🚀': <gensim.models.keyedvectors.Vocab at 0x1a28ad30f0>,
#  '🦌': <gensim.models.keyedvectors.Vocab at 0x1a28ad3128>,
#  '😇': <gensim.models.keyedvectors.Vocab at 0x1a28ad3160>,
#  '🚕': <gensim.models.keyedvectors.Vocab at 0x1a28ad3198>,
#  '🙅': <gensim.models.keyedvectors.Vocab at 0x1a28ad31d0>,
#  '😥': <gensim.models.keyedvectors.Vocab at 0x1a28ad3208>,
#  '🗣': <gensim.models.keyedvectors.Vocab at 0x1a28ad3240>,
#  '🏊': <gensim.models.keyedvectors.Vocab at 0x1a28ad3278>,
#  '🤕': <gensim.models.keyedvectors.Vocab at 0x1a28ad32b0>,
#  '😡': <gensim.models.keyedvectors.Vocab at 0x1a28ad32e8>,
#  '⏰': <gensim.models.keyedvectors.Vocab at 0x1a28ad3320>,
#  '🌙': <gensim.models.keyedvectors.Vocab at 0x1a28ad3358>,
#  '🖐': <gensim.models.keyedvectors.Vocab at 0x1a28ad3390>,
#  '🏡': <gensim.models.keyedvectors.Vocab at 0x1a28ad33c8>,
#  '🙉': <gensim.models.keyedvectors.Vocab at 0x1a28ad3400>,
#  '🐽': <gensim.models.keyedvectors.Vocab at 0x1a28ad3438>,
#  '🌶': <gensim.models.keyedvectors.Vocab at 0x1a28ad3470>,
#  '🥁': <gensim.models.keyedvectors.Vocab at 0x1a28ad34a8>,
#  '🥇': <gensim.models.keyedvectors.Vocab at 0x1a28ad34e0>,
#  '🐢': <gensim.models.keyedvectors.Vocab at 0x1a28ad3518>,
#  '🗽': <gensim.models.keyedvectors.Vocab at 0x1a28ad3550>,
#  '🔪': <gensim.models.keyedvectors.Vocab at 0x1a28ad3588>,
#  '😄': <gensim.models.keyedvectors.Vocab at 0x1a28ad35c0>,
#  '🚫': <gensim.models.keyedvectors.Vocab at 0x1a28ad35f8>,
#  '🧢': <gensim.models.keyedvectors.Vocab at 0x1a28ad3630>,
#  '🐕': <gensim.models.keyedvectors.Vocab at 0x1a28ad3668>,
#  '🕒': <gensim.models.keyedvectors.Vocab at 0x1a28ad36a0>,
#  '🐬': <gensim.models.keyedvectors.Vocab at 0x1a28ad36d8>,
#  '🔵': <gensim.models.keyedvectors.Vocab at 0x1a28ad3710>,
#  '🔜': <gensim.models.keyedvectors.Vocab at 0x1a28ad3748>,
#  '➗': <gensim.models.keyedvectors.Vocab at 0x1a28ad3780>,
#  '🍊': <gensim.models.keyedvectors.Vocab at 0x1a28ad37b8>,
#  '👦': <gensim.models.keyedvectors.Vocab at 0x1a28ad37f0>,
#  '🕯': <gensim.models.keyedvectors.Vocab at 0x1a28ad3828>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x1a28ad3860>,
#  '🧚': <gensim.models.keyedvectors.Vocab at 0x1a28ad3898>,
#  '🚲': <gensim.models.keyedvectors.Vocab at 0x1a28ad38d0>,
#  '🌏': <gensim.models.keyedvectors.Vocab at 0x1a28ad3908>,
#  '🆓': <gensim.models.keyedvectors.Vocab at 0x1a28ad3940>,
#  '✍': <gensim.models.keyedvectors.Vocab at 0x1a28ad3978>,
#  '😝': <gensim.models.keyedvectors.Vocab at 0x1a28ad39b0>,
#  '🥥': <gensim.models.keyedvectors.Vocab at 0x1a28ad39e8>,
#  '🌠': <gensim.models.keyedvectors.Vocab at 0x1a28ad3a20>,
#  '🇫': <gensim.models.keyedvectors.Vocab at 0x1a28ad3a58>,
#  '😛': <gensim.models.keyedvectors.Vocab at 0x1a28ad3a90>,
#  '🥊': <gensim.models.keyedvectors.Vocab at 0x1a28ad3ac8>,
#  '🍗': <gensim.models.keyedvectors.Vocab at 0x1a28ad3b00>,
#  '😯': <gensim.models.keyedvectors.Vocab at 0x1a28ad3b38>,
#  '👧': <gensim.models.keyedvectors.Vocab at 0x1a28ad3b70>,
#  '🎀': <gensim.models.keyedvectors.Vocab at 0x1a28ad3ba8>,
#  '👩': <gensim.models.keyedvectors.Vocab at 0x1a28ad3be0>,
#  '🦒': <gensim.models.keyedvectors.Vocab at 0x1a28ad3c18>,
#  '🐝': <gensim.models.keyedvectors.Vocab at 0x1a28ad3c50>,
#  '🇰': <gensim.models.keyedvectors.Vocab at 0x1a28ad3c88>,
#  '🏦': <gensim.models.keyedvectors.Vocab at 0x1a28ad3cc0>,
#  '🔨': <gensim.models.keyedvectors.Vocab at 0x1a28ad3cf8>,
#  '🖕': <gensim.models.keyedvectors.Vocab at 0x1a28ad3d30>,
#  '🔔': <gensim.models.keyedvectors.Vocab at 0x1a28ad3d68>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x1a28ad3da0>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x1a28ad3dd8>,
#  '🍁': <gensim.models.keyedvectors.Vocab at 0x1a28ad3e10>,
#  '🆔': <gensim.models.keyedvectors.Vocab at 0x1a28ad3e48>,
#  '📝': <gensim.models.keyedvectors.Vocab at 0x1a28ad3e80>,
#  '😰': <gensim.models.keyedvectors.Vocab at 0x1a28ad3eb8>,
#  '😨': <gensim.models.keyedvectors.Vocab at 0x1a28ad3ef0>,
#  '🤫': <gensim.models.keyedvectors.Vocab at 0x1a28ad3f28>,
#  '🍕': <gensim.models.keyedvectors.Vocab at 0x1a28ad3f60>,
#  '😙': <gensim.models.keyedvectors.Vocab at 0x1a28ad3f98>,
#  '❌': <gensim.models.keyedvectors.Vocab at 0x1a28ad3fd0>,
#  '🏄': <gensim.models.keyedvectors.Vocab at 0x1a28ad6048>,
#  '🍟': <gensim.models.keyedvectors.Vocab at 0x1a28ad6080>,
#  '🗯': <gensim.models.keyedvectors.Vocab at 0x1a28ad60b8>,
#  '📬': <gensim.models.keyedvectors.Vocab at 0x1a28ad60f0>,
#  '🛑': <gensim.models.keyedvectors.Vocab at 0x1a28ad6128>,
#  '🍒': <gensim.models.keyedvectors.Vocab at 0x1a28ad6160>,
#  '🚚': <gensim.models.keyedvectors.Vocab at 0x1a28ad6198>,
#  '🏏': <gensim.models.keyedvectors.Vocab at 0x1a28ad61d0>,
#  '🦅': <gensim.models.keyedvectors.Vocab at 0x1a28ad6208>,
#  '🏅': <gensim.models.keyedvectors.Vocab at 0x1a28ad6240>,
#  '🎨': <gensim.models.keyedvectors.Vocab at 0x1a28ad6278>,
#  '🎻': <gensim.models.keyedvectors.Vocab at 0x1a28ad62b0>,
#  '🎬': <gensim.models.keyedvectors.Vocab at 0x1a28ad62e8>,
#  '🤽': <gensim.models.keyedvectors.Vocab at 0x1a28ad6320>,
#  '🐷': <gensim.models.keyedvectors.Vocab at 0x1a28ad6358>,
#  '💶': <gensim.models.keyedvectors.Vocab at 0x1a28ad6390>,
#  '😹': <gensim.models.keyedvectors.Vocab at 0x1a28ad63c8>,
#  '🎮': <gensim.models.keyedvectors.Vocab at 0x1a28ad6400>,
#  '🤾': <gensim.models.keyedvectors.Vocab at 0x1a28ad6438>,
#  '❄': <gensim.models.keyedvectors.Vocab at 0x1a28ad6470>,
#  '🌡': <gensim.models.keyedvectors.Vocab at 0x1a28ad64a8>,
#  '🛸': <gensim.models.keyedvectors.Vocab at 0x1a28ad64e0>,
#  '💢': <gensim.models.keyedvectors.Vocab at 0x1a28ad6518>,
#  '💬': <gensim.models.keyedvectors.Vocab at 0x1a28ad6550>,
#  '💭': <gensim.models.keyedvectors.Vocab at 0x1a28ad6588>,
#  '🌝': <gensim.models.keyedvectors.Vocab at 0x1a28ad65c0>,
#  '⚓': <gensim.models.keyedvectors.Vocab at 0x1a28ad65f8>,
#  '🔁': <gensim.models.keyedvectors.Vocab at 0x1a28ad6630>,
#  '💸': <gensim.models.keyedvectors.Vocab at 0x1a28ad6668>,
#  '🤑': <gensim.models.keyedvectors.Vocab at 0x1a28ad66a0>,
#  '💂': <gensim.models.keyedvectors.Vocab at 0x1a28ad66d8>,
#  '🔈': <gensim.models.keyedvectors.Vocab at 0x1a28ad6710>,
#  '😺': <gensim.models.keyedvectors.Vocab at 0x1a28ad6748>,
#  '✌': <gensim.models.keyedvectors.Vocab at 0x1a28ad6780>,
#  '💮': <gensim.models.keyedvectors.Vocab at 0x1a28ad67b8>,
#  '🚮': <gensim.models.keyedvectors.Vocab at 0x1a28ad67f0>,
#  '🤮': <gensim.models.keyedvectors.Vocab at 0x1a28ad6828>,
#  '🥗': <gensim.models.keyedvectors.Vocab at 0x1a28ad6860>,
#  '👁': <gensim.models.keyedvectors.Vocab at 0x1a28ad6898>,
#  '🥩': <gensim.models.keyedvectors.Vocab at 0x1a28ad68d0>,
#  '🧀': <gensim.models.keyedvectors.Vocab at 0x1a28ad6908>,
#  '🤩': <gensim.models.keyedvectors.Vocab at 0x1a28ad6940>,
#  '👺': <gensim.models.keyedvectors.Vocab at 0x1a28ad6978>,
#  '👹': <gensim.models.keyedvectors.Vocab at 0x1a28ad69b0>,
#  '❔': <gensim.models.keyedvectors.Vocab at 0x1a28ad69e8>,
#  '🍦': <gensim.models.keyedvectors.Vocab at 0x1a28ad6a20>,
#  '🏒': <gensim.models.keyedvectors.Vocab at 0x1a28ad6a58>,
#  '⛸': <gensim.models.keyedvectors.Vocab at 0x1a28ad6a90>,
#  '🥅': <gensim.models.keyedvectors.Vocab at 0x1a28ad6ac8>,
#  '☔': <gensim.models.keyedvectors.Vocab at 0x1a28ad6b00>,
#  '💡': <gensim.models.keyedvectors.Vocab at 0x1a28ad6b38>,
#  '💻': <gensim.models.keyedvectors.Vocab at 0x1a28ad6b70>,
#  '😾': <gensim.models.keyedvectors.Vocab at 0x1a28ad6ba8>,
#  '📰': <gensim.models.keyedvectors.Vocab at 0x1a28ad6be0>,
#  '🍝': <gensim.models.keyedvectors.Vocab at 0x1a28ad6c18>,
#  '🍜': <gensim.models.keyedvectors.Vocab at 0x1a28ad6c50>,
#  '💑': <gensim.models.keyedvectors.Vocab at 0x1a28ad6c88>,
#  '🍿': <gensim.models.keyedvectors.Vocab at 0x1a28ad6cc0>,
#  '🔬': <gensim.models.keyedvectors.Vocab at 0x1a28ad6cf8>,
#  '🤺': <gensim.models.keyedvectors.Vocab at 0x1a28ad6d30>,
#  '🍇': <gensim.models.keyedvectors.Vocab at 0x1a28ad6d68>,
#  '💄': <gensim.models.keyedvectors.Vocab at 0x1a28ad6da0>,
#  '🏍': <gensim.models.keyedvectors.Vocab at 0x1a28ad6dd8>,
#  '🐯': <gensim.models.keyedvectors.Vocab at 0x1a28ad6e10>,
#  '🚄': <gensim.models.keyedvectors.Vocab at 0x1a28ad6e48>,
#  '🥛': <gensim.models.keyedvectors.Vocab at 0x1a28ad6e80>,
#  '🦈': <gensim.models.keyedvectors.Vocab at 0x1a28ad6eb8>,
#  '💤': <gensim.models.keyedvectors.Vocab at 0x1a28ad6ef0>,
#  '🐍': <gensim.models.keyedvectors.Vocab at 0x1a28ad6f28>,
#  '🐐': <gensim.models.keyedvectors.Vocab at 0x1a28ad6f60>,
#  '🤓': <gensim.models.keyedvectors.Vocab at 0x1a28ad6f98>,
#  '🕷': <gensim.models.keyedvectors.Vocab at 0x1a28ad6fd0>,
#  '👶': <gensim.models.keyedvectors.Vocab at 0x1a28ada048>,
#  '🌾': <gensim.models.keyedvectors.Vocab at 0x1a28ada080>,
#  '🐑': <gensim.models.keyedvectors.Vocab at 0x1a28ada0b8>,
#  '🏝': <gensim.models.keyedvectors.Vocab at 0x1a28ada0f0>,
#  '😵': <gensim.models.keyedvectors.Vocab at 0x1a28ada128>,
#  '👭': <gensim.models.keyedvectors.Vocab at 0x1a28ada160>,
#  '👵': <gensim.models.keyedvectors.Vocab at 0x1a28ada198>,
#  '👱': <gensim.models.keyedvectors.Vocab at 0x1a28ada1d0>,
#  '🥤': <gensim.models.keyedvectors.Vocab at 0x1a28ada208>,
#  '😴': <gensim.models.keyedvectors.Vocab at 0x1a28ada240>,
#  '🤖': <gensim.models.keyedvectors.Vocab at 0x1a28ada278>,
#  '👄': <gensim.models.keyedvectors.Vocab at 0x1a28ada2b0>,
#  '🐰': <gensim.models.keyedvectors.Vocab at 0x1a28ada2e8>,
#  '🌃': <gensim.models.keyedvectors.Vocab at 0x1a28ada320>,
#  '🚙': <gensim.models.keyedvectors.Vocab at 0x1a28ada358>,
#  '💊': <gensim.models.keyedvectors.Vocab at 0x1a28ada390>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x1a28ada3c8>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x1a28ada400>,
#  '👙': <gensim.models.keyedvectors.Vocab at 0x1a28ada438>,
#  '🎲': <gensim.models.keyedvectors.Vocab at 0x1a28ada470>,
#  '😖': <gensim.models.keyedvectors.Vocab at 0x1a28ada4a8>,
#  '™': <gensim.models.keyedvectors.Vocab at 0x1a28ada4e0>,
#  '♣': <gensim.models.keyedvectors.Vocab at 0x1a28ada518>,
#  '🤒': <gensim.models.keyedvectors.Vocab at 0x1a28ada550>,
#  '🙀': <gensim.models.keyedvectors.Vocab at 0x1a28ada588>,
#  '👼': <gensim.models.keyedvectors.Vocab at 0x1a28ada5c0>,
#  '💉': <gensim.models.keyedvectors.Vocab at 0x1a28ada5f8>,
#  '🍻': <gensim.models.keyedvectors.Vocab at 0x1a28ada630>,
#  '🗳': <gensim.models.keyedvectors.Vocab at 0x1a28ada668>,
#  '✏': <gensim.models.keyedvectors.Vocab at 0x1a28ada6a0>,
#  '🦊': <gensim.models.keyedvectors.Vocab at 0x1a28ada6d8>,
#  '🐘': <gensim.models.keyedvectors.Vocab at 0x1a28ada710>,
#  '🇽': <gensim.models.keyedvectors.Vocab at 0x1a28ada748>,
#  '🏫': <gensim.models.keyedvectors.Vocab at 0x1a28ada780>,
#  '🍓': <gensim.models.keyedvectors.Vocab at 0x1a28ada7b8>,
#  '🏖': <gensim.models.keyedvectors.Vocab at 0x1a28ada7f0>,
#  '👮': <gensim.models.keyedvectors.Vocab at 0x1a28ada828>,
#  '🤙': <gensim.models.keyedvectors.Vocab at 0x1a28ada860>,
#  '⭕': <gensim.models.keyedvectors.Vocab at 0x1a28ada898>,
#  '❓': <gensim.models.keyedvectors.Vocab at 0x1a28ada8d0>,
#  '☎': <gensim.models.keyedvectors.Vocab at 0x1a28ada908>,
#  '📺': <gensim.models.keyedvectors.Vocab at 0x1a28ada940>,
#  '🔌': <gensim.models.keyedvectors.Vocab at 0x1a28ada978>,
#  '🏈': <gensim.models.keyedvectors.Vocab at 0x1a28ada9b0>,
#  '🌐': <gensim.models.keyedvectors.Vocab at 0x1a28ada9e8>,
#  '🥦': <gensim.models.keyedvectors.Vocab at 0x1a28adaa20>,
#  '🥒': <gensim.models.keyedvectors.Vocab at 0x1a28adaa58>,
#  '🍏': <gensim.models.keyedvectors.Vocab at 0x1a28adaa90>,
#  '🚥': <gensim.models.keyedvectors.Vocab at 0x1a28adaac8>,
#  '🔰': <gensim.models.keyedvectors.Vocab at 0x1a28adab00>,
#  '\U000e007f': <gensim.models.keyedvectors.Vocab at 0x1a28adab38>,
#  '\U000e0073': <gensim.models.keyedvectors.Vocab at 0x1a28adab70>,
#  '\U000e0063': <gensim.models.keyedvectors.Vocab at 0x1a28adaba8>,
#  '\U000e0067': <gensim.models.keyedvectors.Vocab at 0x1a28adabe0>,
#  '\U000e0074': <gensim.models.keyedvectors.Vocab at 0x1a28adac18>,
#  '\U000e0062': <gensim.models.keyedvectors.Vocab at 0x1a28adac50>,
#  '🏴': <gensim.models.keyedvectors.Vocab at 0x1a28adac88>,
#  '🔺': <gensim.models.keyedvectors.Vocab at 0x1a28adacc0>,
#  '🔫': <gensim.models.keyedvectors.Vocab at 0x1a28adacf8>,
#  '☠': <gensim.models.keyedvectors.Vocab at 0x1a28adad30>,
#  '🌛': <gensim.models.keyedvectors.Vocab at 0x1a28adad68>,
#  '▶': <gensim.models.keyedvectors.Vocab at 0x1a28adada0>,
#  '💽': <gensim.models.keyedvectors.Vocab at 0x1a28adadd8>,
#  '😷': <gensim.models.keyedvectors.Vocab at 0x1a28adae10>,
#  '😦': <gensim.models.keyedvectors.Vocab at 0x1a28adae48>,
#  '🐄': <gensim.models.keyedvectors.Vocab at 0x1a28adae80>,
#  '⛵': <gensim.models.keyedvectors.Vocab at 0x1a28adaeb8>,
#  '⛏': <gensim.models.keyedvectors.Vocab at 0x1a28adaef0>,
#  '💧': <gensim.models.keyedvectors.Vocab at 0x1a28adaf28>,
#  '🍮': <gensim.models.keyedvectors.Vocab at 0x1a28adaf60>,
#  '🥧': <gensim.models.keyedvectors.Vocab at 0x1a28adaf98>,
#  '♓': <gensim.models.keyedvectors.Vocab at 0x1a28adafd0>,
#  '🏠': <gensim.models.keyedvectors.Vocab at 0x1a28add048>,
#  '🏭': <gensim.models.keyedvectors.Vocab at 0x1a28add080>,
#  '🏢': <gensim.models.keyedvectors.Vocab at 0x1a28add0b8>,
#  '🤸': <gensim.models.keyedvectors.Vocab at 0x1a28add0f0>,
#  '📀': <gensim.models.keyedvectors.Vocab at 0x1a28add128>,
#  '🏎': <gensim.models.keyedvectors.Vocab at 0x1a28add160>,
#  '🚦': <gensim.models.keyedvectors.Vocab at 0x1a28add198>,
#  '🔗': <gensim.models.keyedvectors.Vocab at 0x1a28add1d0>,
#  '👰': <gensim.models.keyedvectors.Vocab at 0x1a28add208>,
#  '💍': <gensim.models.keyedvectors.Vocab at 0x1a28add240>,
#  '🎟': <gensim.models.keyedvectors.Vocab at 0x1a28add278>,
#  '🎪': <gensim.models.keyedvectors.Vocab at 0x1a28add2b0>,
#  '🆕': <gensim.models.keyedvectors.Vocab at 0x1a28add2e8>,
#  '👕': <gensim.models.keyedvectors.Vocab at 0x1a28add320>,
#  '🍩': <gensim.models.keyedvectors.Vocab at 0x1a28add358>,
#  '🛫': <gensim.models.keyedvectors.Vocab at 0x1a28add390>,
#  '🦄': <gensim.models.keyedvectors.Vocab at 0x1a28add3c8>,
#  '🕊': <gensim.models.keyedvectors.Vocab at 0x1a28add400>,
#  '🙁': <gensim.models.keyedvectors.Vocab at 0x1a28add438>,
#  '🚓': <gensim.models.keyedvectors.Vocab at 0x1a28add470>,
#  '🚑': <gensim.models.keyedvectors.Vocab at 0x1a28add4a8>,
#  '🎯': <gensim.models.keyedvectors.Vocab at 0x1a28add4e0>,
#  '⬅': <gensim.models.keyedvectors.Vocab at 0x1a28add518>,
#  '🇹': <gensim.models.keyedvectors.Vocab at 0x1a28add550>,
#  '®': <gensim.models.keyedvectors.Vocab at 0x1a28add588>,
#  '🐸': <gensim.models.keyedvectors.Vocab at 0x1a28add5c0>,
#  '☕': <gensim.models.keyedvectors.Vocab at 0x1a28add5f8>,
#  '🙇': <gensim.models.keyedvectors.Vocab at 0x1a28add630>,
#  '💒': <gensim.models.keyedvectors.Vocab at 0x1a28add668>,
#  '💏': <gensim.models.keyedvectors.Vocab at 0x1a28add6a0>,
#  '🤵': <gensim.models.keyedvectors.Vocab at 0x1a28add6d8>,
#  '🐙': <gensim.models.keyedvectors.Vocab at 0x1a28add710>,
#  '😐': <gensim.models.keyedvectors.Vocab at 0x1a28add748>,
#  '😟': <gensim.models.keyedvectors.Vocab at 0x1a28add780>,
#  '📈': <gensim.models.keyedvectors.Vocab at 0x1a28add7b8>,
#  '💆': <gensim.models.keyedvectors.Vocab at 0x1a28add7f0>,
#  '🗓': <gensim.models.keyedvectors.Vocab at 0x1a28add828>,
#  '🚂': <gensim.models.keyedvectors.Vocab at 0x1a28add860>,
#  '⏱': <gensim.models.keyedvectors.Vocab at 0x1a28add898>,
#  '⚙': <gensim.models.keyedvectors.Vocab at 0x1a28add8d0>,
#  '↔': <gensim.models.keyedvectors.Vocab at 0x1a28add908>,
#  '🚺': <gensim.models.keyedvectors.Vocab at 0x1a28add940>,
#  '🔉': <gensim.models.keyedvectors.Vocab at 0x1a28add978>,
#  '🤝': <gensim.models.keyedvectors.Vocab at 0x1a28add9b0>,
#  '🍺': <gensim.models.keyedvectors.Vocab at 0x1a28add9e8>,
#  '👢': <gensim.models.keyedvectors.Vocab at 0x1a28adda20>,
#  '🛣': <gensim.models.keyedvectors.Vocab at 0x1a28adda58>,
#  '⛄': <gensim.models.keyedvectors.Vocab at 0x1a28adda90>,
#  '🌬': <gensim.models.keyedvectors.Vocab at 0x1a28addac8>,
#  '🌩': <gensim.models.keyedvectors.Vocab at 0x1a28addb00>,
#  '♠': <gensim.models.keyedvectors.Vocab at 0x1a28addb38>,
#  '🚍': <gensim.models.keyedvectors.Vocab at 0x1a28addb70>,
#  '🌜': <gensim.models.keyedvectors.Vocab at 0x1a28addba8>,
#  '🍹': <gensim.models.keyedvectors.Vocab at 0x1a28addbe0>,
#  '👔': <gensim.models.keyedvectors.Vocab at 0x1a28addc18>,
#  '🌕': <gensim.models.keyedvectors.Vocab at 0x1a28addc50>,
#  '👻': <gensim.models.keyedvectors.Vocab at 0x1a28addc88>,
#  '🍂': <gensim.models.keyedvectors.Vocab at 0x1a28addcc0>,
#  '🎋': <gensim.models.keyedvectors.Vocab at 0x1a28addcf8>,
#  '🕔': <gensim.models.keyedvectors.Vocab at 0x1a28addd30>,
#  '🕑': <gensim.models.keyedvectors.Vocab at 0x1a28addd68>,
#  '🕚': <gensim.models.keyedvectors.Vocab at 0x1a28addda0>,
#  '🕦': <gensim.models.keyedvectors.Vocab at 0x1a28adddd8>,
#  '🕕': <gensim.models.keyedvectors.Vocab at 0x1a28adde10>,
#  '🕖': <gensim.models.keyedvectors.Vocab at 0x1a28adde48>,
#  '🕓': <gensim.models.keyedvectors.Vocab at 0x1a28adde80>,
#  '🕥': <gensim.models.keyedvectors.Vocab at 0x1a28addeb8>,
#  '🕧': <gensim.models.keyedvectors.Vocab at 0x1a28addef0>,
#  '🕐': <gensim.models.keyedvectors.Vocab at 0x1a28addf28>,
#  '🕤': <gensim.models.keyedvectors.Vocab at 0x1a28addf60>,
#  '📃': <gensim.models.keyedvectors.Vocab at 0x1a28addf98>,
#  '🔆': <gensim.models.keyedvectors.Vocab at 0x1a28addfd0>,
#  '⌚': <gensim.models.keyedvectors.Vocab at 0x1a28ae1048>,
#  '🎧': <gensim.models.keyedvectors.Vocab at 0x1a28ae1080>,
#  '⛷': <gensim.models.keyedvectors.Vocab at 0x1a28ae10b8>,
#  '🌄': <gensim.models.keyedvectors.Vocab at 0x1a28ae10f0>,
#  '🎩': <gensim.models.keyedvectors.Vocab at 0x1a28ae1128>,
#  '🔂': <gensim.models.keyedvectors.Vocab at 0x1a28ae1160>,
#  '😪': <gensim.models.keyedvectors.Vocab at 0x1a28ae1198>,
#  '👎': <gensim.models.keyedvectors.Vocab at 0x1a28ae11d0>,
#  '🍡': <gensim.models.keyedvectors.Vocab at 0x1a28ae1208>,
#  '🍨': <gensim.models.keyedvectors.Vocab at 0x1a28ae1240>,
#  '🍧': <gensim.models.keyedvectors.Vocab at 0x1a28ae1278>,
#  '🚔': <gensim.models.keyedvectors.Vocab at 0x1a28ae12b0>,
#  '🚒': <gensim.models.keyedvectors.Vocab at 0x1a28ae12e8>,
#  '🎾': <gensim.models.keyedvectors.Vocab at 0x1a28ae1320>,
#  '🌋': <gensim.models.keyedvectors.Vocab at 0x1a28ae1358>,
#  '💼': <gensim.models.keyedvectors.Vocab at 0x1a28ae1390>,
#  '🥈': <gensim.models.keyedvectors.Vocab at 0x1a28ae13c8>,
#  '⛓': <gensim.models.keyedvectors.Vocab at 0x1a28ae1400>,
#  '🥉': <gensim.models.keyedvectors.Vocab at 0x1a28ae1438>,
#  '👃': <gensim.models.keyedvectors.Vocab at 0x1a28ae1470>,
#  '🖌': <gensim.models.keyedvectors.Vocab at 0x1a28ae14a8>,
#  '🍅': <gensim.models.keyedvectors.Vocab at 0x1a28ae14e0>,
#  '🥟': <gensim.models.keyedvectors.Vocab at 0x1a28ae1518>,
#  '🥐': <gensim.models.keyedvectors.Vocab at 0x1a28ae1550>,
#  '🌮': <gensim.models.keyedvectors.Vocab at 0x1a28ae1588>,
#  '🍣': <gensim.models.keyedvectors.Vocab at 0x1a28ae15c0>,
#  '🦇': <gensim.models.keyedvectors.Vocab at 0x1a28ae15f8>,
#  '🗒': <gensim.models.keyedvectors.Vocab at 0x1a28ae1630>,
#  '🖍': <gensim.models.keyedvectors.Vocab at 0x1a28ae1668>,
#  '🗞': <gensim.models.keyedvectors.Vocab at 0x1a28ae16a0>,
#  '🚘': <gensim.models.keyedvectors.Vocab at 0x1a28ae16d8>,
#  '🚣': <gensim.models.keyedvectors.Vocab at 0x1a28ae1710>,
#  '🅰': <gensim.models.keyedvectors.Vocab at 0x1a28ae1748>,
#  '🅿': <gensim.models.keyedvectors.Vocab at 0x1a28ae1780>,
#  '📧': <gensim.models.keyedvectors.Vocab at 0x1a28ae17b8>,
#  '©': <gensim.models.keyedvectors.Vocab at 0x1a28ae17f0>,
#  '🔛': <gensim.models.keyedvectors.Vocab at 0x1a28ae1828>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x1a28ae1860>,
#  '⬇': <gensim.models.keyedvectors.Vocab at 0x1a28ae1898>,
#  '✖': <gensim.models.keyedvectors.Vocab at 0x1a28ae18d0>,
#  '🔮': <gensim.models.keyedvectors.Vocab at 0x1a28ae1908>,
#  '🗿': <gensim.models.keyedvectors.Vocab at 0x1a28ae1940>,
#  '🎒': <gensim.models.keyedvectors.Vocab at 0x1a28ae1978>,
#  '⚫': <gensim.models.keyedvectors.Vocab at 0x1a28ae19b0>,
#  '🍱': <gensim.models.keyedvectors.Vocab at 0x1a28ae19e8>,
#  '🧐': <gensim.models.keyedvectors.Vocab at 0x1a28ae1a20>,
#  '⛪': <gensim.models.keyedvectors.Vocab at 0x1a28ae1a58>,
#  '🗡': <gensim.models.keyedvectors.Vocab at 0x1a28ae1a90>,
#  '🏋': <gensim.models.keyedvectors.Vocab at 0x1a28ae1ac8>,
#  '🐼': <gensim.models.keyedvectors.Vocab at 0x1a28ae1b00>,
#  '🚌': <gensim.models.keyedvectors.Vocab at 0x1a28ae1b38>,
#  '💇': <gensim.models.keyedvectors.Vocab at 0x1a28ae1b70>,
#  '🏉': <gensim.models.keyedvectors.Vocab at 0x1a28ae1ba8>,
#  '⚔': <gensim.models.keyedvectors.Vocab at 0x1a28ae1be0>,
#  '☝': <gensim.models.keyedvectors.Vocab at 0x1a28ae1c18>,
#  '🌔': <gensim.models.keyedvectors.Vocab at 0x1a28ae1c50>,
#  '⤵': <gensim.models.keyedvectors.Vocab at 0x1a28ae1c88>,
#  '💵': <gensim.models.keyedvectors.Vocab at 0x1a28ae1cc0>,
#  '☄': <gensim.models.keyedvectors.Vocab at 0x1a28ae1cf8>,
#  '🐺': <gensim.models.keyedvectors.Vocab at 0x1a28ae1d30>,
#  '🧕': <gensim.models.keyedvectors.Vocab at 0x1a28ae1d68>,
#  '🐉': <gensim.models.keyedvectors.Vocab at 0x1a28ae1da0>,
#  '🆙': <gensim.models.keyedvectors.Vocab at 0x1a28ae1dd8>,
#  '🧙': <gensim.models.keyedvectors.Vocab at 0x1a28ae1e10>,
#  '👿': <gensim.models.keyedvectors.Vocab at 0x1a28ae1e48>,
#  '🤳': <gensim.models.keyedvectors.Vocab at 0x1a28ae1e80>,
#  '🐂': <gensim.models.keyedvectors.Vocab at 0x1a28ae1eb8>,
#  '👤': <gensim.models.keyedvectors.Vocab at 0x1a28ae1ef0>,
#  '🌽': <gensim.models.keyedvectors.Vocab at 0x1a28ae1f28>,
#  '🇴': <gensim.models.keyedvectors.Vocab at 0x1a28ae1f60>,
#  '🤐': <gensim.models.keyedvectors.Vocab at 0x1a28ae1f98>,
#  '🗝': <gensim.models.keyedvectors.Vocab at 0x1a28ae1fd0>,
#  '🌲': <gensim.models.keyedvectors.Vocab at 0x1a28ae4048>,
#  '🌀': <gensim.models.keyedvectors.Vocab at 0x1a28ae4080>,
#  '🔚': <gensim.models.keyedvectors.Vocab at 0x1a28ae40b8>,
#  '🍖': <gensim.models.keyedvectors.Vocab at 0x1a28ae40f0>,
#  '🐚': <gensim.models.keyedvectors.Vocab at 0x1a28ae4128>,
#  '☘': <gensim.models.keyedvectors.Vocab at 0x1a28ae4160>,
#  '⛈': <gensim.models.keyedvectors.Vocab at 0x1a28ae4198>,
#  '⚖': <gensim.models.keyedvectors.Vocab at 0x1a28ae41d0>,
#  '📵': <gensim.models.keyedvectors.Vocab at 0x1a28ae4208>,
#  '🔐': <gensim.models.keyedvectors.Vocab at 0x1a28ae4240>,
#  '🦕': <gensim.models.keyedvectors.Vocab at 0x1a28ae4278>,
#  '👐': <gensim.models.keyedvectors.Vocab at 0x1a28ae42b0>,
#  '👓': <gensim.models.keyedvectors.Vocab at 0x1a28ae42e8>,
#  '🧦': <gensim.models.keyedvectors.Vocab at 0x1a28ae4320>,
#  '🥃': <gensim.models.keyedvectors.Vocab at 0x1a28ae4358>,
#  '🎡': <gensim.models.keyedvectors.Vocab at 0x1a28ae4390>,
#  '☸': <gensim.models.keyedvectors.Vocab at 0x1a28ae43c8>,
#  '🏹': <gensim.models.keyedvectors.Vocab at 0x1a28ae4400>,
#  '⌛': <gensim.models.keyedvectors.Vocab at 0x1a28ae4438>,
#  '🥜': <gensim.models.keyedvectors.Vocab at 0x1a28ae4470>,
#  '💠': <gensim.models.keyedvectors.Vocab at 0x1a28ae44a8>,
#  '🦆': <gensim.models.keyedvectors.Vocab at 0x1a28ae44e0>,
#  '✡': <gensim.models.keyedvectors.Vocab at 0x1a28ae4518>,
#  '🕳': <gensim.models.keyedvectors.Vocab at 0x1a28ae4550>,
#  '👽': <gensim.models.keyedvectors.Vocab at 0x1a28ae4588>,
#  '⚾': <gensim.models.keyedvectors.Vocab at 0x1a28ae45c0>,
#  '🗻': <gensim.models.keyedvectors.Vocab at 0x1a28ae45f8>,
#  '🏰': <gensim.models.keyedvectors.Vocab at 0x1a28ae4630>,
#  '🍴': <gensim.models.keyedvectors.Vocab at 0x1a28ae4668>,
#  '🔱': <gensim.models.keyedvectors.Vocab at 0x1a28ae46a0>,
#  '🚹': <gensim.models.keyedvectors.Vocab at 0x1a28ae46d8>,
#  '⛽': <gensim.models.keyedvectors.Vocab at 0x1a28ae4710>,
#  '🥓': <gensim.models.keyedvectors.Vocab at 0x1a28ae4748>,
#  '🥪': <gensim.models.keyedvectors.Vocab at 0x1a28ae4780>,
#  '🥨': <gensim.models.keyedvectors.Vocab at 0x1a28ae47b8>,
#  '🥖': <gensim.models.keyedvectors.Vocab at 0x1a28ae47f0>,
#  '🐞': <gensim.models.keyedvectors.Vocab at 0x1a28ae4828>,
#  '🍎': <gensim.models.keyedvectors.Vocab at 0x1a28ae4860>,
#  '☹': <gensim.models.keyedvectors.Vocab at 0x1a28ae4898>,
#  '⛹': <gensim.models.keyedvectors.Vocab at 0x1a28ae48d0>,
#  '🤚': <gensim.models.keyedvectors.Vocab at 0x1a28ae4908>,
#  '🌭': <gensim.models.keyedvectors.Vocab at 0x1a28ae4940>,
#  '🦉': <gensim.models.keyedvectors.Vocab at 0x1a28ae4978>,
#  '🛡': <gensim.models.keyedvectors.Vocab at 0x1a28ae49b0>,
#  '🍯': <gensim.models.keyedvectors.Vocab at 0x1a28ae49e8>,
#  '🕹': <gensim.models.keyedvectors.Vocab at 0x1a28ae4a20>,
#  '🌇': <gensim.models.keyedvectors.Vocab at 0x1a28ae4a58>,
#  '👞': <gensim.models.keyedvectors.Vocab at 0x1a28ae4a90>,
#  '🤛': <gensim.models.keyedvectors.Vocab at 0x1a28ae4ac8>,
#  '🐟': <gensim.models.keyedvectors.Vocab at 0x1a28ae4b00>,
#  '🔽': <gensim.models.keyedvectors.Vocab at 0x1a28ae4b38>,
#  '👆': <gensim.models.keyedvectors.Vocab at 0x1a28ae4b70>,
#  '🏨': <gensim.models.keyedvectors.Vocab at 0x1a28ae4ba8>,
#  '🏥': <gensim.models.keyedvectors.Vocab at 0x1a28ae4be0>,
#  '🔢': <gensim.models.keyedvectors.Vocab at 0x1a28ae4c18>,
#  '⚛': <gensim.models.keyedvectors.Vocab at 0x1a28ae4c50>,
#  '🐨': <gensim.models.keyedvectors.Vocab at 0x1a28ae4c88>,
#  '\U000e0065': <gensim.models.keyedvectors.Vocab at 0x1a28ae4cc0>,
#  '\U000e006e': <gensim.models.keyedvectors.Vocab at 0x1a28ae4cf8>,
#  '🎺': <gensim.models.keyedvectors.Vocab at 0x1a28ae4d30>,
#  '🍼': <gensim.models.keyedvectors.Vocab at 0x1a28ae4d68>,
#  '⬛': <gensim.models.keyedvectors.Vocab at 0x1a28ae4da0>,
#  '😗': <gensim.models.keyedvectors.Vocab at 0x1a28ae4dd8>,
#  '🕋': <gensim.models.keyedvectors.Vocab at 0x1a28ae4e10>,
#  '📿': <gensim.models.keyedvectors.Vocab at 0x1a28ae4e48>,
#  '🚢': <gensim.models.keyedvectors.Vocab at 0x1a28ae4e80>,
#  '🥞': <gensim.models.keyedvectors.Vocab at 0x1a28ae4eb8>,
#  '🐹': <gensim.models.keyedvectors.Vocab at 0x1a28ae4ef0>,
#  '🥕': <gensim.models.keyedvectors.Vocab at 0x1a28ae4f28>,
#  '🤰': <gensim.models.keyedvectors.Vocab at 0x1a28ae4f60>,
#  '⁉': <gensim.models.keyedvectors.Vocab at 0x1a28ae4f98>,
#  '💲': <gensim.models.keyedvectors.Vocab at 0x1a28ae4fd0>,
#  '♑': <gensim.models.keyedvectors.Vocab at 0x1a28ae7048>,
#  '🐋': <gensim.models.keyedvectors.Vocab at 0x1a28ae7080>,
#  '🐳': <gensim.models.keyedvectors.Vocab at 0x1a28ae70b8>,
#  '🦑': <gensim.models.keyedvectors.Vocab at 0x1a28ae70f0>,
#  '🦀': <gensim.models.keyedvectors.Vocab at 0x1a28ae7128>,
#  '◾': <gensim.models.keyedvectors.Vocab at 0x1a28ae7160>,
#  '🔶': <gensim.models.keyedvectors.Vocab at 0x1a28ae7198>,
#  '⏩': <gensim.models.keyedvectors.Vocab at 0x1a28ae71d0>,
#  '🐅': <gensim.models.keyedvectors.Vocab at 0x1a28ae7208>,
#  '🤨': <gensim.models.keyedvectors.Vocab at 0x1a28ae7240>,
#  '👷': <gensim.models.keyedvectors.Vocab at 0x1a28ae7278>,
#  '🏘': <gensim.models.keyedvectors.Vocab at 0x1a28ae72b0>,
#  '🌪': <gensim.models.keyedvectors.Vocab at 0x1a28ae72e8>,
#  '🧛': <gensim.models.keyedvectors.Vocab at 0x1a28ae7320>,
#  '✂': <gensim.models.keyedvectors.Vocab at 0x1a28ae7358>,
#  '🔷': <gensim.models.keyedvectors.Vocab at 0x1a28ae7390>,
#  '🔍': <gensim.models.keyedvectors.Vocab at 0x1a28ae73c8>,
#  '🔎': <gensim.models.keyedvectors.Vocab at 0x1a28ae7400>,
#  '🌯': <gensim.models.keyedvectors.Vocab at 0x1a28ae7438>,
#  '✝': <gensim.models.keyedvectors.Vocab at 0x1a28ae7470>,
#  '➕': <gensim.models.keyedvectors.Vocab at 0x1a28ae74a8>,
#  '🖖': <gensim.models.keyedvectors.Vocab at 0x1a28ae74e0>,
#  '⚰': <gensim.models.keyedvectors.Vocab at 0x1a28ae7518>,
#  '👾': <gensim.models.keyedvectors.Vocab at 0x1a28ae7550>,
#  '⛩': <gensim.models.keyedvectors.Vocab at 0x1a28ae7588>,
#  '🧥': <gensim.models.keyedvectors.Vocab at 0x1a28ae75c0>,
#  '📮': <gensim.models.keyedvectors.Vocab at 0x1a28ae75f8>,
#  '🎠': <gensim.models.keyedvectors.Vocab at 0x1a28ae7630>,
#  '🎭': <gensim.models.keyedvectors.Vocab at 0x1a28ae7668>,
#  '🎢': <gensim.models.keyedvectors.Vocab at 0x1a28ae76a0>,
#  '😼': <gensim.models.keyedvectors.Vocab at 0x1a28ae76d8>,
#  '🤲': <gensim.models.keyedvectors.Vocab at 0x1a28ae7710>,
#  '🧜': <gensim.models.keyedvectors.Vocab at 0x1a28ae7748>,
#  '🚬': <gensim.models.keyedvectors.Vocab at 0x1a28ae7780>,
#  '🏇': <gensim.models.keyedvectors.Vocab at 0x1a28ae77b8>,
#  '🎄': <gensim.models.keyedvectors.Vocab at 0x1a28ae77f0>,
#  '🗂': <gensim.models.keyedvectors.Vocab at 0x1a28ae7828>,
#  '🐀': <gensim.models.keyedvectors.Vocab at 0x1a28ae7860>,
#  '🔸': <gensim.models.keyedvectors.Vocab at 0x1a28ae7898>,
#  '👚': <gensim.models.keyedvectors.Vocab at 0x1a28ae78d0>,
#  '👡': <gensim.models.keyedvectors.Vocab at 0x1a28ae7908>,
#  '👖': <gensim.models.keyedvectors.Vocab at 0x1a28ae7940>,
#  '👜': <gensim.models.keyedvectors.Vocab at 0x1a28ae7978>,
#  '🎞': <gensim.models.keyedvectors.Vocab at 0x1a28ae79b0>,
#  '♻': <gensim.models.keyedvectors.Vocab at 0x1a28ae79e8>,
#  '😓': <gensim.models.keyedvectors.Vocab at 0x1a28ae7a20>,
#  '📣': <gensim.models.keyedvectors.Vocab at 0x1a28ae7a58>,
#  '✴': <gensim.models.keyedvectors.Vocab at 0x1a28ae7a90>,
#  '🐭': <gensim.models.keyedvectors.Vocab at 0x1a28ae7ac8>,
#  '🚧': <gensim.models.keyedvectors.Vocab at 0x1a28ae7b00>,
#  '♏': <gensim.models.keyedvectors.Vocab at 0x1a28ae7b38>,
#  '🆖': <gensim.models.keyedvectors.Vocab at 0x1a28ae7b70>,
#  '💩': <gensim.models.keyedvectors.Vocab at 0x1a28ae7ba8>,
#  '🍍': <gensim.models.keyedvectors.Vocab at 0x1a28ae7be0>,
#  '🚁': <gensim.models.keyedvectors.Vocab at 0x1a28ae7c18>,
#  '🌘': <gensim.models.keyedvectors.Vocab at 0x1a28ae7c50>,
#  '🍛': <gensim.models.keyedvectors.Vocab at 0x1a28ae7c88>,
#  '🎅': <gensim.models.keyedvectors.Vocab at 0x1a28ae7cc0>,
#  '🚿': <gensim.models.keyedvectors.Vocab at 0x1a28ae7cf8>,
#  '🚐': <gensim.models.keyedvectors.Vocab at 0x1a28ae7d30>,
#  '🎌': <gensim.models.keyedvectors.Vocab at 0x1a28ae7d68>,
#  '🎣': <gensim.models.keyedvectors.Vocab at 0x1a28ae7da0>,
#  '♿': <gensim.models.keyedvectors.Vocab at 0x1a28ae7dd8>,
#  '🌵': <gensim.models.keyedvectors.Vocab at 0x1a28ae7e10>,
#  '✒': <gensim.models.keyedvectors.Vocab at 0x1a28ae7e48>,
#  '📂': <gensim.models.keyedvectors.Vocab at 0x1a28ae7e80>,
#  '🔒': <gensim.models.keyedvectors.Vocab at 0x1a28ae7eb8>,
#  '👬': <gensim.models.keyedvectors.Vocab at 0x1a28ae7ef0>,
#  '📦': <gensim.models.keyedvectors.Vocab at 0x1a28ae7f28>,
#  '🏚': <gensim.models.keyedvectors.Vocab at 0x1a28ae7f60>,
#  '✈': <gensim.models.keyedvectors.Vocab at 0x1a28ae7f98>,
#  '🐓': <gensim.models.keyedvectors.Vocab at 0x1a28ae7fd0>,
#  '🛁': <gensim.models.keyedvectors.Vocab at 0x1a28aec048>,
#  '▪': <gensim.models.keyedvectors.Vocab at 0x1a28aec080>,
#  '➖': <gensim.models.keyedvectors.Vocab at 0x1a28aec0b8>,
#  '⛴': <gensim.models.keyedvectors.Vocab at 0x1a28aec0f0>,
#  '🍢': <gensim.models.keyedvectors.Vocab at 0x1a28aec128>,
#  '🐮': <gensim.models.keyedvectors.Vocab at 0x1a28aec160>,
#  '♌': <gensim.models.keyedvectors.Vocab at 0x1a28aec198>,
#  '🧟': <gensim.models.keyedvectors.Vocab at 0x1a28aec1d0>,
#  '🤬': <gensim.models.keyedvectors.Vocab at 0x1a28aec208>,
#  '💳': <gensim.models.keyedvectors.Vocab at 0x1a28aec240>,
#  '📊': <gensim.models.keyedvectors.Vocab at 0x1a28aec278>,
#  '🕉': <gensim.models.keyedvectors.Vocab at 0x1a28aec2b0>,
#  '🧘': <gensim.models.keyedvectors.Vocab at 0x1a28aec2e8>,
#  '🐩': <gensim.models.keyedvectors.Vocab at 0x1a28aec320>,
#  '💴': <gensim.models.keyedvectors.Vocab at 0x1a28aec358>,
#  '▫': <gensim.models.keyedvectors.Vocab at 0x1a28aec390>,
#  '📙': <gensim.models.keyedvectors.Vocab at 0x1a28aec3c8>,
#  '📓': <gensim.models.keyedvectors.Vocab at 0x1a28aec400>,
#  '🛅': <gensim.models.keyedvectors.Vocab at 0x1a28aec438>,
#  '🥋': <gensim.models.keyedvectors.Vocab at 0x1a28aec470>,
#  '🎍': <gensim.models.keyedvectors.Vocab at 0x1a28aec4a8>,
#  '🖥': <gensim.models.keyedvectors.Vocab at 0x1a28aec4e0>,
#  '🆒': <gensim.models.keyedvectors.Vocab at 0x1a28aec518>,
#  '🦖': <gensim.models.keyedvectors.Vocab at 0x1a28aec550>,
#  '🤼': <gensim.models.keyedvectors.Vocab at 0x1a28aec588>,
#  '🐿': <gensim.models.keyedvectors.Vocab at 0x1a28aec5c0>,
#  '🔭': <gensim.models.keyedvectors.Vocab at 0x1a28aec5f8>,
#  '🍄': <gensim.models.keyedvectors.Vocab at 0x1a28aec630>,
#  '🚾': <gensim.models.keyedvectors.Vocab at 0x1a28aec668>,
#  '🛒': <gensim.models.keyedvectors.Vocab at 0x1a28aec6a0>,
#  '◽': <gensim.models.keyedvectors.Vocab at 0x1a28aec6d8>,
#  '🔙': <gensim.models.keyedvectors.Vocab at 0x1a28aec710>,
#  '🍶': <gensim.models.keyedvectors.Vocab at 0x1a28aec748>,
#  '🔄': <gensim.models.keyedvectors.Vocab at 0x1a28aec780>,
#  '✉': <gensim.models.keyedvectors.Vocab at 0x1a28aec7b8>,
#  '🎐': <gensim.models.keyedvectors.Vocab at 0x1a28aec7f0>,
#  '🍚': <gensim.models.keyedvectors.Vocab at 0x1a28aec828>,
#  '⏳': <gensim.models.keyedvectors.Vocab at 0x1a28aec860>,
#  '🆚': <gensim.models.keyedvectors.Vocab at 0x1a28aec898>,
#  '💹': <gensim.models.keyedvectors.Vocab at 0x1a28aec8d0>,
#  '☪': <gensim.models.keyedvectors.Vocab at 0x1a28aec908>,
#  '🤱': <gensim.models.keyedvectors.Vocab at 0x1a28aec940>,
#  '🔦': <gensim.models.keyedvectors.Vocab at 0x1a28aec978>,
#  '📎': <gensim.models.keyedvectors.Vocab at 0x1a28aec9b0>,
#  '☢': <gensim.models.keyedvectors.Vocab at 0x1a28aec9e8>,
#  '🗼': <gensim.models.keyedvectors.Vocab at 0x1a28aeca20>,
#  '👒': <gensim.models.keyedvectors.Vocab at 0x1a28aeca58>,
#  '♨': <gensim.models.keyedvectors.Vocab at 0x1a28aeca90>,
#  '🥘': <gensim.models.keyedvectors.Vocab at 0x1a28aecac8>,
#  '👛': <gensim.models.keyedvectors.Vocab at 0x1a28aecb00>,
#  '😧': <gensim.models.keyedvectors.Vocab at 0x1a28aecb38>,
#  '🥝': <gensim.models.keyedvectors.Vocab at 0x1a28aecb70>,
#  '📔': <gensim.models.keyedvectors.Vocab at 0x1a28aecba8>,
#  '📞': <gensim.models.keyedvectors.Vocab at 0x1a28aecbe0>,
#  '🐡': <gensim.models.keyedvectors.Vocab at 0x1a28aecc18>,
#  '😿': <gensim.models.keyedvectors.Vocab at 0x1a28aecc50>,
#  '🏑': <gensim.models.keyedvectors.Vocab at 0x1a28aecc88>,
#  '◼': <gensim.models.keyedvectors.Vocab at 0x1a28aeccc0>,
#  '🍲': <gensim.models.keyedvectors.Vocab at 0x1a28aeccf8>,
#  '❇': <gensim.models.keyedvectors.Vocab at 0x1a28aecd30>,
#  '🌗': <gensim.models.keyedvectors.Vocab at 0x1a28aecd68>,
#  '🌖': <gensim.models.keyedvectors.Vocab at 0x1a28aecda0>,
#  '🙎': <gensim.models.keyedvectors.Vocab at 0x1a28aecdd8>,
#  '❎': <gensim.models.keyedvectors.Vocab at 0x1a28aece10>,
#  '♦': <gensim.models.keyedvectors.Vocab at 0x1a28aece48>,
#  '🍵': <gensim.models.keyedvectors.Vocab at 0x1a28aece80>,
#  '⛰': <gensim.models.keyedvectors.Vocab at 0x1a28aeceb8>,
#  '🇶': <gensim.models.keyedvectors.Vocab at 0x1a28aecef0>,
#  '🐒': <gensim.models.keyedvectors.Vocab at 0x1a28aecf28>,
#  '⚒': <gensim.models.keyedvectors.Vocab at 0x1a28aecf60>,
#  '🌫': <gensim.models.keyedvectors.Vocab at 0x1a28aecf98>,
#  '🥣': <gensim.models.keyedvectors.Vocab at 0x1a28aecfd0>,
#  '⛅': <gensim.models.keyedvectors.Vocab at 0x1a28aef048>,
#  '🛬': <gensim.models.keyedvectors.Vocab at 0x1a28aef080>,
#  '🥢': <gensim.models.keyedvectors.Vocab at 0x1a28aef0b8>,
#  '🍤': <gensim.models.keyedvectors.Vocab at 0x1a28aef0f0>,
#  '📅': <gensim.models.keyedvectors.Vocab at 0x1a28aef128>,
#  '🇼': <gensim.models.keyedvectors.Vocab at 0x1a28aef160>,
#  '🎱': <gensim.models.keyedvectors.Vocab at 0x1a28aef198>,
#  '🦃': <gensim.models.keyedvectors.Vocab at 0x1a28aef1d0>,
#  '🏸': <gensim.models.keyedvectors.Vocab at 0x1a28aef208>,
#  '🌓': <gensim.models.keyedvectors.Vocab at 0x1a28aef240>,
#  '🏙': <gensim.models.keyedvectors.Vocab at 0x1a28aef278>,
#  '👴': <gensim.models.keyedvectors.Vocab at 0x1a28aef2b0>,
#  '🚰': <gensim.models.keyedvectors.Vocab at 0x1a28aef2e8>,
#  '🧒': <gensim.models.keyedvectors.Vocab at 0x1a28aef320>,
#  '🎰': <gensim.models.keyedvectors.Vocab at 0x1a28aef358>,
#  '🔹': <gensim.models.keyedvectors.Vocab at 0x1a28aef390>,
#  '☁': <gensim.models.keyedvectors.Vocab at 0x1a28aef3c8>,
#  '⬆': <gensim.models.keyedvectors.Vocab at 0x1a28aef400>,
#  '🎃': <gensim.models.keyedvectors.Vocab at 0x1a28aef438>,
#  '📍': <gensim.models.keyedvectors.Vocab at 0x1a28aef470>,
#  '🛰': <gensim.models.keyedvectors.Vocab at 0x1a28aef4a8>,
#  '📜': <gensim.models.keyedvectors.Vocab at 0x1a28aef4e0>,
#  '⚗': <gensim.models.keyedvectors.Vocab at 0x1a28aef518>,
#  '🐖': <gensim.models.keyedvectors.Vocab at 0x1a28aef550>,
#  '♊': <gensim.models.keyedvectors.Vocab at 0x1a28aef588>,
#  '🧔': <gensim.models.keyedvectors.Vocab at 0x1a28aef5c0>,
#  '🛵': <gensim.models.keyedvectors.Vocab at 0x1a28aef5f8>,
#  '🛏': <gensim.models.keyedvectors.Vocab at 0x1a28aef630>,
#  '🏪': <gensim.models.keyedvectors.Vocab at 0x1a28aef668>,
#  '🚵': <gensim.models.keyedvectors.Vocab at 0x1a28aef6a0>,
#  '🦐': <gensim.models.keyedvectors.Vocab at 0x1a28aef6d8>,
#  '📒': <gensim.models.keyedvectors.Vocab at 0x1a28aef710>,
#  '🇻': <gensim.models.keyedvectors.Vocab at 0x1a28aef748>,
#  '☑': <gensim.models.keyedvectors.Vocab at 0x1a28aef780>,
#  '🖼': <gensim.models.keyedvectors.Vocab at 0x1a28aef7b8>,
#  '🎽': <gensim.models.keyedvectors.Vocab at 0x1a28aef7f0>,
#  '👝': <gensim.models.keyedvectors.Vocab at 0x1a28aef828>,
#  '🐜': <gensim.models.keyedvectors.Vocab at 0x1a28aef860>,
#  '📼': <gensim.models.keyedvectors.Vocab at 0x1a28aef898>,
#  '🎗': <gensim.models.keyedvectors.Vocab at 0x1a28aef8d0>,
#  '🔓': <gensim.models.keyedvectors.Vocab at 0x1a28aef908>,
#  '🅾': <gensim.models.keyedvectors.Vocab at 0x1a28aef940>,
#  '🅱': <gensim.models.keyedvectors.Vocab at 0x1a28aef978>,
#  '⌨': <gensim.models.keyedvectors.Vocab at 0x1a28aef9b0>,
#  '🕰': <gensim.models.keyedvectors.Vocab at 0x1a28aef9e8>,
#  '🐏': <gensim.models.keyedvectors.Vocab at 0x1a28aefa20>,
#  '🛩': <gensim.models.keyedvectors.Vocab at 0x1a28aefa58>,
#  '🌒': <gensim.models.keyedvectors.Vocab at 0x1a28aefa90>,
#  '🧗': <gensim.models.keyedvectors.Vocab at 0x1a28aefac8>,
#  '🐆': <gensim.models.keyedvectors.Vocab at 0x1a28aefb00>,
#  '🛳': <gensim.models.keyedvectors.Vocab at 0x1a28aefb38>,
#  '🍈': <gensim.models.keyedvectors.Vocab at 0x1a28aefb70>,
#  '🛌': <gensim.models.keyedvectors.Vocab at 0x1a28aefba8>,
#  '👪': <gensim.models.keyedvectors.Vocab at 0x1a28aefbe0>,
#  '🏵': <gensim.models.keyedvectors.Vocab at 0x1a28aefc18>,
#  '🖋': <gensim.models.keyedvectors.Vocab at 0x1a28aefc50>,
#  '🗑': <gensim.models.keyedvectors.Vocab at 0x1a28aefc88>,
#  '🐲': <gensim.models.keyedvectors.Vocab at 0x1a28aefcc0>,
#  '⛱': <gensim.models.keyedvectors.Vocab at 0x1a28aefcf8>,
#  '🛋': <gensim.models.keyedvectors.Vocab at 0x1a28aefd30>,
#  '🆎': <gensim.models.keyedvectors.Vocab at 0x1a28aefd68>,
#  '📯': <gensim.models.keyedvectors.Vocab at 0x1a28aefda0>,
#  '🏷': <gensim.models.keyedvectors.Vocab at 0x1a28aefdd8>,
#  'Ⓜ': <gensim.models.keyedvectors.Vocab at 0x1a28aefe10>,
#  '🐛': <gensim.models.keyedvectors.Vocab at 0x1a28aefe48>,
#  '🏂': <gensim.models.keyedvectors.Vocab at 0x1a28aefe80>,
#  '🕸': <gensim.models.keyedvectors.Vocab at 0x1a28aefeb8>,
#  '🧝': <gensim.models.keyedvectors.Vocab at 0x1a28aefef0>,
#  '🚜': <gensim.models.keyedvectors.Vocab at 0x1a28aeff28>,
#  '🚤': <gensim.models.keyedvectors.Vocab at 0x1a28aeff60>,
#  '🛥': <gensim.models.keyedvectors.Vocab at 0x1a28aeff98>,
#  '🧑': <gensim.models.keyedvectors.Vocab at 0x1a28aeffd0>,
#  '🃏': <gensim.models.keyedvectors.Vocab at 0x1a28af3048>,
#  '🚷': <gensim.models.keyedvectors.Vocab at 0x1a28af3080>,
#  '🥑': <gensim.models.keyedvectors.Vocab at 0x1a28af30b8>,
#  '♋': <gensim.models.keyedvectors.Vocab at 0x1a28af30f0>,
#  '🐁': <gensim.models.keyedvectors.Vocab at 0x1a28af3128>,
#  '🗺': <gensim.models.keyedvectors.Vocab at 0x1a28af3160>,
#  '👘': <gensim.models.keyedvectors.Vocab at 0x1a28af3198>,
#  '📥': <gensim.models.keyedvectors.Vocab at 0x1a28af31d0>,
#  '🆑': <gensim.models.keyedvectors.Vocab at 0x1a28af3208>,
#  '➰': <gensim.models.keyedvectors.Vocab at 0x1a28af3240>,
#  '🦓': <gensim.models.keyedvectors.Vocab at 0x1a28af3278>,
#  '💈': <gensim.models.keyedvectors.Vocab at 0x1a28af32b0>,
#  '🖊': <gensim.models.keyedvectors.Vocab at 0x1a28af32e8>,
#  '⛺': <gensim.models.keyedvectors.Vocab at 0x1a28af3320>,
#  '🐌': <gensim.models.keyedvectors.Vocab at 0x1a28af3358>,
#  '🐫': <gensim.models.keyedvectors.Vocab at 0x1a28af3390>,
#  '\U000e0077': <gensim.models.keyedvectors.Vocab at 0x1a28af33c8>,
#  '\U000e006c': <gensim.models.keyedvectors.Vocab at 0x1a28af3400>,
#  '🧤': <gensim.models.keyedvectors.Vocab at 0x1a28af3438>,
#  '🍐': <gensim.models.keyedvectors.Vocab at 0x1a28af3470>,
#  '📩': <gensim.models.keyedvectors.Vocab at 0x1a28af34a8>,
#  '🔃': <gensim.models.keyedvectors.Vocab at 0x1a28af34e0>,
#  '📘': <gensim.models.keyedvectors.Vocab at 0x1a28af3518>,
#  '🧖': <gensim.models.keyedvectors.Vocab at 0x1a28af3550>,
#  '🌑': <gensim.models.keyedvectors.Vocab at 0x1a28af3588>,
#  '🤥': <gensim.models.keyedvectors.Vocab at 0x1a28af35c0>,
#  '✳': <gensim.models.keyedvectors.Vocab at 0x1a28af35f8>,
#  '📶': <gensim.models.keyedvectors.Vocab at 0x1a28af3630>,
#  '🌰': <gensim.models.keyedvectors.Vocab at 0x1a28af3668>,
#  '🏧': <gensim.models.keyedvectors.Vocab at 0x1a28af36a0>,
#  '🛤': <gensim.models.keyedvectors.Vocab at 0x1a28af36d8>,
#  '🔧': <gensim.models.keyedvectors.Vocab at 0x1a28af3710>,
#  '🤹': <gensim.models.keyedvectors.Vocab at 0x1a28af3748>,
#  '📏': <gensim.models.keyedvectors.Vocab at 0x1a28af3780>,
#  '☃': <gensim.models.keyedvectors.Vocab at 0x1a28af37b8>,
#  '⛲': <gensim.models.keyedvectors.Vocab at 0x1a28af37f0>,
#  '⚕': <gensim.models.keyedvectors.Vocab at 0x1a28af3828>,
#  '🀄': <gensim.models.keyedvectors.Vocab at 0x1a28af3860>,
#  '🚽': <gensim.models.keyedvectors.Vocab at 0x1a28af3898>,
#  '🧓': <gensim.models.keyedvectors.Vocab at 0x1a28af38d0>,
#  '♈': <gensim.models.keyedvectors.Vocab at 0x1a28af3908>,
#  '🍥': <gensim.models.keyedvectors.Vocab at 0x1a28af3940>,
#  '🦔': <gensim.models.keyedvectors.Vocab at 0x1a28af3978>,
#  '🥙': <gensim.models.keyedvectors.Vocab at 0x1a28af39b0>,
#  '🚅': <gensim.models.keyedvectors.Vocab at 0x1a28af39e8>,
#  '🚋': <gensim.models.keyedvectors.Vocab at 0x1a28af3a20>,
#  '🦂': <gensim.models.keyedvectors.Vocab at 0x1a28af3a58>,
#  ...}

# %%
thrones2vec.train(emojiSequences, total_examples=thrones2vec.corpus_count, epochs = 1)
# Out:
# 2019-01-14 10:15:50,195 : INFO : training model with 12 workers on 1082 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=2
# 2019-01-14 10:15:50,487 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-01-14 10:15:50,490 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-01-14 10:15:50,496 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-01-14 10:15:50,497 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-01-14 10:15:50,498 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-14 10:15:50,499 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-14 10:15:50,500 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-14 10:15:50,501 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-14 10:15:50,502 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-14 10:15:50,506 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-14 10:15:50,509 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-14 10:15:50,510 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-14 10:15:50,510 : INFO : EPOCH - 1 : training on 610256 raw words (388536 effective words) took 0.3s, 1277455 effective words/s
# 2019-01-14 10:15:50,511 : INFO : training on a 610256 raw words (388536 effective words) took 0.3s, 1232027 effective words/s
# 2019-01-14 10:15:50,512 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# (388536, 610256)

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
thrones2vec.save(os.path.join("trained", "mostSimilarWorkButSimilarityComparisonDoesnt.w2v"))
# Out:
# 2019-01-14 10:15:51,407 : INFO : saving Word2Vec object under trained/mostSimilarWorkButSimilarityComparisonDoesnt.w2v, separately None
# 2019-01-14 10:15:51,408 : INFO : not storing attribute vectors_norm
# 2019-01-14 10:15:51,409 : INFO : not storing attribute cum_table
# 2019-01-14 10:15:51,434 : INFO : saved trained/mostSimilarWorkButSimilarityComparisonDoesnt.w2v

# %% [markdown]
# # explore the trained model

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "mostSimilarWorkButSimilarityComparisonDoesnt.w2v"))
# Out:
# 2019-01-14 10:16:55,093 : INFO : loading Word2Vec object from trained/mostSimilarWorkButSimilarityComparisonDoesnt.w2v
# 2019-01-14 10:16:55,111 : INFO : loading wv recursively from trained/mostSimilarWorkButSimilarityComparisonDoesnt.w2v.wv.* with mmap=None
# 2019-01-14 10:16:55,112 : INFO : setting ignored attribute vectors_norm to None
# 2019-01-14 10:16:55,112 : INFO : loading vocabulary recursively from trained/mostSimilarWorkButSimilarityComparisonDoesnt.w2v.vocabulary.* with mmap=None
# 2019-01-14 10:16:55,113 : INFO : loading trainables recursively from trained/mostSimilarWorkButSimilarityComparisonDoesnt.w2v.trainables.* with mmap=None
# 2019-01-14 10:16:55,113 : INFO : setting ignored attribute cum_table to None
# 2019-01-14 10:16:55,114 : INFO : loaded trained/mostSimilarWorkButSimilarityComparisonDoesnt.w2v

# %%
vector1 = thrones2vec.wv['😳']

# %%
vector2 = thrones2vec.wv['😍']

# %%
vector3 = thrones2vec.wv['❤️']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-bc8e46fa6474> in <module>
# ----> 1 vector3 = thrones2vec.wv['❤️']
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     167         if isinstance(entities, string_types):
#     168             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 169             return self.get_vector(entities)
#     170
#     171         return vstack([self.get_vector(entity) for entity in entities])
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     275
#     276     def get_vector(self, word):
# --> 277         return self.word_vec(word)
#     278
#     279     def words_closer_than(self, w1, w2):
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     272             return result
#     273         else:
# --> 274             raise KeyError("word '%s' not in vocabulary" % word)
#     275
#     276     def get_vector(self, word):
#
# KeyError: "word '❤️' not in vocabulary"

# %%
thrones2vec.wv.similarity('🎶', '💜')
# Out:
# 0.47109443432216425

# %%
thrones2vec.wv.vocab
# Out:
# {'⚠': <gensim.models.keyedvectors.Vocab at 0x1a28c4b390>,
#  '😀': <gensim.models.keyedvectors.Vocab at 0x1a28c4ba90>,
#  '🎷': <gensim.models.keyedvectors.Vocab at 0x1a28c4bbe0>,
#  '🙌': <gensim.models.keyedvectors.Vocab at 0x1a28c4bac8>,
#  '💐': <gensim.models.keyedvectors.Vocab at 0x1a28c4bc88>,
#  '🌈': <gensim.models.keyedvectors.Vocab at 0x1a28c4b080>,
#  '🍸': <gensim.models.keyedvectors.Vocab at 0x1a28c4bb70>,
#  '🎶': <gensim.models.keyedvectors.Vocab at 0x1a28c4bb00>,
#  '💜': <gensim.models.keyedvectors.Vocab at 0x1a28c4b9e8>,
#  '🌼': <gensim.models.keyedvectors.Vocab at 0x1a28c4bd30>,
#  '💛': <gensim.models.keyedvectors.Vocab at 0x1a28c4bcc0>,
#  '❤': <gensim.models.keyedvectors.Vocab at 0x1a28c4bc50>,
#  '☮': <gensim.models.keyedvectors.Vocab at 0x1a28c4bd68>,
#  '✨': <gensim.models.keyedvectors.Vocab at 0x1a28c4bda0>,
#  '🏕': <gensim.models.keyedvectors.Vocab at 0x1a28c4bdd8>,
#  '💖': <gensim.models.keyedvectors.Vocab at 0x1a28c4be10>,
#  '🌤': <gensim.models.keyedvectors.Vocab at 0x1a28c4be48>,
#  '🌸': <gensim.models.keyedvectors.Vocab at 0x1a28c4be80>,
#  '🌷': <gensim.models.keyedvectors.Vocab at 0x1a28c4beb8>,
#  '\u200d': <gensim.models.keyedvectors.Vocab at 0x1a28c4bef0>,
#  '🏔': <gensim.models.keyedvectors.Vocab at 0x1a28c4bf28>,
#  '️': <gensim.models.keyedvectors.Vocab at 0x1a28c4bf60>,
#  '🍀': <gensim.models.keyedvectors.Vocab at 0x1a28c4bf98>,
#  '🌎': <gensim.models.keyedvectors.Vocab at 0x1a28c4bfd0>,
#  '🥀': <gensim.models.keyedvectors.Vocab at 0x1a28c55048>,
#  '🌱': <gensim.models.keyedvectors.Vocab at 0x1a28c55080>,
#  '🌳': <gensim.models.keyedvectors.Vocab at 0x1a28c550b8>,
#  '🚴': <gensim.models.keyedvectors.Vocab at 0x1a28c550f0>,
#  '🌻': <gensim.models.keyedvectors.Vocab at 0x1a28c55128>,
#  '♀': <gensim.models.keyedvectors.Vocab at 0x1a28c55160>,
#  '🇦': <gensim.models.keyedvectors.Vocab at 0x1a28c55198>,
#  '🇿': <gensim.models.keyedvectors.Vocab at 0x1a28c551d0>,
#  '🇸': <gensim.models.keyedvectors.Vocab at 0x1a28c55208>,
#  '🇺': <gensim.models.keyedvectors.Vocab at 0x1a28c55240>,
#  '🇩': <gensim.models.keyedvectors.Vocab at 0x1a28c55278>,
#  '🇪': <gensim.models.keyedvectors.Vocab at 0x1a28c552b0>,
#  '🇮': <gensim.models.keyedvectors.Vocab at 0x1a28c552e8>,
#  '🇧': <gensim.models.keyedvectors.Vocab at 0x1a28c55320>,
#  '😭': <gensim.models.keyedvectors.Vocab at 0x1a28c55358>,
#  '🤦': <gensim.models.keyedvectors.Vocab at 0x1a28c55390>,
#  '♂': <gensim.models.keyedvectors.Vocab at 0x1a28c553c8>,
#  '👉': <gensim.models.keyedvectors.Vocab at 0x1a28c55400>,
#  '🚖': <gensim.models.keyedvectors.Vocab at 0x1a28c55438>,
#  '🏾': <gensim.models.keyedvectors.Vocab at 0x1a28c55470>,
#  '🎈': <gensim.models.keyedvectors.Vocab at 0x1a28c554a8>,
#  '💃': <gensim.models.keyedvectors.Vocab at 0x1a28c554e0>,
#  '💞': <gensim.models.keyedvectors.Vocab at 0x1a28c55518>,
#  '😳': <gensim.models.keyedvectors.Vocab at 0x1a28c55550>,
#  '😉': <gensim.models.keyedvectors.Vocab at 0x1a28c55588>,
#  '⚽': <gensim.models.keyedvectors.Vocab at 0x1a28c555c0>,
#  '🍬': <gensim.models.keyedvectors.Vocab at 0x1a28c555f8>,
#  '🍭': <gensim.models.keyedvectors.Vocab at 0x1a28c55630>,
#  '💕': <gensim.models.keyedvectors.Vocab at 0x1a28c55668>,
#  '🔋': <gensim.models.keyedvectors.Vocab at 0x1a28c556a0>,
#  '🙊': <gensim.models.keyedvectors.Vocab at 0x1a28c556d8>,
#  '👍': <gensim.models.keyedvectors.Vocab at 0x1a28c55710>,
#  '🍳': <gensim.models.keyedvectors.Vocab at 0x1a28c55748>,
#  '🥚': <gensim.models.keyedvectors.Vocab at 0x1a28c55780>,
#  '😞': <gensim.models.keyedvectors.Vocab at 0x1a28c557b8>,
#  '😢': <gensim.models.keyedvectors.Vocab at 0x1a28c557f0>,
#  '😘': <gensim.models.keyedvectors.Vocab at 0x1a28c55828>,
#  '😍': <gensim.models.keyedvectors.Vocab at 0x1a28c55860>,
#  '🤧': <gensim.models.keyedvectors.Vocab at 0x1a28c55898>,
#  '🤗': <gensim.models.keyedvectors.Vocab at 0x1a28c558d0>,
#  '🎉': <gensim.models.keyedvectors.Vocab at 0x1a28c55908>,
#  '🍾': <gensim.models.keyedvectors.Vocab at 0x1a28c55940>,
#  '🍷': <gensim.models.keyedvectors.Vocab at 0x1a28c55978>,
#  '🎊': <gensim.models.keyedvectors.Vocab at 0x1a28c559b0>,
#  '📱': <gensim.models.keyedvectors.Vocab at 0x1a28c559e8>,
#  '💋': <gensim.models.keyedvectors.Vocab at 0x1a28c55a20>,
#  '😊': <gensim.models.keyedvectors.Vocab at 0x1a28c55a58>,
#  '⃣': <gensim.models.keyedvectors.Vocab at 0x1a28c55a90>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x1a28c55ac8>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x1a28c55b00>,
#  '🎵': <gensim.models.keyedvectors.Vocab at 0x1a28c55b38>,
#  '💌': <gensim.models.keyedvectors.Vocab at 0x1a28c55b70>,
#  '👟': <gensim.models.keyedvectors.Vocab at 0x1a28c55ba8>,
#  '🎁': <gensim.models.keyedvectors.Vocab at 0x1a28c55be0>,
#  '🔥': <gensim.models.keyedvectors.Vocab at 0x1a28c55c18>,
#  '🐶': <gensim.models.keyedvectors.Vocab at 0x1a28c55c50>,
#  '🎹': <gensim.models.keyedvectors.Vocab at 0x1a28c55c88>,
#  '😂': <gensim.models.keyedvectors.Vocab at 0x1a28c55cc0>,
#  '🍑': <gensim.models.keyedvectors.Vocab at 0x1a28c55cf8>,
#  '😋': <gensim.models.keyedvectors.Vocab at 0x1a28c55d30>,
#  '🙏': <gensim.models.keyedvectors.Vocab at 0x1a28c55d68>,
#  '💿': <gensim.models.keyedvectors.Vocab at 0x1a28c55da0>,
#  '💘': <gensim.models.keyedvectors.Vocab at 0x1a28c55dd8>,
#  '🌧': <gensim.models.keyedvectors.Vocab at 0x1a28c55e10>,
#  '💙': <gensim.models.keyedvectors.Vocab at 0x1a28c55e48>,
#  '😃': <gensim.models.keyedvectors.Vocab at 0x1a28c55e80>,
#  '🏽': <gensim.models.keyedvectors.Vocab at 0x1a28c55eb8>,
#  '🕵': <gensim.models.keyedvectors.Vocab at 0x1a28c55ef0>,
#  '‼': <gensim.models.keyedvectors.Vocab at 0x1a28c55f28>,
#  '📌': <gensim.models.keyedvectors.Vocab at 0x1a28c55f60>,
#  '❕': <gensim.models.keyedvectors.Vocab at 0x1a28c55f98>,
#  '🙆': <gensim.models.keyedvectors.Vocab at 0x1a28c55fd0>,
#  '😌': <gensim.models.keyedvectors.Vocab at 0x1a28c5e048>,
#  '🎤': <gensim.models.keyedvectors.Vocab at 0x1a28c5e080>,
#  '😆': <gensim.models.keyedvectors.Vocab at 0x1a28c5e0b8>,
#  '😅': <gensim.models.keyedvectors.Vocab at 0x1a28c5e0f0>,
#  '🙄': <gensim.models.keyedvectors.Vocab at 0x1a28c5e128>,
#  '📹': <gensim.models.keyedvectors.Vocab at 0x1a28c5e160>,
#  '🍽': <gensim.models.keyedvectors.Vocab at 0x1a28c5e198>,
#  '🏌': <gensim.models.keyedvectors.Vocab at 0x1a28c5e1d0>,
#  '⛳': <gensim.models.keyedvectors.Vocab at 0x1a28c5e208>,
#  '👌': <gensim.models.keyedvectors.Vocab at 0x1a28c5e240>,
#  '💪': <gensim.models.keyedvectors.Vocab at 0x1a28c5e278>,
#  '🏆': <gensim.models.keyedvectors.Vocab at 0x1a28c5e2b0>,
#  '🏻': <gensim.models.keyedvectors.Vocab at 0x1a28c5e2e8>,
#  '♥': <gensim.models.keyedvectors.Vocab at 0x1a28c5e320>,
#  '🤟': <gensim.models.keyedvectors.Vocab at 0x1a28c5e358>,
#  '😈': <gensim.models.keyedvectors.Vocab at 0x1a28c5e390>,
#  '🏼': <gensim.models.keyedvectors.Vocab at 0x1a28c5e3c8>,
#  '⭐': <gensim.models.keyedvectors.Vocab at 0x1a28c5e400>,
#  '🇷': <gensim.models.keyedvectors.Vocab at 0x1a28c5e438>,
#  '🌺': <gensim.models.keyedvectors.Vocab at 0x1a28c5e470>,
#  '🐾': <gensim.models.keyedvectors.Vocab at 0x1a28c5e4a8>,
#  '🐠': <gensim.models.keyedvectors.Vocab at 0x1a28c5e4e0>,
#  '🐇': <gensim.models.keyedvectors.Vocab at 0x1a28c5e518>,
#  '👑': <gensim.models.keyedvectors.Vocab at 0x1a28c5e550>,
#  '🐣': <gensim.models.keyedvectors.Vocab at 0x1a28c5e588>,
#  '🐧': <gensim.models.keyedvectors.Vocab at 0x1a28c5e5c0>,
#  '👣': <gensim.models.keyedvectors.Vocab at 0x1a28c5e5f8>,
#  '🔞': <gensim.models.keyedvectors.Vocab at 0x1a28c5e630>,
#  '📽': <gensim.models.keyedvectors.Vocab at 0x1a28c5e668>,
#  '🤷': <gensim.models.keyedvectors.Vocab at 0x1a28c5e6a0>,
#  '🏃': <gensim.models.keyedvectors.Vocab at 0x1a28c5e6d8>,
#  '💨': <gensim.models.keyedvectors.Vocab at 0x1a28c5e710>,
#  '🍰': <gensim.models.keyedvectors.Vocab at 0x1a28c5e748>,
#  '💰': <gensim.models.keyedvectors.Vocab at 0x1a28c5e780>,
#  '👋': <gensim.models.keyedvectors.Vocab at 0x1a28c5e7b8>,
#  '😫': <gensim.models.keyedvectors.Vocab at 0x1a28c5e7f0>,
#  '🎥': <gensim.models.keyedvectors.Vocab at 0x1a28c5e828>,
#  '🙈': <gensim.models.keyedvectors.Vocab at 0x1a28c5e860>,
#  '👏': <gensim.models.keyedvectors.Vocab at 0x1a28c5e898>,
#  '🌊': <gensim.models.keyedvectors.Vocab at 0x1a28c5e8d0>,
#  '🤴': <gensim.models.keyedvectors.Vocab at 0x1a28c5e908>,
#  '👸': <gensim.models.keyedvectors.Vocab at 0x1a28c5e940>,
#  '👀': <gensim.models.keyedvectors.Vocab at 0x1a28c5e978>,
#  '😏': <gensim.models.keyedvectors.Vocab at 0x1a28c5e9b0>,
#  '😩': <gensim.models.keyedvectors.Vocab at 0x1a28c5e9e8>,
#  '📐': <gensim.models.keyedvectors.Vocab at 0x1a28c5ea20>,
#  '🕶': <gensim.models.keyedvectors.Vocab at 0x1a28c5ea58>,
#  '☀': <gensim.models.keyedvectors.Vocab at 0x1a28c5ea90>,
#  '😲': <gensim.models.keyedvectors.Vocab at 0x1a28c5eac8>,
#  '🌍': <gensim.models.keyedvectors.Vocab at 0x1a28c5eb00>,
#  '🇯': <gensim.models.keyedvectors.Vocab at 0x1a28c5eb38>,
#  '🇵': <gensim.models.keyedvectors.Vocab at 0x1a28c5eb70>,
#  '💀': <gensim.models.keyedvectors.Vocab at 0x1a28c5eba8>,
#  '🤭': <gensim.models.keyedvectors.Vocab at 0x1a28c5ebe0>,
#  '😎': <gensim.models.keyedvectors.Vocab at 0x1a28c5ec18>,
#  '🇲': <gensim.models.keyedvectors.Vocab at 0x1a28c5ec50>,
#  '💥': <gensim.models.keyedvectors.Vocab at 0x1a28c5ec88>,
#  '✅': <gensim.models.keyedvectors.Vocab at 0x1a28c5ecc0>,
#  '📢': <gensim.models.keyedvectors.Vocab at 0x1a28c5ecf8>,
#  '🚗': <gensim.models.keyedvectors.Vocab at 0x1a28c5ed30>,
#  '🔑': <gensim.models.keyedvectors.Vocab at 0x1a28c5ed68>,
#  '🇨': <gensim.models.keyedvectors.Vocab at 0x1a28c5eda0>,
#  '🤞': <gensim.models.keyedvectors.Vocab at 0x1a28c5edd8>,
#  '📲': <gensim.models.keyedvectors.Vocab at 0x1a28c5ee10>,
#  '🆘': <gensim.models.keyedvectors.Vocab at 0x1a28c5ee48>,
#  '🏁': <gensim.models.keyedvectors.Vocab at 0x1a28c5ee80>,
#  '🚩': <gensim.models.keyedvectors.Vocab at 0x1a28c5eeb8>,
#  '🍃': <gensim.models.keyedvectors.Vocab at 0x1a28c5eef0>,
#  '🤣': <gensim.models.keyedvectors.Vocab at 0x1a28c5ef28>,
#  '📷': <gensim.models.keyedvectors.Vocab at 0x1a28c5ef60>,
#  '🌴': <gensim.models.keyedvectors.Vocab at 0x1a28c5ef98>,
#  '🤘': <gensim.models.keyedvectors.Vocab at 0x1a28c5efd0>,
#  '🙃': <gensim.models.keyedvectors.Vocab at 0x1a28c68048>,
#  '👯': <gensim.models.keyedvectors.Vocab at 0x1a28c68080>,
#  '🕺': <gensim.models.keyedvectors.Vocab at 0x1a28c680b8>,
#  '💚': <gensim.models.keyedvectors.Vocab at 0x1a28c680f0>,
#  '😱': <gensim.models.keyedvectors.Vocab at 0x1a28c68128>,
#  '⚡': <gensim.models.keyedvectors.Vocab at 0x1a28c68160>,
#  '📉': <gensim.models.keyedvectors.Vocab at 0x1a28c68198>,
#  '👠': <gensim.models.keyedvectors.Vocab at 0x1a28c681d0>,
#  '🎓': <gensim.models.keyedvectors.Vocab at 0x1a28c68208>,
#  '🐪': <gensim.models.keyedvectors.Vocab at 0x1a28c68240>,
#  '💔': <gensim.models.keyedvectors.Vocab at 0x1a28c68278>,
#  '🏀': <gensim.models.keyedvectors.Vocab at 0x1a28c682b0>,
#  '👥': <gensim.models.keyedvectors.Vocab at 0x1a28c682e8>,
#  '👇': <gensim.models.keyedvectors.Vocab at 0x1a28c68320>,
#  '😒': <gensim.models.keyedvectors.Vocab at 0x1a28c68358>,
#  '🤔': <gensim.models.keyedvectors.Vocab at 0x1a28c68390>,
#  '🤯': <gensim.models.keyedvectors.Vocab at 0x1a28c683c8>,
#  '📖': <gensim.models.keyedvectors.Vocab at 0x1a28c68400>,
#  '👂': <gensim.models.keyedvectors.Vocab at 0x1a28c68438>,
#  '🧠': <gensim.models.keyedvectors.Vocab at 0x1a28c68470>,
#  '📚': <gensim.models.keyedvectors.Vocab at 0x1a28c684a8>,
#  '🎙': <gensim.models.keyedvectors.Vocab at 0x1a28c684e0>,
#  '💦': <gensim.models.keyedvectors.Vocab at 0x1a28c68518>,
#  '💯': <gensim.models.keyedvectors.Vocab at 0x1a28c68550>,
#  '💫': <gensim.models.keyedvectors.Vocab at 0x1a28c68588>,
#  '🎂': <gensim.models.keyedvectors.Vocab at 0x1a28c685c0>,
#  '👊': <gensim.models.keyedvectors.Vocab at 0x1a28c685f8>,
#  '😁': <gensim.models.keyedvectors.Vocab at 0x1a28c68630>,
#  '🐎': <gensim.models.keyedvectors.Vocab at 0x1a28c68668>,
#  '😻': <gensim.models.keyedvectors.Vocab at 0x1a28c686a0>,
#  '🍉': <gensim.models.keyedvectors.Vocab at 0x1a28c686d8>,
#  '😽': <gensim.models.keyedvectors.Vocab at 0x1a28c68710>,
#  '☺': <gensim.models.keyedvectors.Vocab at 0x1a28c68748>,
#  '😸': <gensim.models.keyedvectors.Vocab at 0x1a28c68780>,
#  '🍫': <gensim.models.keyedvectors.Vocab at 0x1a28c687b8>,
#  '😔': <gensim.models.keyedvectors.Vocab at 0x1a28c687f0>,
#  '🔊': <gensim.models.keyedvectors.Vocab at 0x1a28c68828>,
#  '🇱': <gensim.models.keyedvectors.Vocab at 0x1a28c68860>,
#  '🌟': <gensim.models.keyedvectors.Vocab at 0x1a28c68898>,
#  '🛴': <gensim.models.keyedvectors.Vocab at 0x1a28c688d0>,
#  '💟': <gensim.models.keyedvectors.Vocab at 0x1a28c68908>,
#  '🦋': <gensim.models.keyedvectors.Vocab at 0x1a28c68940>,
#  '🖤': <gensim.models.keyedvectors.Vocab at 0x1a28c68978>,
#  '🏳': <gensim.models.keyedvectors.Vocab at 0x1a28c689b0>,
#  '🤡': <gensim.models.keyedvectors.Vocab at 0x1a28c689e8>,
#  '😬': <gensim.models.keyedvectors.Vocab at 0x1a28c68a20>,
#  '😠': <gensim.models.keyedvectors.Vocab at 0x1a28c68a58>,
#  '✋': <gensim.models.keyedvectors.Vocab at 0x1a28c68a90>,
#  '🏿': <gensim.models.keyedvectors.Vocab at 0x1a28c68ac8>,
#  '🧡': <gensim.models.keyedvectors.Vocab at 0x1a28c68b00>,
#  '🙋': <gensim.models.keyedvectors.Vocab at 0x1a28c68b38>,
#  '🌹': <gensim.models.keyedvectors.Vocab at 0x1a28c68b70>,
#  '💗': <gensim.models.keyedvectors.Vocab at 0x1a28c68ba8>,
#  '😚': <gensim.models.keyedvectors.Vocab at 0x1a28c68be0>,
#  '🌂': <gensim.models.keyedvectors.Vocab at 0x1a28c68c18>,
#  '😕': <gensim.models.keyedvectors.Vocab at 0x1a28c68c50>,
#  '🌅': <gensim.models.keyedvectors.Vocab at 0x1a28c68c88>,
#  '🛎': <gensim.models.keyedvectors.Vocab at 0x1a28c68cc0>,
#  '🏐': <gensim.models.keyedvectors.Vocab at 0x1a28c68cf8>,
#  '👈': <gensim.models.keyedvectors.Vocab at 0x1a28c68d30>,
#  '😤': <gensim.models.keyedvectors.Vocab at 0x1a28c68d68>,
#  '👨': <gensim.models.keyedvectors.Vocab at 0x1a28c68da0>,
#  '🦍': <gensim.models.keyedvectors.Vocab at 0x1a28c68dd8>,
#  '🌦': <gensim.models.keyedvectors.Vocab at 0x1a28c68e10>,
#  '🌿': <gensim.models.keyedvectors.Vocab at 0x1a28c68e48>,
#  '😮': <gensim.models.keyedvectors.Vocab at 0x1a28c68e80>,
#  '🍌': <gensim.models.keyedvectors.Vocab at 0x1a28c68eb8>,
#  '🍞': <gensim.models.keyedvectors.Vocab at 0x1a28c68ef0>,
#  '🍆': <gensim.models.keyedvectors.Vocab at 0x1a28c68f28>,
#  '💅': <gensim.models.keyedvectors.Vocab at 0x1a28c68f60>,
#  '😜': <gensim.models.keyedvectors.Vocab at 0x1a28c68f98>,
#  '🌌': <gensim.models.keyedvectors.Vocab at 0x1a28c68fd0>,
#  '🐈': <gensim.models.keyedvectors.Vocab at 0x1a28c72048>,
#  '🐱': <gensim.models.keyedvectors.Vocab at 0x1a28c72080>,
#  '➡': <gensim.models.keyedvectors.Vocab at 0x1a28c720b8>,
#  '🇳': <gensim.models.keyedvectors.Vocab at 0x1a28c720f0>,
#  '🌆': <gensim.models.keyedvectors.Vocab at 0x1a28c72128>,
#  '🌞': <gensim.models.keyedvectors.Vocab at 0x1a28c72160>,
#  '🤤': <gensim.models.keyedvectors.Vocab at 0x1a28c72198>,
#  '✊': <gensim.models.keyedvectors.Vocab at 0x1a28c721d0>,
#  '💎': <gensim.models.keyedvectors.Vocab at 0x1a28c72208>,
#  '💷': <gensim.models.keyedvectors.Vocab at 0x1a28c72240>,
#  '👫': <gensim.models.keyedvectors.Vocab at 0x1a28c72278>,
#  '💓': <gensim.models.keyedvectors.Vocab at 0x1a28c722b0>,
#  '🐻': <gensim.models.keyedvectors.Vocab at 0x1a28c722e8>,
#  '🏩': <gensim.models.keyedvectors.Vocab at 0x1a28c72320>,
#  '👗': <gensim.models.keyedvectors.Vocab at 0x1a28c72358>,
#  '📗': <gensim.models.keyedvectors.Vocab at 0x1a28c72390>,
#  '🌚': <gensim.models.keyedvectors.Vocab at 0x1a28c723c8>,
#  '🕛': <gensim.models.keyedvectors.Vocab at 0x1a28c72400>,
#  '🍋': <gensim.models.keyedvectors.Vocab at 0x1a28c72438>,
#  '🔅': <gensim.models.keyedvectors.Vocab at 0x1a28c72470>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x1a28c724a8>,
#  '🤠': <gensim.models.keyedvectors.Vocab at 0x1a28c724e0>,
#  '🤜': <gensim.models.keyedvectors.Vocab at 0x1a28c72518>,
#  '🤢': <gensim.models.keyedvectors.Vocab at 0x1a28c72550>,
#  '🇬': <gensim.models.keyedvectors.Vocab at 0x1a28c72588>,
#  '🇭': <gensim.models.keyedvectors.Vocab at 0x1a28c725c0>,
#  '💝': <gensim.models.keyedvectors.Vocab at 0x1a28c725f8>,
#  '❣': <gensim.models.keyedvectors.Vocab at 0x1a28c72630>,
#  '🛍': <gensim.models.keyedvectors.Vocab at 0x1a28c72668>,
#  '🐴': <gensim.models.keyedvectors.Vocab at 0x1a28c726a0>,
#  '✔': <gensim.models.keyedvectors.Vocab at 0x1a28c726d8>,
#  '❗': <gensim.models.keyedvectors.Vocab at 0x1a28c72710>,
#  '📡': <gensim.models.keyedvectors.Vocab at 0x1a28c72748>,
#  '🎇': <gensim.models.keyedvectors.Vocab at 0x1a28c72780>,
#  '😣': <gensim.models.keyedvectors.Vocab at 0x1a28c727b8>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x1a28c727f0>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x1a28c72828>,
#  '🔴': <gensim.models.keyedvectors.Vocab at 0x1a28c72860>,
#  '⚪': <gensim.models.keyedvectors.Vocab at 0x1a28c72898>,
#  '🎼': <gensim.models.keyedvectors.Vocab at 0x1a28c728d0>,
#  '😑': <gensim.models.keyedvectors.Vocab at 0x1a28c72908>,
#  '🚶': <gensim.models.keyedvectors.Vocab at 0x1a28c72940>,
#  '🚪': <gensim.models.keyedvectors.Vocab at 0x1a28c72978>,
#  '💣': <gensim.models.keyedvectors.Vocab at 0x1a28c729b0>,
#  '🚨': <gensim.models.keyedvectors.Vocab at 0x1a28c729e8>,
#  '🍪': <gensim.models.keyedvectors.Vocab at 0x1a28c72a20>,
#  '📻': <gensim.models.keyedvectors.Vocab at 0x1a28c72a58>,
#  '🐥': <gensim.models.keyedvectors.Vocab at 0x1a28c72a90>,
#  '🐔': <gensim.models.keyedvectors.Vocab at 0x1a28c72ac8>,
#  '🐦': <gensim.models.keyedvectors.Vocab at 0x1a28c72b00>,
#  '🐤': <gensim.models.keyedvectors.Vocab at 0x1a28c72b38>,
#  '🕗': <gensim.models.keyedvectors.Vocab at 0x1a28c72b70>,
#  '😶': <gensim.models.keyedvectors.Vocab at 0x1a28c72ba8>,
#  '🙂': <gensim.models.keyedvectors.Vocab at 0x1a28c72be0>,
#  '🏟': <gensim.models.keyedvectors.Vocab at 0x1a28c72c18>,
#  '👅': <gensim.models.keyedvectors.Vocab at 0x1a28c72c50>,
#  '🐊': <gensim.models.keyedvectors.Vocab at 0x1a28c72c88>,
#  '🎖': <gensim.models.keyedvectors.Vocab at 0x1a28c72cc0>,
#  '🍔': <gensim.models.keyedvectors.Vocab at 0x1a28c72cf8>,
#  '🎸': <gensim.models.keyedvectors.Vocab at 0x1a28c72d30>,
#  '🎆': <gensim.models.keyedvectors.Vocab at 0x1a28c72d68>,
#  '💁': <gensim.models.keyedvectors.Vocab at 0x1a28c72da0>,
#  '🥂': <gensim.models.keyedvectors.Vocab at 0x1a28c72dd8>,
#  '🤪': <gensim.models.keyedvectors.Vocab at 0x1a28c72e10>,
#  '🇾': <gensim.models.keyedvectors.Vocab at 0x1a28c72e48>,
#  '🦁': <gensim.models.keyedvectors.Vocab at 0x1a28c72e80>,
#  '🔝': <gensim.models.keyedvectors.Vocab at 0x1a28c72eb8>,
#  '📸': <gensim.models.keyedvectors.Vocab at 0x1a28c72ef0>,
#  '🚀': <gensim.models.keyedvectors.Vocab at 0x1a28c72f28>,
#  '🦌': <gensim.models.keyedvectors.Vocab at 0x1a28c72f60>,
#  '😇': <gensim.models.keyedvectors.Vocab at 0x1a28c72f98>,
#  '🚕': <gensim.models.keyedvectors.Vocab at 0x1a28c72fd0>,
#  '🙅': <gensim.models.keyedvectors.Vocab at 0x1a28c7c048>,
#  '😥': <gensim.models.keyedvectors.Vocab at 0x1a28c7c080>,
#  '🗣': <gensim.models.keyedvectors.Vocab at 0x1a28c7c0b8>,
#  '🏊': <gensim.models.keyedvectors.Vocab at 0x1a28c7c0f0>,
#  '🤕': <gensim.models.keyedvectors.Vocab at 0x1a28c7c128>,
#  '😡': <gensim.models.keyedvectors.Vocab at 0x1a28c7c160>,
#  '⏰': <gensim.models.keyedvectors.Vocab at 0x1a28c7c198>,
#  '🌙': <gensim.models.keyedvectors.Vocab at 0x1a28c7c1d0>,
#  '🖐': <gensim.models.keyedvectors.Vocab at 0x1a28c7c208>,
#  '🏡': <gensim.models.keyedvectors.Vocab at 0x1a28c7c240>,
#  '🙉': <gensim.models.keyedvectors.Vocab at 0x1a28c7c278>,
#  '🐽': <gensim.models.keyedvectors.Vocab at 0x1a28c7c2b0>,
#  '🌶': <gensim.models.keyedvectors.Vocab at 0x1a28c7c2e8>,
#  '🥁': <gensim.models.keyedvectors.Vocab at 0x1a28c7c320>,
#  '🥇': <gensim.models.keyedvectors.Vocab at 0x1a28c7c358>,
#  '🐢': <gensim.models.keyedvectors.Vocab at 0x1a28c7c390>,
#  '🗽': <gensim.models.keyedvectors.Vocab at 0x1a28c7c3c8>,
#  '🔪': <gensim.models.keyedvectors.Vocab at 0x1a28c7c400>,
#  '😄': <gensim.models.keyedvectors.Vocab at 0x1a28c7c438>,
#  '🚫': <gensim.models.keyedvectors.Vocab at 0x1a28c7c470>,
#  '🧢': <gensim.models.keyedvectors.Vocab at 0x1a28c7c4a8>,
#  '🐕': <gensim.models.keyedvectors.Vocab at 0x1a28c7c4e0>,
#  '🕒': <gensim.models.keyedvectors.Vocab at 0x1a28c7c518>,
#  '🐬': <gensim.models.keyedvectors.Vocab at 0x1a28c7c550>,
#  '🔵': <gensim.models.keyedvectors.Vocab at 0x1a28c7c588>,
#  '🔜': <gensim.models.keyedvectors.Vocab at 0x1a28c7c5c0>,
#  '➗': <gensim.models.keyedvectors.Vocab at 0x1a28c7c5f8>,
#  '🍊': <gensim.models.keyedvectors.Vocab at 0x1a28c7c630>,
#  '👦': <gensim.models.keyedvectors.Vocab at 0x1a28c7c668>,
#  '🕯': <gensim.models.keyedvectors.Vocab at 0x1a28c7c6a0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x1a28c7c6d8>,
#  '🧚': <gensim.models.keyedvectors.Vocab at 0x1a28c7c710>,
#  '🚲': <gensim.models.keyedvectors.Vocab at 0x1a28c7c748>,
#  '🌏': <gensim.models.keyedvectors.Vocab at 0x1a28c7c780>,
#  '🆓': <gensim.models.keyedvectors.Vocab at 0x1a28c7c7b8>,
#  '✍': <gensim.models.keyedvectors.Vocab at 0x1a28c7c7f0>,
#  '😝': <gensim.models.keyedvectors.Vocab at 0x1a28c7c828>,
#  '🥥': <gensim.models.keyedvectors.Vocab at 0x1a28c7c860>,
#  '🌠': <gensim.models.keyedvectors.Vocab at 0x1a28c7c898>,
#  '🇫': <gensim.models.keyedvectors.Vocab at 0x1a28c7c8d0>,
#  '😛': <gensim.models.keyedvectors.Vocab at 0x1a28c7c908>,
#  '🥊': <gensim.models.keyedvectors.Vocab at 0x1a28c7c940>,
#  '🍗': <gensim.models.keyedvectors.Vocab at 0x1a28c7c978>,
#  '😯': <gensim.models.keyedvectors.Vocab at 0x1a28c7c9b0>,
#  '👧': <gensim.models.keyedvectors.Vocab at 0x1a28c7c9e8>,
#  '🎀': <gensim.models.keyedvectors.Vocab at 0x1a28c7ca20>,
#  '👩': <gensim.models.keyedvectors.Vocab at 0x1a28c7ca58>,
#  '🦒': <gensim.models.keyedvectors.Vocab at 0x1a28c7ca90>,
#  '🐝': <gensim.models.keyedvectors.Vocab at 0x1a28c7cac8>,
#  '🇰': <gensim.models.keyedvectors.Vocab at 0x1a28c7cb00>,
#  '🏦': <gensim.models.keyedvectors.Vocab at 0x1a28c7cb38>,
#  '🔨': <gensim.models.keyedvectors.Vocab at 0x1a28c7cb70>,
#  '🖕': <gensim.models.keyedvectors.Vocab at 0x1a28c7cba8>,
#  '🔔': <gensim.models.keyedvectors.Vocab at 0x1a28c7cbe0>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x1a28c7cc18>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x1a28c7cc50>,
#  '🍁': <gensim.models.keyedvectors.Vocab at 0x1a28c7cc88>,
#  '🆔': <gensim.models.keyedvectors.Vocab at 0x1a28c7ccc0>,
#  '📝': <gensim.models.keyedvectors.Vocab at 0x1a28c7ccf8>,
#  '😰': <gensim.models.keyedvectors.Vocab at 0x1a28c7cd30>,
#  '😨': <gensim.models.keyedvectors.Vocab at 0x1a28c7cd68>,
#  '🤫': <gensim.models.keyedvectors.Vocab at 0x1a28c7cda0>,
#  '🍕': <gensim.models.keyedvectors.Vocab at 0x1a28c7cdd8>,
#  '😙': <gensim.models.keyedvectors.Vocab at 0x1a28c7ce10>,
#  '❌': <gensim.models.keyedvectors.Vocab at 0x1a28c7ce48>,
#  '🏄': <gensim.models.keyedvectors.Vocab at 0x1a28c7ce80>,
#  '🍟': <gensim.models.keyedvectors.Vocab at 0x1a28c7ceb8>,
#  '🗯': <gensim.models.keyedvectors.Vocab at 0x1a28c7cef0>,
#  '📬': <gensim.models.keyedvectors.Vocab at 0x1a28c7cf28>,
#  '🛑': <gensim.models.keyedvectors.Vocab at 0x1a28c7cf60>,
#  '🍒': <gensim.models.keyedvectors.Vocab at 0x1a28c7cf98>,
#  '🚚': <gensim.models.keyedvectors.Vocab at 0x1a28c7cfd0>,
#  '🏏': <gensim.models.keyedvectors.Vocab at 0x1a28c86048>,
#  '🦅': <gensim.models.keyedvectors.Vocab at 0x1a28c86080>,
#  '🏅': <gensim.models.keyedvectors.Vocab at 0x1a28c860b8>,
#  '🎨': <gensim.models.keyedvectors.Vocab at 0x1a28c860f0>,
#  '🎻': <gensim.models.keyedvectors.Vocab at 0x1a28c86128>,
#  '🎬': <gensim.models.keyedvectors.Vocab at 0x1a28c86160>,
#  '🤽': <gensim.models.keyedvectors.Vocab at 0x1a28c86198>,
#  '🐷': <gensim.models.keyedvectors.Vocab at 0x1a28c861d0>,
#  '💶': <gensim.models.keyedvectors.Vocab at 0x1a28c86208>,
#  '😹': <gensim.models.keyedvectors.Vocab at 0x1a28c86240>,
#  '🎮': <gensim.models.keyedvectors.Vocab at 0x1a28c86278>,
#  '🤾': <gensim.models.keyedvectors.Vocab at 0x1a28c862b0>,
#  '❄': <gensim.models.keyedvectors.Vocab at 0x1a28c862e8>,
#  '🌡': <gensim.models.keyedvectors.Vocab at 0x1a28c86320>,
#  '🛸': <gensim.models.keyedvectors.Vocab at 0x1a28c86358>,
#  '💢': <gensim.models.keyedvectors.Vocab at 0x1a28c86390>,
#  '💬': <gensim.models.keyedvectors.Vocab at 0x1a28c863c8>,
#  '💭': <gensim.models.keyedvectors.Vocab at 0x1a28c86400>,
#  '🌝': <gensim.models.keyedvectors.Vocab at 0x1a28c86438>,
#  '⚓': <gensim.models.keyedvectors.Vocab at 0x1a28c86470>,
#  '🔁': <gensim.models.keyedvectors.Vocab at 0x1a28c864a8>,
#  '💸': <gensim.models.keyedvectors.Vocab at 0x1a28c864e0>,
#  '🤑': <gensim.models.keyedvectors.Vocab at 0x1a28c86518>,
#  '💂': <gensim.models.keyedvectors.Vocab at 0x1a28c86550>,
#  '🔈': <gensim.models.keyedvectors.Vocab at 0x1a28c86588>,
#  '😺': <gensim.models.keyedvectors.Vocab at 0x1a28c865c0>,
#  '✌': <gensim.models.keyedvectors.Vocab at 0x1a28c865f8>,
#  '💮': <gensim.models.keyedvectors.Vocab at 0x1a28c86630>,
#  '🚮': <gensim.models.keyedvectors.Vocab at 0x1a28c86668>,
#  '🤮': <gensim.models.keyedvectors.Vocab at 0x1a28c866a0>,
#  '🥗': <gensim.models.keyedvectors.Vocab at 0x1a28c866d8>,
#  '👁': <gensim.models.keyedvectors.Vocab at 0x1a28c86710>,
#  '🥩': <gensim.models.keyedvectors.Vocab at 0x1a28c86748>,
#  '🧀': <gensim.models.keyedvectors.Vocab at 0x1a28c86780>,
#  '🤩': <gensim.models.keyedvectors.Vocab at 0x1a28c867b8>,
#  '👺': <gensim.models.keyedvectors.Vocab at 0x1a28c867f0>,
#  '👹': <gensim.models.keyedvectors.Vocab at 0x1a28c86828>,
#  '❔': <gensim.models.keyedvectors.Vocab at 0x1a28c86860>,
#  '🍦': <gensim.models.keyedvectors.Vocab at 0x1a28c86898>,
#  '🏒': <gensim.models.keyedvectors.Vocab at 0x1a28c868d0>,
#  '⛸': <gensim.models.keyedvectors.Vocab at 0x1a28c86908>,
#  '🥅': <gensim.models.keyedvectors.Vocab at 0x1a28c86940>,
#  '☔': <gensim.models.keyedvectors.Vocab at 0x1a28c86978>,
#  '💡': <gensim.models.keyedvectors.Vocab at 0x1a28c869b0>,
#  '💻': <gensim.models.keyedvectors.Vocab at 0x1a28c869e8>,
#  '😾': <gensim.models.keyedvectors.Vocab at 0x1a28c86a20>,
#  '📰': <gensim.models.keyedvectors.Vocab at 0x1a28c86a58>,
#  '🍝': <gensim.models.keyedvectors.Vocab at 0x1a28c86a90>,
#  '🍜': <gensim.models.keyedvectors.Vocab at 0x1a28c86ac8>,
#  '💑': <gensim.models.keyedvectors.Vocab at 0x1a28c86b00>,
#  '🍿': <gensim.models.keyedvectors.Vocab at 0x1a28c86b38>,
#  '🔬': <gensim.models.keyedvectors.Vocab at 0x1a28c86b70>,
#  '🤺': <gensim.models.keyedvectors.Vocab at 0x1a28c86ba8>,
#  '🍇': <gensim.models.keyedvectors.Vocab at 0x1a28c86be0>,
#  '💄': <gensim.models.keyedvectors.Vocab at 0x1a28c86c18>,
#  '🏍': <gensim.models.keyedvectors.Vocab at 0x1a28c86c50>,
#  '🐯': <gensim.models.keyedvectors.Vocab at 0x1a28c86c88>,
#  '🚄': <gensim.models.keyedvectors.Vocab at 0x1a28c86cc0>,
#  '🥛': <gensim.models.keyedvectors.Vocab at 0x1a28c86cf8>,
#  '🦈': <gensim.models.keyedvectors.Vocab at 0x1a28c86d30>,
#  '💤': <gensim.models.keyedvectors.Vocab at 0x1a28c86d68>,
#  '🐍': <gensim.models.keyedvectors.Vocab at 0x1a28c86da0>,
#  '🐐': <gensim.models.keyedvectors.Vocab at 0x1a28c86dd8>,
#  '🤓': <gensim.models.keyedvectors.Vocab at 0x1a28c86e10>,
#  '🕷': <gensim.models.keyedvectors.Vocab at 0x1a28c86e48>,
#  '👶': <gensim.models.keyedvectors.Vocab at 0x1a28c86e80>,
#  '🌾': <gensim.models.keyedvectors.Vocab at 0x1a28c86eb8>,
#  '🐑': <gensim.models.keyedvectors.Vocab at 0x1a28c86ef0>,
#  '🏝': <gensim.models.keyedvectors.Vocab at 0x1a28c86f28>,
#  '😵': <gensim.models.keyedvectors.Vocab at 0x1a28c86f60>,
#  '👭': <gensim.models.keyedvectors.Vocab at 0x1a28c86f98>,
#  '👵': <gensim.models.keyedvectors.Vocab at 0x1a28c86fd0>,
#  '👱': <gensim.models.keyedvectors.Vocab at 0x1a29abe048>,
#  '🥤': <gensim.models.keyedvectors.Vocab at 0x1a29abe080>,
#  '😴': <gensim.models.keyedvectors.Vocab at 0x1a29abe0b8>,
#  '🤖': <gensim.models.keyedvectors.Vocab at 0x1a29abe0f0>,
#  '👄': <gensim.models.keyedvectors.Vocab at 0x1a29abe128>,
#  '🐰': <gensim.models.keyedvectors.Vocab at 0x1a29abe160>,
#  '🌃': <gensim.models.keyedvectors.Vocab at 0x1a29abe198>,
#  '🚙': <gensim.models.keyedvectors.Vocab at 0x1a29abe1d0>,
#  '💊': <gensim.models.keyedvectors.Vocab at 0x1a29abe208>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x1a29abe240>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x1a29abe278>,
#  '👙': <gensim.models.keyedvectors.Vocab at 0x1a29abe2b0>,
#  '🎲': <gensim.models.keyedvectors.Vocab at 0x1a29abe2e8>,
#  '😖': <gensim.models.keyedvectors.Vocab at 0x1a29abe320>,
#  '™': <gensim.models.keyedvectors.Vocab at 0x1a29abe358>,
#  '♣': <gensim.models.keyedvectors.Vocab at 0x1a29abe390>,
#  '🤒': <gensim.models.keyedvectors.Vocab at 0x1a29abe3c8>,
#  '🙀': <gensim.models.keyedvectors.Vocab at 0x1a29abe400>,
#  '👼': <gensim.models.keyedvectors.Vocab at 0x1a29abe438>,
#  '💉': <gensim.models.keyedvectors.Vocab at 0x1a29abe470>,
#  '🍻': <gensim.models.keyedvectors.Vocab at 0x1a29abe4a8>,
#  '🗳': <gensim.models.keyedvectors.Vocab at 0x1a29abe4e0>,
#  '✏': <gensim.models.keyedvectors.Vocab at 0x1a29abe518>,
#  '🦊': <gensim.models.keyedvectors.Vocab at 0x1a29abe550>,
#  '🐘': <gensim.models.keyedvectors.Vocab at 0x1a29abe588>,
#  '🇽': <gensim.models.keyedvectors.Vocab at 0x1a29abe5c0>,
#  '🏫': <gensim.models.keyedvectors.Vocab at 0x1a29abe5f8>,
#  '🍓': <gensim.models.keyedvectors.Vocab at 0x1a29abe630>,
#  '🏖': <gensim.models.keyedvectors.Vocab at 0x1a29abe668>,
#  '👮': <gensim.models.keyedvectors.Vocab at 0x1a29abe6a0>,
#  '🤙': <gensim.models.keyedvectors.Vocab at 0x1a29abe6d8>,
#  '⭕': <gensim.models.keyedvectors.Vocab at 0x1a29abe710>,
#  '❓': <gensim.models.keyedvectors.Vocab at 0x1a29abe748>,
#  '☎': <gensim.models.keyedvectors.Vocab at 0x1a29abe780>,
#  '📺': <gensim.models.keyedvectors.Vocab at 0x1a29abe7b8>,
#  '🔌': <gensim.models.keyedvectors.Vocab at 0x1a29abe7f0>,
#  '🏈': <gensim.models.keyedvectors.Vocab at 0x1a29abe828>,
#  '🌐': <gensim.models.keyedvectors.Vocab at 0x1a29abe860>,
#  '🥦': <gensim.models.keyedvectors.Vocab at 0x1a29abe898>,
#  '🥒': <gensim.models.keyedvectors.Vocab at 0x1a29abe8d0>,
#  '🍏': <gensim.models.keyedvectors.Vocab at 0x1a29abe908>,
#  '🚥': <gensim.models.keyedvectors.Vocab at 0x1a29abe940>,
#  '🔰': <gensim.models.keyedvectors.Vocab at 0x1a29abe978>,
#  '\U000e007f': <gensim.models.keyedvectors.Vocab at 0x1a29abe9b0>,
#  '\U000e0073': <gensim.models.keyedvectors.Vocab at 0x1a29abe9e8>,
#  '\U000e0063': <gensim.models.keyedvectors.Vocab at 0x1a29abea20>,
#  '\U000e0067': <gensim.models.keyedvectors.Vocab at 0x1a29abea58>,
#  '\U000e0074': <gensim.models.keyedvectors.Vocab at 0x1a29abea90>,
#  '\U000e0062': <gensim.models.keyedvectors.Vocab at 0x1a29abeac8>,
#  '🏴': <gensim.models.keyedvectors.Vocab at 0x1a29abeb00>,
#  '🔺': <gensim.models.keyedvectors.Vocab at 0x1a29abeb38>,
#  '🔫': <gensim.models.keyedvectors.Vocab at 0x1a29abeb70>,
#  '☠': <gensim.models.keyedvectors.Vocab at 0x1a29abeba8>,
#  '🌛': <gensim.models.keyedvectors.Vocab at 0x1a29abebe0>,
#  '▶': <gensim.models.keyedvectors.Vocab at 0x1a29abec18>,
#  '💽': <gensim.models.keyedvectors.Vocab at 0x1a29abec50>,
#  '😷': <gensim.models.keyedvectors.Vocab at 0x1a29abec88>,
#  '😦': <gensim.models.keyedvectors.Vocab at 0x1a29abecc0>,
#  '🐄': <gensim.models.keyedvectors.Vocab at 0x1a29abecf8>,
#  '⛵': <gensim.models.keyedvectors.Vocab at 0x1a29abed30>,
#  '⛏': <gensim.models.keyedvectors.Vocab at 0x1a29abed68>,
#  '💧': <gensim.models.keyedvectors.Vocab at 0x1a29abeda0>,
#  '🍮': <gensim.models.keyedvectors.Vocab at 0x1a29abedd8>,
#  '🥧': <gensim.models.keyedvectors.Vocab at 0x1a29abee10>,
#  '♓': <gensim.models.keyedvectors.Vocab at 0x1a29abee48>,
#  '🏠': <gensim.models.keyedvectors.Vocab at 0x1a29abee80>,
#  '🏭': <gensim.models.keyedvectors.Vocab at 0x1a29abeeb8>,
#  '🏢': <gensim.models.keyedvectors.Vocab at 0x1a29abeef0>,
#  '🤸': <gensim.models.keyedvectors.Vocab at 0x1a29abef28>,
#  '📀': <gensim.models.keyedvectors.Vocab at 0x1a29abef60>,
#  '🏎': <gensim.models.keyedvectors.Vocab at 0x1a29abef98>,
#  '🚦': <gensim.models.keyedvectors.Vocab at 0x1a29abefd0>,
#  '🔗': <gensim.models.keyedvectors.Vocab at 0x1a29ac8048>,
#  '👰': <gensim.models.keyedvectors.Vocab at 0x1a29ac8080>,
#  '💍': <gensim.models.keyedvectors.Vocab at 0x1a29ac80b8>,
#  '🎟': <gensim.models.keyedvectors.Vocab at 0x1a29ac80f0>,
#  '🎪': <gensim.models.keyedvectors.Vocab at 0x1a29ac8128>,
#  '🆕': <gensim.models.keyedvectors.Vocab at 0x1a29ac8160>,
#  '👕': <gensim.models.keyedvectors.Vocab at 0x1a29ac8198>,
#  '🍩': <gensim.models.keyedvectors.Vocab at 0x1a29ac81d0>,
#  '🛫': <gensim.models.keyedvectors.Vocab at 0x1a29ac8208>,
#  '🦄': <gensim.models.keyedvectors.Vocab at 0x1a29ac8240>,
#  '🕊': <gensim.models.keyedvectors.Vocab at 0x1a29ac8278>,
#  '🙁': <gensim.models.keyedvectors.Vocab at 0x1a29ac82b0>,
#  '🚓': <gensim.models.keyedvectors.Vocab at 0x1a29ac82e8>,
#  '🚑': <gensim.models.keyedvectors.Vocab at 0x1a29ac8320>,
#  '🎯': <gensim.models.keyedvectors.Vocab at 0x1a29ac8358>,
#  '⬅': <gensim.models.keyedvectors.Vocab at 0x1a29ac8390>,
#  '🇹': <gensim.models.keyedvectors.Vocab at 0x1a29ac83c8>,
#  '®': <gensim.models.keyedvectors.Vocab at 0x1a29ac8400>,
#  '🐸': <gensim.models.keyedvectors.Vocab at 0x1a29ac8438>,
#  '☕': <gensim.models.keyedvectors.Vocab at 0x1a29ac8470>,
#  '🙇': <gensim.models.keyedvectors.Vocab at 0x1a29ac84a8>,
#  '💒': <gensim.models.keyedvectors.Vocab at 0x1a29ac84e0>,
#  '💏': <gensim.models.keyedvectors.Vocab at 0x1a29ac8518>,
#  '🤵': <gensim.models.keyedvectors.Vocab at 0x1a29ac8550>,
#  '🐙': <gensim.models.keyedvectors.Vocab at 0x1a29ac8588>,
#  '😐': <gensim.models.keyedvectors.Vocab at 0x1a29ac85c0>,
#  '😟': <gensim.models.keyedvectors.Vocab at 0x1a29ac85f8>,
#  '📈': <gensim.models.keyedvectors.Vocab at 0x1a29ac8630>,
#  '💆': <gensim.models.keyedvectors.Vocab at 0x1a29ac8668>,
#  '🗓': <gensim.models.keyedvectors.Vocab at 0x1a29ac86a0>,
#  '🚂': <gensim.models.keyedvectors.Vocab at 0x1a29ac86d8>,
#  '⏱': <gensim.models.keyedvectors.Vocab at 0x1a29ac8710>,
#  '⚙': <gensim.models.keyedvectors.Vocab at 0x1a29ac8748>,
#  '↔': <gensim.models.keyedvectors.Vocab at 0x1a29ac8780>,
#  '🚺': <gensim.models.keyedvectors.Vocab at 0x1a29ac87b8>,
#  '🔉': <gensim.models.keyedvectors.Vocab at 0x1a29ac87f0>,
#  '🤝': <gensim.models.keyedvectors.Vocab at 0x1a29ac8828>,
#  '🍺': <gensim.models.keyedvectors.Vocab at 0x1a29ac8860>,
#  '👢': <gensim.models.keyedvectors.Vocab at 0x1a29ac8898>,
#  '🛣': <gensim.models.keyedvectors.Vocab at 0x1a29ac88d0>,
#  '⛄': <gensim.models.keyedvectors.Vocab at 0x1a29ac8908>,
#  '🌬': <gensim.models.keyedvectors.Vocab at 0x1a29ac8940>,
#  '🌩': <gensim.models.keyedvectors.Vocab at 0x1a29ac8978>,
#  '♠': <gensim.models.keyedvectors.Vocab at 0x1a29ac89b0>,
#  '🚍': <gensim.models.keyedvectors.Vocab at 0x1a29ac89e8>,
#  '🌜': <gensim.models.keyedvectors.Vocab at 0x1a29ac8a20>,
#  '🍹': <gensim.models.keyedvectors.Vocab at 0x1a29ac8a58>,
#  '👔': <gensim.models.keyedvectors.Vocab at 0x1a29ac8a90>,
#  '🌕': <gensim.models.keyedvectors.Vocab at 0x1a29ac8ac8>,
#  '👻': <gensim.models.keyedvectors.Vocab at 0x1a29ac8b00>,
#  '🍂': <gensim.models.keyedvectors.Vocab at 0x1a29ac8b38>,
#  '🎋': <gensim.models.keyedvectors.Vocab at 0x1a29ac8b70>,
#  '🕔': <gensim.models.keyedvectors.Vocab at 0x1a29ac8ba8>,
#  '🕑': <gensim.models.keyedvectors.Vocab at 0x1a29ac8be0>,
#  '🕚': <gensim.models.keyedvectors.Vocab at 0x1a29ac8c18>,
#  '🕦': <gensim.models.keyedvectors.Vocab at 0x1a29ac8c50>,
#  '🕕': <gensim.models.keyedvectors.Vocab at 0x1a29ac8c88>,
#  '🕖': <gensim.models.keyedvectors.Vocab at 0x1a29ac8cc0>,
#  '🕓': <gensim.models.keyedvectors.Vocab at 0x1a29ac8cf8>,
#  '🕥': <gensim.models.keyedvectors.Vocab at 0x1a29ac8d30>,
#  '🕧': <gensim.models.keyedvectors.Vocab at 0x1a29ac8d68>,
#  '🕐': <gensim.models.keyedvectors.Vocab at 0x1a29ac8da0>,
#  '🕤': <gensim.models.keyedvectors.Vocab at 0x1a29ac8dd8>,
#  '📃': <gensim.models.keyedvectors.Vocab at 0x1a29ac8e10>,
#  '🔆': <gensim.models.keyedvectors.Vocab at 0x1a29ac8e48>,
#  '⌚': <gensim.models.keyedvectors.Vocab at 0x1a29ac8e80>,
#  '🎧': <gensim.models.keyedvectors.Vocab at 0x1a29ac8eb8>,
#  '⛷': <gensim.models.keyedvectors.Vocab at 0x1a29ac8ef0>,
#  '🌄': <gensim.models.keyedvectors.Vocab at 0x1a29ac8f28>,
#  '🎩': <gensim.models.keyedvectors.Vocab at 0x1a29ac8f60>,
#  '🔂': <gensim.models.keyedvectors.Vocab at 0x1a29ac8f98>,
#  '😪': <gensim.models.keyedvectors.Vocab at 0x1a29ac8fd0>,
#  '👎': <gensim.models.keyedvectors.Vocab at 0x1a29ad3048>,
#  '🍡': <gensim.models.keyedvectors.Vocab at 0x1a29ad3080>,
#  '🍨': <gensim.models.keyedvectors.Vocab at 0x1a29ad30b8>,
#  '🍧': <gensim.models.keyedvectors.Vocab at 0x1a29ad30f0>,
#  '🚔': <gensim.models.keyedvectors.Vocab at 0x1a29ad3128>,
#  '🚒': <gensim.models.keyedvectors.Vocab at 0x1a29ad3160>,
#  '🎾': <gensim.models.keyedvectors.Vocab at 0x1a29ad3198>,
#  '🌋': <gensim.models.keyedvectors.Vocab at 0x1a29ad31d0>,
#  '💼': <gensim.models.keyedvectors.Vocab at 0x1a29ad3208>,
#  '🥈': <gensim.models.keyedvectors.Vocab at 0x1a29ad3240>,
#  '⛓': <gensim.models.keyedvectors.Vocab at 0x1a29ad3278>,
#  '🥉': <gensim.models.keyedvectors.Vocab at 0x1a29ad32b0>,
#  '👃': <gensim.models.keyedvectors.Vocab at 0x1a29ad32e8>,
#  '🖌': <gensim.models.keyedvectors.Vocab at 0x1a29ad3320>,
#  '🍅': <gensim.models.keyedvectors.Vocab at 0x1a29ad3358>,
#  '🥟': <gensim.models.keyedvectors.Vocab at 0x1a29ad3390>,
#  '🥐': <gensim.models.keyedvectors.Vocab at 0x1a29ad33c8>,
#  '🌮': <gensim.models.keyedvectors.Vocab at 0x1a29ad3400>,
#  '🍣': <gensim.models.keyedvectors.Vocab at 0x1a29ad3438>,
#  '🦇': <gensim.models.keyedvectors.Vocab at 0x1a29ad3470>,
#  '🗒': <gensim.models.keyedvectors.Vocab at 0x1a29ad34a8>,
#  '🖍': <gensim.models.keyedvectors.Vocab at 0x1a29ad34e0>,
#  '🗞': <gensim.models.keyedvectors.Vocab at 0x1a29ad3518>,
#  '🚘': <gensim.models.keyedvectors.Vocab at 0x1a29ad3550>,
#  '🚣': <gensim.models.keyedvectors.Vocab at 0x1a29ad3588>,
#  '🅰': <gensim.models.keyedvectors.Vocab at 0x1a29ad35c0>,
#  '🅿': <gensim.models.keyedvectors.Vocab at 0x1a29ad35f8>,
#  '📧': <gensim.models.keyedvectors.Vocab at 0x1a29ad3630>,
#  '©': <gensim.models.keyedvectors.Vocab at 0x1a29ad3668>,
#  '🔛': <gensim.models.keyedvectors.Vocab at 0x1a29ad36a0>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x1a29ad36d8>,
#  '⬇': <gensim.models.keyedvectors.Vocab at 0x1a29ad3710>,
#  '✖': <gensim.models.keyedvectors.Vocab at 0x1a29ad3748>,
#  '🔮': <gensim.models.keyedvectors.Vocab at 0x1a29ad3780>,
#  '🗿': <gensim.models.keyedvectors.Vocab at 0x1a29ad37b8>,
#  '🎒': <gensim.models.keyedvectors.Vocab at 0x1a29ad37f0>,
#  '⚫': <gensim.models.keyedvectors.Vocab at 0x1a29ad3828>,
#  '🍱': <gensim.models.keyedvectors.Vocab at 0x1a29ad3860>,
#  '🧐': <gensim.models.keyedvectors.Vocab at 0x1a29ad3898>,
#  '⛪': <gensim.models.keyedvectors.Vocab at 0x1a29ad38d0>,
#  '🗡': <gensim.models.keyedvectors.Vocab at 0x1a29ad3908>,
#  '🏋': <gensim.models.keyedvectors.Vocab at 0x1a29ad3940>,
#  '🐼': <gensim.models.keyedvectors.Vocab at 0x1a29ad3978>,
#  '🚌': <gensim.models.keyedvectors.Vocab at 0x1a29ad39b0>,
#  '💇': <gensim.models.keyedvectors.Vocab at 0x1a29ad39e8>,
#  '🏉': <gensim.models.keyedvectors.Vocab at 0x1a29ad3a20>,
#  '⚔': <gensim.models.keyedvectors.Vocab at 0x1a29ad3a58>,
#  '☝': <gensim.models.keyedvectors.Vocab at 0x1a29ad3a90>,
#  '🌔': <gensim.models.keyedvectors.Vocab at 0x1a29ad3ac8>,
#  '⤵': <gensim.models.keyedvectors.Vocab at 0x1a29ad3b00>,
#  '💵': <gensim.models.keyedvectors.Vocab at 0x1a29ad3b38>,
#  '☄': <gensim.models.keyedvectors.Vocab at 0x1a29ad3b70>,
#  '🐺': <gensim.models.keyedvectors.Vocab at 0x1a29ad3ba8>,
#  '🧕': <gensim.models.keyedvectors.Vocab at 0x1a29ad3be0>,
#  '🐉': <gensim.models.keyedvectors.Vocab at 0x1a29ad3c18>,
#  '🆙': <gensim.models.keyedvectors.Vocab at 0x1a29ad3c50>,
#  '🧙': <gensim.models.keyedvectors.Vocab at 0x1a29ad3c88>,
#  '👿': <gensim.models.keyedvectors.Vocab at 0x1a29ad3cc0>,
#  '🤳': <gensim.models.keyedvectors.Vocab at 0x1a29ad3cf8>,
#  '🐂': <gensim.models.keyedvectors.Vocab at 0x1a29ad3d30>,
#  '👤': <gensim.models.keyedvectors.Vocab at 0x1a29ad3d68>,
#  '🌽': <gensim.models.keyedvectors.Vocab at 0x1a29ad3da0>,
#  '🇴': <gensim.models.keyedvectors.Vocab at 0x1a29ad3dd8>,
#  '🤐': <gensim.models.keyedvectors.Vocab at 0x1a29ad3e10>,
#  '🗝': <gensim.models.keyedvectors.Vocab at 0x1a29ad3e48>,
#  '🌲': <gensim.models.keyedvectors.Vocab at 0x1a29ad3e80>,
#  '🌀': <gensim.models.keyedvectors.Vocab at 0x1a29ad3eb8>,
#  '🔚': <gensim.models.keyedvectors.Vocab at 0x1a29ad3ef0>,
#  '🍖': <gensim.models.keyedvectors.Vocab at 0x1a29ad3f28>,
#  '🐚': <gensim.models.keyedvectors.Vocab at 0x1a29ad3f60>,
#  '☘': <gensim.models.keyedvectors.Vocab at 0x1a29ad3f98>,
#  '⛈': <gensim.models.keyedvectors.Vocab at 0x1a29ad3fd0>,
#  '⚖': <gensim.models.keyedvectors.Vocab at 0x1a29ade048>,
#  '📵': <gensim.models.keyedvectors.Vocab at 0x1a29ade080>,
#  '🔐': <gensim.models.keyedvectors.Vocab at 0x1a29ade0b8>,
#  '🦕': <gensim.models.keyedvectors.Vocab at 0x1a29ade0f0>,
#  '👐': <gensim.models.keyedvectors.Vocab at 0x1a29ade128>,
#  '👓': <gensim.models.keyedvectors.Vocab at 0x1a29ade160>,
#  '🧦': <gensim.models.keyedvectors.Vocab at 0x1a29ade198>,
#  '🥃': <gensim.models.keyedvectors.Vocab at 0x1a29ade1d0>,
#  '🎡': <gensim.models.keyedvectors.Vocab at 0x1a29ade208>,
#  '☸': <gensim.models.keyedvectors.Vocab at 0x1a29ade240>,
#  '🏹': <gensim.models.keyedvectors.Vocab at 0x1a29ade278>,
#  '⌛': <gensim.models.keyedvectors.Vocab at 0x1a29ade2b0>,
#  '🥜': <gensim.models.keyedvectors.Vocab at 0x1a29ade2e8>,
#  '💠': <gensim.models.keyedvectors.Vocab at 0x1a29ade320>,
#  '🦆': <gensim.models.keyedvectors.Vocab at 0x1a29ade358>,
#  '✡': <gensim.models.keyedvectors.Vocab at 0x1a29ade390>,
#  '🕳': <gensim.models.keyedvectors.Vocab at 0x1a29ade3c8>,
#  '👽': <gensim.models.keyedvectors.Vocab at 0x1a29ade400>,
#  '⚾': <gensim.models.keyedvectors.Vocab at 0x1a29ade438>,
#  '🗻': <gensim.models.keyedvectors.Vocab at 0x1a29ade470>,
#  '🏰': <gensim.models.keyedvectors.Vocab at 0x1a29ade4a8>,
#  '🍴': <gensim.models.keyedvectors.Vocab at 0x1a29ade4e0>,
#  '🔱': <gensim.models.keyedvectors.Vocab at 0x1a29ade518>,
#  '🚹': <gensim.models.keyedvectors.Vocab at 0x1a29ade550>,
#  '⛽': <gensim.models.keyedvectors.Vocab at 0x1a29ade588>,
#  '🥓': <gensim.models.keyedvectors.Vocab at 0x1a29ade5c0>,
#  '🥪': <gensim.models.keyedvectors.Vocab at 0x1a29ade5f8>,
#  '🥨': <gensim.models.keyedvectors.Vocab at 0x1a29ade630>,
#  '🥖': <gensim.models.keyedvectors.Vocab at 0x1a29ade668>,
#  '🐞': <gensim.models.keyedvectors.Vocab at 0x1a29ade6a0>,
#  '🍎': <gensim.models.keyedvectors.Vocab at 0x1a29ade6d8>,
#  '☹': <gensim.models.keyedvectors.Vocab at 0x1a29ade710>,
#  '⛹': <gensim.models.keyedvectors.Vocab at 0x1a29ade748>,
#  '🤚': <gensim.models.keyedvectors.Vocab at 0x1a29ade780>,
#  '🌭': <gensim.models.keyedvectors.Vocab at 0x1a29ade7b8>,
#  '🦉': <gensim.models.keyedvectors.Vocab at 0x1a29ade7f0>,
#  '🛡': <gensim.models.keyedvectors.Vocab at 0x1a29ade828>,
#  '🍯': <gensim.models.keyedvectors.Vocab at 0x1a29ade860>,
#  '🕹': <gensim.models.keyedvectors.Vocab at 0x1a29ade898>,
#  '🌇': <gensim.models.keyedvectors.Vocab at 0x1a29ade8d0>,
#  '👞': <gensim.models.keyedvectors.Vocab at 0x1a29ade908>,
#  '🤛': <gensim.models.keyedvectors.Vocab at 0x1a29ade940>,
#  '🐟': <gensim.models.keyedvectors.Vocab at 0x1a29ade978>,
#  '🔽': <gensim.models.keyedvectors.Vocab at 0x1a29ade9b0>,
#  '👆': <gensim.models.keyedvectors.Vocab at 0x1a29ade9e8>,
#  '🏨': <gensim.models.keyedvectors.Vocab at 0x1a29adea20>,
#  '🏥': <gensim.models.keyedvectors.Vocab at 0x1a29adea58>,
#  '🔢': <gensim.models.keyedvectors.Vocab at 0x1a29adea90>,
#  '⚛': <gensim.models.keyedvectors.Vocab at 0x1a29adeac8>,
#  '🐨': <gensim.models.keyedvectors.Vocab at 0x1a29adeb00>,
#  '\U000e0065': <gensim.models.keyedvectors.Vocab at 0x1a29adeb38>,
#  '\U000e006e': <gensim.models.keyedvectors.Vocab at 0x1a29adeb70>,
#  '🎺': <gensim.models.keyedvectors.Vocab at 0x1a29adeba8>,
#  '🍼': <gensim.models.keyedvectors.Vocab at 0x1a29adebe0>,
#  '⬛': <gensim.models.keyedvectors.Vocab at 0x1a29adec18>,
#  '😗': <gensim.models.keyedvectors.Vocab at 0x1a29adec50>,
#  '🕋': <gensim.models.keyedvectors.Vocab at 0x1a29adec88>,
#  '📿': <gensim.models.keyedvectors.Vocab at 0x1a29adecc0>,
#  '🚢': <gensim.models.keyedvectors.Vocab at 0x1a29adecf8>,
#  '🥞': <gensim.models.keyedvectors.Vocab at 0x1a29aded30>,
#  '🐹': <gensim.models.keyedvectors.Vocab at 0x1a29aded68>,
#  '🥕': <gensim.models.keyedvectors.Vocab at 0x1a29adeda0>,
#  '🤰': <gensim.models.keyedvectors.Vocab at 0x1a29adedd8>,
#  '⁉': <gensim.models.keyedvectors.Vocab at 0x1a29adee10>,
#  '💲': <gensim.models.keyedvectors.Vocab at 0x1a29adee48>,
#  '♑': <gensim.models.keyedvectors.Vocab at 0x1a29adee80>,
#  '🐋': <gensim.models.keyedvectors.Vocab at 0x1a29adeeb8>,
#  '🐳': <gensim.models.keyedvectors.Vocab at 0x1a29adeef0>,
#  '🦑': <gensim.models.keyedvectors.Vocab at 0x1a29adef28>,
#  '🦀': <gensim.models.keyedvectors.Vocab at 0x1a29adef60>,
#  '◾': <gensim.models.keyedvectors.Vocab at 0x1a29adef98>,
#  '🔶': <gensim.models.keyedvectors.Vocab at 0x1a29adefd0>,
#  '⏩': <gensim.models.keyedvectors.Vocab at 0x1a29ae6048>,
#  '🐅': <gensim.models.keyedvectors.Vocab at 0x1a29ae6080>,
#  '🤨': <gensim.models.keyedvectors.Vocab at 0x1a29ae60b8>,
#  '👷': <gensim.models.keyedvectors.Vocab at 0x1a29ae60f0>,
#  '🏘': <gensim.models.keyedvectors.Vocab at 0x1a29ae6128>,
#  '🌪': <gensim.models.keyedvectors.Vocab at 0x1a29ae6160>,
#  '🧛': <gensim.models.keyedvectors.Vocab at 0x1a29ae6198>,
#  '✂': <gensim.models.keyedvectors.Vocab at 0x1a29ae61d0>,
#  '🔷': <gensim.models.keyedvectors.Vocab at 0x1a29ae6208>,
#  '🔍': <gensim.models.keyedvectors.Vocab at 0x1a29ae6240>,
#  '🔎': <gensim.models.keyedvectors.Vocab at 0x1a29ae6278>,
#  '🌯': <gensim.models.keyedvectors.Vocab at 0x1a29ae62b0>,
#  '✝': <gensim.models.keyedvectors.Vocab at 0x1a29ae62e8>,
#  '➕': <gensim.models.keyedvectors.Vocab at 0x1a29ae6320>,
#  '🖖': <gensim.models.keyedvectors.Vocab at 0x1a29ae6358>,
#  '⚰': <gensim.models.keyedvectors.Vocab at 0x1a29ae6390>,
#  '👾': <gensim.models.keyedvectors.Vocab at 0x1a29ae63c8>,
#  '⛩': <gensim.models.keyedvectors.Vocab at 0x1a29ae6400>,
#  '🧥': <gensim.models.keyedvectors.Vocab at 0x1a29ae6438>,
#  '📮': <gensim.models.keyedvectors.Vocab at 0x1a29ae6470>,
#  '🎠': <gensim.models.keyedvectors.Vocab at 0x1a29ae64a8>,
#  '🎭': <gensim.models.keyedvectors.Vocab at 0x1a29ae64e0>,
#  '🎢': <gensim.models.keyedvectors.Vocab at 0x1a29ae6518>,
#  '😼': <gensim.models.keyedvectors.Vocab at 0x1a29ae6550>,
#  '🤲': <gensim.models.keyedvectors.Vocab at 0x1a29ae6588>,
#  '🧜': <gensim.models.keyedvectors.Vocab at 0x1a29ae65c0>,
#  '🚬': <gensim.models.keyedvectors.Vocab at 0x1a29ae65f8>,
#  '🏇': <gensim.models.keyedvectors.Vocab at 0x1a29ae6630>,
#  '🎄': <gensim.models.keyedvectors.Vocab at 0x1a29ae6668>,
#  '🗂': <gensim.models.keyedvectors.Vocab at 0x1a29ae66a0>,
#  '🐀': <gensim.models.keyedvectors.Vocab at 0x1a29ae66d8>,
#  '🔸': <gensim.models.keyedvectors.Vocab at 0x1a29ae6710>,
#  '👚': <gensim.models.keyedvectors.Vocab at 0x1a29ae6748>,
#  '👡': <gensim.models.keyedvectors.Vocab at 0x1a29ae6780>,
#  '👖': <gensim.models.keyedvectors.Vocab at 0x1a29ae67b8>,
#  '👜': <gensim.models.keyedvectors.Vocab at 0x1a29ae67f0>,
#  '🎞': <gensim.models.keyedvectors.Vocab at 0x1a29ae6828>,
#  '♻': <gensim.models.keyedvectors.Vocab at 0x1a29ae6860>,
#  '😓': <gensim.models.keyedvectors.Vocab at 0x1a29ae6898>,
#  '📣': <gensim.models.keyedvectors.Vocab at 0x1a29ae68d0>,
#  '✴': <gensim.models.keyedvectors.Vocab at 0x1a29ae6908>,
#  '🐭': <gensim.models.keyedvectors.Vocab at 0x1a29ae6940>,
#  '🚧': <gensim.models.keyedvectors.Vocab at 0x1a29ae6978>,
#  '♏': <gensim.models.keyedvectors.Vocab at 0x1a29ae69b0>,
#  '🆖': <gensim.models.keyedvectors.Vocab at 0x1a29ae69e8>,
#  '💩': <gensim.models.keyedvectors.Vocab at 0x1a29ae6a20>,
#  '🍍': <gensim.models.keyedvectors.Vocab at 0x1a29ae6a58>,
#  '🚁': <gensim.models.keyedvectors.Vocab at 0x1a29ae6a90>,
#  '🌘': <gensim.models.keyedvectors.Vocab at 0x1a29ae6ac8>,
#  '🍛': <gensim.models.keyedvectors.Vocab at 0x1a29ae6b00>,
#  '🎅': <gensim.models.keyedvectors.Vocab at 0x1a29ae6b38>,
#  '🚿': <gensim.models.keyedvectors.Vocab at 0x1a29ae6b70>,
#  '🚐': <gensim.models.keyedvectors.Vocab at 0x1a29ae6ba8>,
#  '🎌': <gensim.models.keyedvectors.Vocab at 0x1a29ae6be0>,
#  '🎣': <gensim.models.keyedvectors.Vocab at 0x1a29ae6c18>,
#  '♿': <gensim.models.keyedvectors.Vocab at 0x1a29ae6c50>,
#  '🌵': <gensim.models.keyedvectors.Vocab at 0x1a29ae6c88>,
#  '✒': <gensim.models.keyedvectors.Vocab at 0x1a29ae6cc0>,
#  '📂': <gensim.models.keyedvectors.Vocab at 0x1a29ae6cf8>,
#  '🔒': <gensim.models.keyedvectors.Vocab at 0x1a29ae6d30>,
#  '👬': <gensim.models.keyedvectors.Vocab at 0x1a29ae6d68>,
#  '📦': <gensim.models.keyedvectors.Vocab at 0x1a29ae6da0>,
#  '🏚': <gensim.models.keyedvectors.Vocab at 0x1a29ae6dd8>,
#  '✈': <gensim.models.keyedvectors.Vocab at 0x1a29ae6e10>,
#  '🐓': <gensim.models.keyedvectors.Vocab at 0x1a29ae6e48>,
#  '🛁': <gensim.models.keyedvectors.Vocab at 0x1a29ae6e80>,
#  '▪': <gensim.models.keyedvectors.Vocab at 0x1a29ae6eb8>,
#  '➖': <gensim.models.keyedvectors.Vocab at 0x1a29ae6ef0>,
#  '⛴': <gensim.models.keyedvectors.Vocab at 0x1a29ae6f28>,
#  '🍢': <gensim.models.keyedvectors.Vocab at 0x1a29ae6f60>,
#  '🐮': <gensim.models.keyedvectors.Vocab at 0x1a29ae6f98>,
#  '♌': <gensim.models.keyedvectors.Vocab at 0x1a29ae6fd0>,
#  '🧟': <gensim.models.keyedvectors.Vocab at 0x1a29af0048>,
#  '🤬': <gensim.models.keyedvectors.Vocab at 0x1a29af0080>,
#  '💳': <gensim.models.keyedvectors.Vocab at 0x1a29af00b8>,
#  '📊': <gensim.models.keyedvectors.Vocab at 0x1a29af00f0>,
#  '🕉': <gensim.models.keyedvectors.Vocab at 0x1a29af0128>,
#  '🧘': <gensim.models.keyedvectors.Vocab at 0x1a29af0160>,
#  '🐩': <gensim.models.keyedvectors.Vocab at 0x1a29af0198>,
#  '💴': <gensim.models.keyedvectors.Vocab at 0x1a29af01d0>,
#  '▫': <gensim.models.keyedvectors.Vocab at 0x1a29af0208>,
#  '📙': <gensim.models.keyedvectors.Vocab at 0x1a29af0240>,
#  '📓': <gensim.models.keyedvectors.Vocab at 0x1a29af0278>,
#  '🛅': <gensim.models.keyedvectors.Vocab at 0x1a29af02b0>,
#  '🥋': <gensim.models.keyedvectors.Vocab at 0x1a29af02e8>,
#  '🎍': <gensim.models.keyedvectors.Vocab at 0x1a29af0320>,
#  '🖥': <gensim.models.keyedvectors.Vocab at 0x1a29af0358>,
#  '🆒': <gensim.models.keyedvectors.Vocab at 0x1a29af0390>,
#  '🦖': <gensim.models.keyedvectors.Vocab at 0x1a29af03c8>,
#  '🤼': <gensim.models.keyedvectors.Vocab at 0x1a29af0400>,
#  '🐿': <gensim.models.keyedvectors.Vocab at 0x1a29af0438>,
#  '🔭': <gensim.models.keyedvectors.Vocab at 0x1a29af0470>,
#  '🍄': <gensim.models.keyedvectors.Vocab at 0x1a29af04a8>,
#  '🚾': <gensim.models.keyedvectors.Vocab at 0x1a29af04e0>,
#  '🛒': <gensim.models.keyedvectors.Vocab at 0x1a29af0518>,
#  '◽': <gensim.models.keyedvectors.Vocab at 0x1a29af0550>,
#  '🔙': <gensim.models.keyedvectors.Vocab at 0x1a29af0588>,
#  '🍶': <gensim.models.keyedvectors.Vocab at 0x1a29af05c0>,
#  '🔄': <gensim.models.keyedvectors.Vocab at 0x1a29af05f8>,
#  '✉': <gensim.models.keyedvectors.Vocab at 0x1a29af0630>,
#  '🎐': <gensim.models.keyedvectors.Vocab at 0x1a29af0668>,
#  '🍚': <gensim.models.keyedvectors.Vocab at 0x1a29af06a0>,
#  '⏳': <gensim.models.keyedvectors.Vocab at 0x1a29af06d8>,
#  '🆚': <gensim.models.keyedvectors.Vocab at 0x1a29af0710>,
#  '💹': <gensim.models.keyedvectors.Vocab at 0x1a29af0748>,
#  '☪': <gensim.models.keyedvectors.Vocab at 0x1a29af0780>,
#  '🤱': <gensim.models.keyedvectors.Vocab at 0x1a29af07b8>,
#  '🔦': <gensim.models.keyedvectors.Vocab at 0x1a29af07f0>,
#  '📎': <gensim.models.keyedvectors.Vocab at 0x1a29af0828>,
#  '☢': <gensim.models.keyedvectors.Vocab at 0x1a29af0860>,
#  '🗼': <gensim.models.keyedvectors.Vocab at 0x1a29af0898>,
#  '👒': <gensim.models.keyedvectors.Vocab at 0x1a29af08d0>,
#  '♨': <gensim.models.keyedvectors.Vocab at 0x1a29af0908>,
#  '🥘': <gensim.models.keyedvectors.Vocab at 0x1a29af0940>,
#  '👛': <gensim.models.keyedvectors.Vocab at 0x1a29af0978>,
#  '😧': <gensim.models.keyedvectors.Vocab at 0x1a29af09b0>,
#  '🥝': <gensim.models.keyedvectors.Vocab at 0x1a29af09e8>,
#  '📔': <gensim.models.keyedvectors.Vocab at 0x1a29af0a20>,
#  '📞': <gensim.models.keyedvectors.Vocab at 0x1a29af0a58>,
#  '🐡': <gensim.models.keyedvectors.Vocab at 0x1a29af0a90>,
#  '😿': <gensim.models.keyedvectors.Vocab at 0x1a29af0ac8>,
#  '🏑': <gensim.models.keyedvectors.Vocab at 0x1a29af0b00>,
#  '◼': <gensim.models.keyedvectors.Vocab at 0x1a29af0b38>,
#  '🍲': <gensim.models.keyedvectors.Vocab at 0x1a29af0b70>,
#  '❇': <gensim.models.keyedvectors.Vocab at 0x1a29af0ba8>,
#  '🌗': <gensim.models.keyedvectors.Vocab at 0x1a29af0be0>,
#  '🌖': <gensim.models.keyedvectors.Vocab at 0x1a29af0c18>,
#  '🙎': <gensim.models.keyedvectors.Vocab at 0x1a29af0c50>,
#  '❎': <gensim.models.keyedvectors.Vocab at 0x1a29af0c88>,
#  '♦': <gensim.models.keyedvectors.Vocab at 0x1a29af0cc0>,
#  '🍵': <gensim.models.keyedvectors.Vocab at 0x1a29af0cf8>,
#  '⛰': <gensim.models.keyedvectors.Vocab at 0x1a29af0d30>,
#  '🇶': <gensim.models.keyedvectors.Vocab at 0x1a29af0d68>,
#  '🐒': <gensim.models.keyedvectors.Vocab at 0x1a29af0da0>,
#  '⚒': <gensim.models.keyedvectors.Vocab at 0x1a29af0dd8>,
#  '🌫': <gensim.models.keyedvectors.Vocab at 0x1a29af0e10>,
#  '🥣': <gensim.models.keyedvectors.Vocab at 0x1a29af0e48>,
#  '⛅': <gensim.models.keyedvectors.Vocab at 0x1a29af0e80>,
#  '🛬': <gensim.models.keyedvectors.Vocab at 0x1a29af0eb8>,
#  '🥢': <gensim.models.keyedvectors.Vocab at 0x1a29af0ef0>,
#  '🍤': <gensim.models.keyedvectors.Vocab at 0x1a29af0f28>,
#  '📅': <gensim.models.keyedvectors.Vocab at 0x1a29af0f60>,
#  '🇼': <gensim.models.keyedvectors.Vocab at 0x1a29af0f98>,
#  '🎱': <gensim.models.keyedvectors.Vocab at 0x1a29af0fd0>,
#  '🦃': <gensim.models.keyedvectors.Vocab at 0x1a29afb048>,
#  '🏸': <gensim.models.keyedvectors.Vocab at 0x1a29afb080>,
#  '🌓': <gensim.models.keyedvectors.Vocab at 0x1a29afb0b8>,
#  '🏙': <gensim.models.keyedvectors.Vocab at 0x1a29afb0f0>,
#  '👴': <gensim.models.keyedvectors.Vocab at 0x1a29afb128>,
#  '🚰': <gensim.models.keyedvectors.Vocab at 0x1a29afb160>,
#  '🧒': <gensim.models.keyedvectors.Vocab at 0x1a29afb198>,
#  '🎰': <gensim.models.keyedvectors.Vocab at 0x1a29afb1d0>,
#  '🔹': <gensim.models.keyedvectors.Vocab at 0x1a29afb208>,
#  '☁': <gensim.models.keyedvectors.Vocab at 0x1a29afb240>,
#  '⬆': <gensim.models.keyedvectors.Vocab at 0x1a29afb278>,
#  '🎃': <gensim.models.keyedvectors.Vocab at 0x1a29afb2b0>,
#  '📍': <gensim.models.keyedvectors.Vocab at 0x1a29afb2e8>,
#  '🛰': <gensim.models.keyedvectors.Vocab at 0x1a29afb320>,
#  '📜': <gensim.models.keyedvectors.Vocab at 0x1a29afb358>,
#  '⚗': <gensim.models.keyedvectors.Vocab at 0x1a29afb390>,
#  '🐖': <gensim.models.keyedvectors.Vocab at 0x1a29afb3c8>,
#  '♊': <gensim.models.keyedvectors.Vocab at 0x1a29afb400>,
#  '🧔': <gensim.models.keyedvectors.Vocab at 0x1a29afb438>,
#  '🛵': <gensim.models.keyedvectors.Vocab at 0x1a29afb470>,
#  '🛏': <gensim.models.keyedvectors.Vocab at 0x1a29afb4a8>,
#  '🏪': <gensim.models.keyedvectors.Vocab at 0x1a29afb4e0>,
#  '🚵': <gensim.models.keyedvectors.Vocab at 0x1a29afb518>,
#  '🦐': <gensim.models.keyedvectors.Vocab at 0x1a29afb550>,
#  '📒': <gensim.models.keyedvectors.Vocab at 0x1a29afb588>,
#  '🇻': <gensim.models.keyedvectors.Vocab at 0x1a29afb5c0>,
#  '☑': <gensim.models.keyedvectors.Vocab at 0x1a29afb5f8>,
#  '🖼': <gensim.models.keyedvectors.Vocab at 0x1a29afb630>,
#  '🎽': <gensim.models.keyedvectors.Vocab at 0x1a29afb668>,
#  '👝': <gensim.models.keyedvectors.Vocab at 0x1a29afb6a0>,
#  '🐜': <gensim.models.keyedvectors.Vocab at 0x1a29afb6d8>,
#  '📼': <gensim.models.keyedvectors.Vocab at 0x1a29afb710>,
#  '🎗': <gensim.models.keyedvectors.Vocab at 0x1a29afb748>,
#  '🔓': <gensim.models.keyedvectors.Vocab at 0x1a29afb780>,
#  '🅾': <gensim.models.keyedvectors.Vocab at 0x1a29afb7b8>,
#  '🅱': <gensim.models.keyedvectors.Vocab at 0x1a29afb7f0>,
#  '⌨': <gensim.models.keyedvectors.Vocab at 0x1a29afb828>,
#  '🕰': <gensim.models.keyedvectors.Vocab at 0x1a29afb860>,
#  '🐏': <gensim.models.keyedvectors.Vocab at 0x1a29afb898>,
#  '🛩': <gensim.models.keyedvectors.Vocab at 0x1a29afb8d0>,
#  '🌒': <gensim.models.keyedvectors.Vocab at 0x1a29afb908>,
#  '🧗': <gensim.models.keyedvectors.Vocab at 0x1a29afb940>,
#  '🐆': <gensim.models.keyedvectors.Vocab at 0x1a29afb978>,
#  '🛳': <gensim.models.keyedvectors.Vocab at 0x1a29afb9b0>,
#  '🍈': <gensim.models.keyedvectors.Vocab at 0x1a29afb9e8>,
#  '🛌': <gensim.models.keyedvectors.Vocab at 0x1a29afba20>,
#  '👪': <gensim.models.keyedvectors.Vocab at 0x1a29afba58>,
#  '🏵': <gensim.models.keyedvectors.Vocab at 0x1a29afba90>,
#  '🖋': <gensim.models.keyedvectors.Vocab at 0x1a29afbac8>,
#  '🗑': <gensim.models.keyedvectors.Vocab at 0x1a29afbb00>,
#  '🐲': <gensim.models.keyedvectors.Vocab at 0x1a29afbb38>,
#  '⛱': <gensim.models.keyedvectors.Vocab at 0x1a29afbb70>,
#  '🛋': <gensim.models.keyedvectors.Vocab at 0x1a29afbba8>,
#  '🆎': <gensim.models.keyedvectors.Vocab at 0x1a29afbbe0>,
#  '📯': <gensim.models.keyedvectors.Vocab at 0x1a29afbc18>,
#  '🏷': <gensim.models.keyedvectors.Vocab at 0x1a29afbc50>,
#  'Ⓜ': <gensim.models.keyedvectors.Vocab at 0x1a29afbc88>,
#  '🐛': <gensim.models.keyedvectors.Vocab at 0x1a29afbcc0>,
#  '🏂': <gensim.models.keyedvectors.Vocab at 0x1a29afbcf8>,
#  '🕸': <gensim.models.keyedvectors.Vocab at 0x1a29afbd30>,
#  '🧝': <gensim.models.keyedvectors.Vocab at 0x1a29afbd68>,
#  '🚜': <gensim.models.keyedvectors.Vocab at 0x1a29afbda0>,
#  '🚤': <gensim.models.keyedvectors.Vocab at 0x1a29afbdd8>,
#  '🛥': <gensim.models.keyedvectors.Vocab at 0x1a29afbe10>,
#  '🧑': <gensim.models.keyedvectors.Vocab at 0x1a29afbe48>,
#  '🃏': <gensim.models.keyedvectors.Vocab at 0x1a29afbe80>,
#  '🚷': <gensim.models.keyedvectors.Vocab at 0x1a29afbeb8>,
#  '🥑': <gensim.models.keyedvectors.Vocab at 0x1a29afbef0>,
#  '♋': <gensim.models.keyedvectors.Vocab at 0x1a29afbf28>,
#  '🐁': <gensim.models.keyedvectors.Vocab at 0x1a29afbf60>,
#  '🗺': <gensim.models.keyedvectors.Vocab at 0x1a29afbf98>,
#  '👘': <gensim.models.keyedvectors.Vocab at 0x1a29afbfd0>,
#  '📥': <gensim.models.keyedvectors.Vocab at 0x1a29b05048>,
#  '🆑': <gensim.models.keyedvectors.Vocab at 0x1a29b05080>,
#  '➰': <gensim.models.keyedvectors.Vocab at 0x1a29b050b8>,
#  '🦓': <gensim.models.keyedvectors.Vocab at 0x1a29b050f0>,
#  '💈': <gensim.models.keyedvectors.Vocab at 0x1a29b05128>,
#  '🖊': <gensim.models.keyedvectors.Vocab at 0x1a29b05160>,
#  '⛺': <gensim.models.keyedvectors.Vocab at 0x1a29b05198>,
#  '🐌': <gensim.models.keyedvectors.Vocab at 0x1a29b051d0>,
#  '🐫': <gensim.models.keyedvectors.Vocab at 0x1a29b05208>,
#  '\U000e0077': <gensim.models.keyedvectors.Vocab at 0x1a29b05240>,
#  '\U000e006c': <gensim.models.keyedvectors.Vocab at 0x1a29b05278>,
#  '🧤': <gensim.models.keyedvectors.Vocab at 0x1a29b052b0>,
#  '🍐': <gensim.models.keyedvectors.Vocab at 0x1a29b052e8>,
#  '📩': <gensim.models.keyedvectors.Vocab at 0x1a29b05320>,
#  '🔃': <gensim.models.keyedvectors.Vocab at 0x1a29b05358>,
#  '📘': <gensim.models.keyedvectors.Vocab at 0x1a29b05390>,
#  '🧖': <gensim.models.keyedvectors.Vocab at 0x1a29b053c8>,
#  '🌑': <gensim.models.keyedvectors.Vocab at 0x1a29b05400>,
#  '🤥': <gensim.models.keyedvectors.Vocab at 0x1a29b05438>,
#  '✳': <gensim.models.keyedvectors.Vocab at 0x1a29b05470>,
#  '📶': <gensim.models.keyedvectors.Vocab at 0x1a29b054a8>,
#  '🌰': <gensim.models.keyedvectors.Vocab at 0x1a29b054e0>,
#  '🏧': <gensim.models.keyedvectors.Vocab at 0x1a29b05518>,
#  '🛤': <gensim.models.keyedvectors.Vocab at 0x1a29b05550>,
#  '🔧': <gensim.models.keyedvectors.Vocab at 0x1a29b05588>,
#  '🤹': <gensim.models.keyedvectors.Vocab at 0x1a29b055c0>,
#  '📏': <gensim.models.keyedvectors.Vocab at 0x1a29b055f8>,
#  '☃': <gensim.models.keyedvectors.Vocab at 0x1a29b05630>,
#  '⛲': <gensim.models.keyedvectors.Vocab at 0x1a29b05668>,
#  '⚕': <gensim.models.keyedvectors.Vocab at 0x1a29b056a0>,
#  '🀄': <gensim.models.keyedvectors.Vocab at 0x1a29b056d8>,
#  '🚽': <gensim.models.keyedvectors.Vocab at 0x1a29b05710>,
#  '🧓': <gensim.models.keyedvectors.Vocab at 0x1a29b05748>,
#  '♈': <gensim.models.keyedvectors.Vocab at 0x1a29b05780>,
#  '🍥': <gensim.models.keyedvectors.Vocab at 0x1a29b057b8>,
#  '🦔': <gensim.models.keyedvectors.Vocab at 0x1a29b057f0>,
#  '🥙': <gensim.models.keyedvectors.Vocab at 0x1a29b05828>,
#  '🚅': <gensim.models.keyedvectors.Vocab at 0x1a29b05860>,
#  '🚋': <gensim.models.keyedvectors.Vocab at 0x1a29b05898>,
#  '🦂': <gensim.models.keyedvectors.Vocab at 0x1a29b058d0>,
#  ...}

# %%
thrones2vec.wv.most_similar('😍')
# Out:
# /anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('😘', 0.9771696925163269),
#  ('❤️', 0.9631988406181335),
#  ('😢', 0.1335771232843399),
#  ('🙁', 0.11866120994091034),
#  ('😳', 0.10258054733276367),
#  ('🤔', 0.09710533171892166)]

# %%
# extracts the 508 Annotator Results as the Gold-Standard
corpus_filename = '../data/EmoSim508.json'
corpus = open(corpus_filename).read()
annotator_similarity_score_508 = list(array(re.findall('(?<=_Annotator_Agreement": )(.*?)(?=\})', corpus)))

# glyph_pairs_1016
unicode_pairs_1016 = re.findall('(?<=unicodelong": "\\\)(.*?)(?=")', corpus)    
glyph_pairs_1016 = [codecs.decode(unicode_pairs_1016[x].replace(str('\\\\'),str('\\')).replace('_',''), 'unicode_escape') for x in range(len(unicode_pairs_1016))]

# fdfdsfaf
goldstandard = []
selftrained = []
for x in range(len(annotator_similarity_score_508)):
    cosineSimilarity = None
    
    emoji1 = glyph_pairs_1016.pop(0)
    emoji2 = glyph_pairs_1016.pop(0)
    
    try:
        cosineSimilarity = thrones2vec.wv.similarity(emoji1, emoji2)
    except:
        print('the cosine similarity between ' + emoji1 + ' and ' + emoji2 + ' could not be computed.')
    
    if(cosineSimilarity is not None):
        goldstandard.append(cosineSimilarity)
        selftrained.append(annotator_similarity_score_508.pop(0))
print(len(goldstandard))
print(len(selftrained))

spearmanRank = stats.spearmanr(goldstandard, selftrained)

print('Der Spearman Rank Correlation Coefficient is {}'.format(spearmanRank))
# Out:
# the cosine similarity between 🎵 and 🎶 could not be computed.
# the cosine similarity between 🎊 and 🎉 could not be computed.
# the cosine similarity between ☺ and 😊 could not be computed.
# the cosine similarity between ❤ and 💞 could not be computed.
# the cosine similarity between 💕 and ❤ could not be computed.
# the cosine similarity between 💞 and 💕 could not be computed.
# the cosine similarity between 💘 and 💕 could not be computed.
# the cosine similarity between 💕 and 😍 could not be computed.
# the cosine similarity between 💜 and 💙 could not be computed.
# the cosine similarity between 💗 and ❤ could not be computed.
# the cosine similarity between 💗 and 💕 could not be computed.
# the cosine similarity between ❤ and 💓 could not be computed.
# the cosine similarity between 🎤 and 🎶 could not be computed.
# the cosine similarity between 💖 and 💕 could not be computed.
# the cosine similarity between 💕 and 💓 could not be computed.
# the cosine similarity between ❤ and 💙 could not be computed.
# the cosine similarity between 💙 and 💚 could not be computed.
# the cosine similarity between ❤ and 💜 could not be computed.
# the cosine similarity between 💛 and 💚 could not be computed.
# the cosine similarity between ❤ and 💖 could not be computed.
# the cosine similarity between ❤ and 💚 could not be computed.
# the cosine similarity between 💛 and ❤ could not be computed.
# the cosine similarity between 💜 and 💚 could not be computed.
# the cosine similarity between 💛 and 💜 could not be computed.
# the cosine similarity between 💞 and 💖 could not be computed.
# the cosine similarity between 💗 and 💖 could not be computed.
# the cosine similarity between 🎧 and 🎶 could not be computed.
# the cosine similarity between 😍 and 💖 could not be computed.
# the cosine similarity between 🏌 and ⛳ could not be computed.
# the cosine similarity between 💕 and 💜 could not be computed.
# the cosine similarity between 🎼 and 🎶 could not be computed.
# the cosine similarity between ❤ and 😍 could not be computed.
# the cosine similarity between 😍 and 💞 could not be computed.
# the cosine similarity between 🎧 and 🎤 could not be computed.
# the cosine similarity between 💘 and ❤ could not be computed.
# the cosine similarity between 🎈 and 🎉 could not be computed.
# the cosine similarity between 😅 and 😂 could not be computed.
# the cosine similarity between 💙 and 💕 could not be computed.
# the cosine similarity between 😁 and 😂 could not be computed.
# the cosine similarity between 😭 and 😩 could not be computed.
# the cosine similarity between 💖 and 😘 could not be computed.
# the cosine similarity between 👍 and 👌 could not be computed.
# the cosine similarity between 😫 and 😭 could not be computed.
# the cosine similarity between 💙 and 💛 could not be computed.
# the cosine similarity between 😢 and 😭 could not be computed.
# the cosine similarity between 😘 and 💋 could not be computed.
# the cosine similarity between 💕 and 😘 could not be computed.
# the cosine similarity between 🎉 and 🎁 could not be computed.
# the cosine similarity between 💗 and 😍 could not be computed.
# the cosine similarity between 😍 and 💛 could not be computed.
# the cosine similarity between 💖 and 💙 could not be computed.
# the cosine similarity between 💘 and 😍 could not be computed.
# the cosine similarity between 🎁 and 🎂 could not be computed.
# the cosine similarity between 😘 and 💞 could not be computed.
# the cosine similarity between 😂 and 😆 could not be computed.
# the cosine similarity between 🎂 and 🎉 could not be computed.
# the cosine similarity between 🙄 and 🤔 could not be computed.
# the cosine similarity between 🎂 and 🎈 could not be computed.
# the cosine similarity between 💫 and ✨ could not be computed.
# the cosine similarity between ❤ and 😘 could not be computed.
# the cosine similarity between 😭 and 💔 could not be computed.
# the cosine similarity between 🎈 and 🎊 could not be computed.
# the cosine similarity between 💕 and 💋 could not be computed.
# the cosine similarity between 💜 and 😘 could not be computed.
# the cosine similarity between 💋 and ❤ could not be computed.
# the cosine similarity between 💜 and 😍 could not be computed.
# the cosine similarity between 😂 and 😄 could not be computed.
# the cosine similarity between ✅ and 👍 could not be computed.
# the cosine similarity between 💓 and 😍 could not be computed.
# the cosine similarity between 🎈 and 🎁 could not be computed.
# the cosine similarity between 😭 and 😔 could not be computed.
# the cosine similarity between 👉 and 👈 could not be computed.
# the cosine similarity between 👌 and 👏 could not be computed.
# the cosine similarity between 😘 and 💗 could not be computed.
# the cosine similarity between 👍 and 👏 could not be computed.
# the cosine similarity between 🙈 and 🙊 could not be computed.
# the cosine similarity between 💙 and 😘 could not be computed.
# the cosine similarity between 😂 and 😝 could not be computed.
# the cosine similarity between 😍 and 😊 could not be computed.
# the cosine similarity between 😉 and 😘 could not be computed.
# the cosine similarity between 😍 and 💙 could not be computed.
# the cosine similarity between ✔ and 👍 could not be computed.
# the cosine similarity between 🎶 and 📻 could not be computed.
# the cosine similarity between ➡ and ⬅ could not be computed.
# the cosine similarity between 💯 and 👌 could not be computed.
# the cosine similarity between 💋 and 😍 could not be computed.
# the cosine similarity between 😊 and 😁 could not be computed.
# the cosine similarity between 😘 and 💓 could not be computed.
# the cosine similarity between 🌊 and 🏄 could not be computed.
# the cosine similarity between ❤ and 😻 could not be computed.
# the cosine similarity between 💛 and 😘 could not be computed.
# the cosine similarity between 😘 and 😊 could not be computed.
# the cosine similarity between 😊 and 🙈 could not be computed.
# the cosine similarity between 🙌 and 🙏 could not be computed.
# the cosine similarity between 😌 and 😂 could not be computed.
# the cosine similarity between 😊 and 😄 could not be computed.
# the cosine similarity between 💋 and 💖 could not be computed.
# the cosine similarity between 😍 and 💚 could not be computed.
# the cosine similarity between 💕 and 😊 could not be computed.
# the cosine similarity between 👀 and 🤔 could not be computed.
# the cosine similarity between 💘 and 😘 could not be computed.
# the cosine similarity between 🙊 and 🙉 could not be computed.
# the cosine similarity between 🏆 and ⚽ could not be computed.
# the cosine similarity between 🔥 and 💥 could not be computed.
# the cosine similarity between 😜 and 😂 could not be computed.
# the cosine similarity between 🙄 and 😒 could not be computed.
# the cosine similarity between 😊 and 😉 could not be computed.
# the cosine similarity between 🙉 and 🙈 could not be computed.
# the cosine similarity between ☺ and 😘 could not be computed.
# the cosine similarity between 😊 and 😂 could not be computed.
# the cosine similarity between 😂 and 😛 could not be computed.
# the cosine similarity between ☺ and 💕 could not be computed.
# the cosine similarity between 👋 and 👊 could not be computed.
# the cosine similarity between 😍 and ☺ could not be computed.
# the cosine similarity between 👍 and 💯 could not be computed.
# the cosine similarity between 🙌 and 👏 could not be computed.
# the cosine similarity between 😉 and 😂 could not be computed.
# the cosine similarity between 🌹 and 🍃 could not be computed.
# the cosine similarity between 💖 and 😊 could not be computed.
# the cosine similarity between 😒 and 😩 could not be computed.
# the cosine similarity between ☺ and 😂 could not be computed.
# the cosine similarity between 🙌 and 🏆 could not be computed.
# the cosine similarity between 👈 and 👌 could not be computed.
# the cosine similarity between 🌹 and ❤ could not be computed.
# the cosine similarity between ☝ and 👇 could not be computed.
# the cosine similarity between 😂 and 😋 could not be computed.
# the cosine similarity between 🎉 and 👏 could not be computed.
# the cosine similarity between 👈 and 👍 could not be computed.
# the cosine similarity between 😎 and 😂 could not be computed.
# the cosine similarity between 😊 and 💙 could not be computed.
# the cosine similarity between 🙏 and 👍 could not be computed.
# the cosine similarity between 😳 and 😩 could not be computed.
# the cosine similarity between 🇬🇧 and 🇺🇸 could not be computed.
# the cosine similarity between 💖 and ✨ could not be computed.
# the cosine similarity between 😍 and 😌 could not be computed.
# the cosine similarity between ❤ and 😊 could not be computed.
# the cosine similarity between 👍 and 👉 could not be computed.
# the cosine similarity between 😍 and 🎉 could not be computed.
# the cosine similarity between 😁 and 😍 could not be computed.
# the cosine similarity between 😂 and 🙈 could not be computed.
# the cosine similarity between 🙌 and 🎉 could not be computed.
# the cosine similarity between 🎉 and 💖 could not be computed.
# the cosine similarity between 😍 and 😉 could not be computed.
# the cosine similarity between ❤ and 💔 could not be computed.
# the cosine similarity between 💗 and 😊 could not be computed.
# the cosine similarity between ⚠ and 🚩 could not be computed.
# the cosine similarity between 👍 and 😉 could not be computed.
# the cosine similarity between ✨ and 🎉 could not be computed.
# the cosine similarity between 🌹 and 😍 could not be computed.
# the cosine similarity between 😍 and 👌 could not be computed.
# the cosine similarity between 🎉 and 💕 could not be computed.
# the cosine similarity between 😜 and 😍 could not be computed.
# the cosine similarity between 😩 and 🙄 could not be computed.
# the cosine similarity between 👌 and 😘 could not be computed.
# the cosine similarity between 😊 and 😳 could not be computed.
# the cosine similarity between 🙄 and 😭 could not be computed.
# the cosine similarity between 🎉 and 😊 could not be computed.
# the cosine similarity between ☺ and ❤ could not be computed.
# the cosine similarity between 👌 and 👉 could not be computed.
# the cosine similarity between 💛 and 😊 could not be computed.
# the cosine similarity between 👉 and 👇 could not be computed.
# the cosine similarity between ❤ and 😁 could not be computed.
# the cosine similarity between 😋 and 😍 could not be computed.
# the cosine similarity between 😘 and 🎉 could not be computed.
# the cosine similarity between 🆓 and 💸 could not be computed.
# the cosine similarity between 💗 and 🎉 could not be computed.
# the cosine similarity between 😊 and 💜 could not be computed.
# the cosine similarity between 🤗 and 😂 could not be computed.
# the cosine similarity between 🙏 and 👉 could not be computed.
# the cosine similarity between 👍 and 😎 could not be computed.
# the cosine similarity between 😘 and 😁 could not be computed.
# the cosine similarity between 😂 and 👌 could not be computed.
# the cosine similarity between 😍 and 🙌 could not be computed.
# the cosine similarity between 😍 and 🙈 could not be computed.
# the cosine similarity between 😎 and 😍 could not be computed.
# the cosine similarity between 👌 and 😊 could not be computed.
# the cosine similarity between ❤ and 🎉 could not be computed.
# the cosine similarity between 😂 and 👏 could not be computed.
# the cosine similarity between 😍 and 👍 could not be computed.
# the cosine similarity between 🙃 and 😂 could not be computed.
# the cosine similarity between 🙌 and 💯 could not be computed.
# the cosine similarity between 🤔 and 😩 could not be computed.
# the cosine similarity between 🌸 and ❤ could not be computed.
# the cosine similarity between 😄 and 😍 could not be computed.
# the cosine similarity between 😍 and 🤗 could not be computed.
# the cosine similarity between 💍 and 😍 could not be computed.
# the cosine similarity between 💯 and 🔝 could not be computed.
# the cosine similarity between 😇 and 😂 could not be computed.
# the cosine similarity between 👍 and 😊 could not be computed.
# the cosine similarity between 💗 and ✨ could not be computed.
# the cosine similarity between 🤔 and 😭 could not be computed.
# the cosine similarity between 😈 and 😂 could not be computed.
# the cosine similarity between ✌ and 😊 could not be computed.
# the cosine similarity between 😭 and 💘 could not be computed.
# the cosine similarity between 🌃 and 📍 could not be computed.
# the cosine similarity between 😚 and 👏 could not be computed.
# the cosine similarity between ❤ and 🎈 could not be computed.
# the cosine similarity between 😂 and 🙌 could not be computed.
# the cosine similarity between ❤ and 💄 could not be computed.
# the cosine similarity between 😘 and 😄 could not be computed.
# the cosine similarity between 😂 and 😏 could not be computed.
# the cosine similarity between 🎉 and 👍 could not be computed.
# the cosine similarity between 🎉 and 💙 could not be computed.
# the cosine similarity between 🎉 and ☺ could not be computed.
# the cosine similarity between 💯 and 💰 could not be computed.
# the cosine similarity between 😂 and 👍 could not be computed.
# the cosine similarity between 😂 and 💖 could not be computed.
# the cosine similarity between 😍 and 👑 could not be computed.
# the cosine similarity between 💕 and ✨ could not be computed.
# the cosine similarity between 🌙 and 💖 could not be computed.
# the cosine similarity between 😉 and ❤ could not be computed.
# the cosine similarity between 🙏 and 💯 could not be computed.
# the cosine similarity between 💩 and 😂 could not be computed.
# the cosine similarity between 💕 and 🙈 could not be computed.
# the cosine similarity between 😍 and 😛 could not be computed.
# the cosine similarity between 😎 and 👌 could not be computed.
# the cosine similarity between ✨ and 😍 could not be computed.
# the cosine similarity between ✌ and 😂 could not be computed.
# the cosine similarity between 👋 and 😳 could not be computed.
# the cosine similarity between 😘 and 👍 could not be computed.
# the cosine similarity between 🙊 and 😂 could not be computed.
# the cosine similarity between ❤ and 🤗 could not be computed.
# the cosine similarity between 💃 and 🌃 could not be computed.
# the cosine similarity between 😩 and ❤ could not be computed.
# the cosine similarity between ✨ and 💄 could not be computed.
# the cosine similarity between 😂 and 🎉 could not be computed.
# the cosine similarity between 💯 and 😍 could not be computed.
# the cosine similarity between 👏 and 😘 could not be computed.
# the cosine similarity between 💙 and 👍 could not be computed.
# the cosine similarity between 🤘 and 💯 could not be computed.
# the cosine similarity between 🏅 and 🇺🇸 could not be computed.
# the cosine similarity between 😘 and 🎈 could not be computed.
# the cosine similarity between 😂 and 😫 could not be computed.
# the cosine similarity between 😂 and 💙 could not be computed.
# the cosine similarity between 😱 and 😂 could not be computed.
# the cosine similarity between 😄 and 💕 could not be computed.
# the cosine similarity between 😇 and 🙏 could not be computed.
# the cosine similarity between 😍 and 😂 could not be computed.
# the cosine similarity between 😂 and 😘 could not be computed.
# the cosine similarity between 🆓 and 💃 could not be computed.
# the cosine similarity between 🌸 and ✨ could not be computed.
# the cosine similarity between 🎥 and 👍 could not be computed.
# the cosine similarity between ❤ and 👑 could not be computed.
# the cosine similarity between 😍 and 👏 could not be computed.
# the cosine similarity between 🙈 and 😳 could not be computed.
# the cosine similarity between 😇 and ❤ could not be computed.
# the cosine similarity between 😉 and 💕 could not be computed.
# the cosine similarity between 😂 and 😭 could not be computed.
# the cosine similarity between ❤ and 🔥 could not be computed.
# the cosine similarity between 🤘 and 😂 could not be computed.
# the cosine similarity between 💕 and 👍 could not be computed.
# the cosine similarity between 📢 and ⚠ could not be computed.
# the cosine similarity between 📢 and 🚩 could not be computed.
# the cosine similarity between 👑 and 💕 could not be computed.
# the cosine similarity between 😂 and 💜 could not be computed.
# the cosine similarity between ✨ and 💞 could not be computed.
# the cosine similarity between ❤ and 🎶 could not be computed.
# the cosine similarity between 💕 and 🌸 could not be computed.
# the cosine similarity between 💯 and 👏 could not be computed.
# the cosine similarity between 👉 and ✔ could not be computed.
# the cosine similarity between ✨ and 💙 could not be computed.
# the cosine similarity between 🌟 and ❤ could not be computed.
# the cosine similarity between 😭 and 😅 could not be computed.
# the cosine similarity between 😘 and 🙈 could not be computed.
# the cosine similarity between 💚 and ✨ could not be computed.
# the cosine similarity between 🙄 and 😂 could not be computed.
# the cosine similarity between 😳 and 😂 could not be computed.
# the cosine similarity between 😂 and 😒 could not be computed.
# the cosine similarity between 😭 and 😘 could not be computed.
# the cosine similarity between 🙈 and ❤ could not be computed.
# the cosine similarity between 🙌 and ❤ could not be computed.
# the cosine similarity between 😱 and 😍 could not be computed.
# the cosine similarity between 👏 and 👉 could not be computed.
# the cosine similarity between 🙊 and 😍 could not be computed.
# the cosine similarity between 🙏 and 😊 could not be computed.
# the cosine similarity between 💯 and ‼ could not be computed.
# the cosine similarity between 😂 and 💗 could not be computed.
# the cosine similarity between 📍 and 🎯 could not be computed.
# the cosine similarity between 😎 and 💯 could not be computed.
# the cosine similarity between 👋 and 😘 could not be computed.
# the cosine similarity between ✨ and 👑 could not be computed.
# the cosine similarity between 😈 and 😍 could not be computed.
# the cosine similarity between 💯 and 😂 could not be computed.
# the cosine similarity between ❤ and 💯 could not be computed.
# the cosine similarity between 🇺🇸 and ❤ could not be computed.
# the cosine similarity between 😭 and 🙏 could not be computed.
# the cosine similarity between 😂 and 😓 could not be computed.
# the cosine similarity between ⚪ and 🔘 could not be computed.
# the cosine similarity between 😭 and 💗 could not be computed.
# the cosine similarity between 🌈 and 💕 could not be computed.
# the cosine similarity between 😂 and 😢 could not be computed.
# the cosine similarity between 💞 and 👍 could not be computed.
# the cosine similarity between 😍 and 🎶 could not be computed.
# the cosine similarity between ✨ and ❤ could not be computed.
# the cosine similarity between 🌃 and 💸 could not be computed.
# the cosine similarity between 👑 and 🦄 could not be computed.
# the cosine similarity between 😍 and 🙏 could not be computed.
# the cosine similarity between 💯 and 💪 could not be computed.
# the cosine similarity between 💦 and 👙 could not be computed.
# the cosine similarity between ✨ and 💜 could not be computed.
# the cosine similarity between 😏 and 😍 could not be computed.
# the cosine similarity between 🙏 and 😂 could not be computed.
# the cosine similarity between 👌 and ❤ could not be computed.
# the cosine similarity between 🌚 and 😂 could not be computed.
# the cosine similarity between 💛 and ✨ could not be computed.
# the cosine similarity between 😕 and 😂 could not be computed.
# the cosine similarity between 😭 and 💞 could not be computed.
# the cosine similarity between 😭 and 💀 could not be computed.
# the cosine similarity between 👅 and 💦 could not be computed.
# the cosine similarity between 😭 and 💙 could not be computed.
# the cosine similarity between 🌃 and 🕹 could not be computed.
# the cosine similarity between 👊 and 😳 could not be computed.
# the cosine similarity between 😢 and ❤ could not be computed.
# the cosine similarity between 😩 and 😂 could not be computed.
# the cosine similarity between ❤ and 👍 could not be computed.
# the cosine similarity between 🙏 and ❤ could not be computed.
# the cosine similarity between 💸 and 💃 could not be computed.
# the cosine similarity between 😈 and 🔥 could not be computed.
# the cosine similarity between 🔥 and 🙏 could not be computed.
# the cosine similarity between 😍 and 👅 could not be computed.
# the cosine similarity between 😘 and 🙏 could not be computed.
# the cosine similarity between 😂 and 😑 could not be computed.
# the cosine similarity between 😊 and ✨ could not be computed.
# the cosine similarity between 📷 and © could not be computed.
# the cosine similarity between 😍 and 🔥 could not be computed.
# the cosine similarity between 😂 and 💕 could not be computed.
# the cosine similarity between 👇 and 😳 could not be computed.
# the cosine similarity between 🆓 and 📍 could not be computed.
# the cosine similarity between 😂 and 💁 could not be computed.
# the cosine similarity between 😂 and 😐 could not be computed.
# the cosine similarity between ❤ and 😌 could not be computed.
# the cosine similarity between 😂 and 👋 could not be computed.
# the cosine similarity between 😩 and 💕 could not be computed.
# the cosine similarity between 🔥 and 💦 could not be computed.
# the cosine similarity between 👍 and ✨ could not be computed.
# the cosine similarity between 😭 and 💓 could not be computed.
# the cosine similarity between 💕 and 🙏 could not be computed.
# the cosine similarity between 😎 and ❤ could not be computed.
# the cosine similarity between ⛳ and 💚 could not be computed.
# the cosine similarity between 👉 and 🎥 could not be computed.
# the cosine similarity between 😂 and 🖕 could not be computed.
# the cosine similarity between 😭 and 😊 could not be computed.
# the cosine similarity between 😂 and 👊 could not be computed.
# the cosine similarity between 👏 and ❤ could not be computed.
# the cosine similarity between 🙌 and 👉 could not be computed.
# the cosine similarity between 💦 and 😂 could not be computed.
# the cosine similarity between 👋 and 👇 could not be computed.
# the cosine similarity between 💯 and 🔥 could not be computed.
# the cosine similarity between 😈 and 💦 could not be computed.
# the cosine similarity between 😂 and ❤ could not be computed.
# the cosine similarity between 😭 and 😍 could not be computed.
# the cosine similarity between 😭 and ❤ could not be computed.
# the cosine similarity between 💃 and 📍 could not be computed.
# the cosine similarity between ‼ and 🔥 could not be computed.
# the cosine similarity between 👉 and 😎 could not be computed.
# the cosine similarity between 😂 and 😴 could not be computed.
# the cosine similarity between 😏 and 🌃 could not be computed.
# the cosine similarity between 📍 and 📲 could not be computed.
# the cosine similarity between 🔥 and 💕 could not be computed.
# the cosine similarity between 👌 and 🔥 could not be computed.
# the cosine similarity between 💯 and 📢 could not be computed.
# the cosine similarity between 💕 and 🙌 could not be computed.
# the cosine similarity between 😘 and 😩 could not be computed.
# the cosine similarity between 💪 and ❤ could not be computed.
# the cosine similarity between ‼ and 😂 could not be computed.
# the cosine similarity between 📷 and 😍 could not be computed.
# the cosine similarity between 🙉 and 📢 could not be computed.
# the cosine similarity between 😩 and 😍 could not be computed.
# the cosine similarity between 😂 and 👀 could not be computed.
# the cosine similarity between 💕 and 😭 could not be computed.
# the cosine similarity between 💸 and 🚫 could not be computed.
# the cosine similarity between 🔥 and 👈 could not be computed.
# the cosine similarity between 🏌 and 💚 could not be computed.
# the cosine similarity between 🔥 and 👀 could not be computed.
# the cosine similarity between ✨ and 👉 could not be computed.
# the cosine similarity between © and 🐺 could not be computed.
# the cosine similarity between 💖 and 😭 could not be computed.
# the cosine similarity between 😎 and 🔥 could not be computed.
# the cosine similarity between 💯 and 😈 could not be computed.
# the cosine similarity between 🔥 and 😭 could not be computed.
# the cosine similarity between 😘 and 💯 could not be computed.
# the cosine similarity between ✨ and 😘 could not be computed.
# the cosine similarity between 🙊 and 📢 could not be computed.
# the cosine similarity between 😂 and 🤔 could not be computed.
# the cosine similarity between ☝ and 😳 could not be computed.
# the cosine similarity between 🌃 and 🆓 could not be computed.
# the cosine similarity between 🚫 and 🆓 could not be computed.
# the cosine similarity between 🌃 and 🚫 could not be computed.
# the cosine similarity between 📍 and 🚫 could not be computed.
# the cosine similarity between 👇 and 🎶 could not be computed.
# the cosine similarity between 💯 and 😩 could not be computed.
# the cosine similarity between 😏 and 🕹 could not be computed.
# the cosine similarity between 😍 and 👀 could not be computed.
# the cosine similarity between 📲 and 🎤 could not be computed.
# the cosine similarity between 💦 and 🍆 could not be computed.
# the cosine similarity between 🔥 and ✨ could not be computed.
# the cosine similarity between 💋 and ✨ could not be computed.
# the cosine similarity between 😭 and 🙌 could not be computed.
# the cosine similarity between 👉 and 😫 could not be computed.
# the cosine similarity between 🙊 and 🌴 could not be computed.
# the cosine similarity between 💯 and 🙉 could not be computed.
# the cosine similarity between 🏇 and ▶ could not be computed.
# the cosine similarity between 🙉 and 👣 could not be computed.
# the cosine similarity between 😂 and 💪 could not be computed.
# the cosine similarity between 👈 and 😎 could not be computed.
# the cosine similarity between 💙 and 🙏 could not be computed.
# the cosine similarity between 😂 and 💀 could not be computed.
# the cosine similarity between 😂 and ☝ could not be computed.
# the cosine similarity between 💸 and 📍 could not be computed.
# the cosine similarity between 👇 and 🎤 could not be computed.
# the cosine similarity between 💯 and 😏 could not be computed.
# the cosine similarity between 💯 and 😭 could not be computed.
# the cosine similarity between 🇺🇸 and 💥 could not be computed.
# the cosine similarity between 😈 and 👙 could not be computed.
# the cosine similarity between 👏 and ▶ could not be computed.
# the cosine similarity between 🙌 and 😘 could not be computed.
# the cosine similarity between 📍 and 🎥 could not be computed.
# the cosine similarity between 💖 and 🙏 could not be computed.
# the cosine similarity between 🙄 and ❤ could not be computed.
# the cosine similarity between 💦 and 😩 could not be computed.
# the cosine similarity between 😉 and ☠ could not be computed.
# the cosine similarity between 🔊 and 😂 could not be computed.
# the cosine similarity between 💕 and 👉 could not be computed.
# the cosine similarity between 🎤 and 🇳🇬 could not be computed.
# the cosine similarity between 😍 and 💦 could not be computed.
# the cosine similarity between ♻ and 👣 could not be computed.
# the cosine similarity between 👉 and 🎧 could not be computed.
# the cosine similarity between 🔥 and 👍 could not be computed.
# the cosine similarity between 👈 and 😍 could not be computed.
# the cosine similarity between ♻ and 💯 could not be computed.
# the cosine similarity between 💯 and 🤔 could not be computed.
# the cosine similarity between 🕹 and 💯 could not be computed.
# the cosine similarity between 👇 and 🎧 could not be computed.
# the cosine similarity between 👉 and 📱 could not be computed.
# the cosine similarity between 🙊 and 💯 could not be computed.
# the cosine similarity between 👀 and ❤ could not be computed.
# the cosine similarity between 🇳🇬 and 📲 could not be computed.
# the cosine similarity between 🙄 and 💯 could not be computed.
# the cosine similarity between 👣 and 🙊 could not be computed.
# the cosine similarity between 🤘 and 🔥 could not be computed.
# the cosine similarity between 😂 and 👉 could not be computed.
# the cosine similarity between 🚕 and 😉 could not be computed.
# the cosine similarity between 🚕 and ☠ could not be computed.
# the cosine similarity between 👇 and 😂 could not be computed.
# the cosine similarity between 👉 and 🔥 could not be computed.
# the cosine similarity between ❤ and 👉 could not be computed.
# the cosine similarity between 💃 and 🚫 could not be computed.
# the cosine similarity between 🔥 and 🎥 could not be computed.
# the cosine similarity between 👇 and 🇳🇬 could not be computed.
# the cosine similarity between 😪 and 🖖 could not be computed.
# the cosine similarity between 🙌 and 🔥 could not be computed.
# the cosine similarity between 🌆 and 👉 could not be computed.
# the cosine similarity between 💯 and 👀 could not be computed.
# the cosine similarity between 🎧 and 🇳🇬 could not be computed.
# the cosine similarity between 👉 and 💞 could not be computed.
# the cosine similarity between 💯 and 👣 could not be computed.
# the cosine similarity between 🌇 and 👉 could not be computed.
# the cosine similarity between 🎥 and ‼ could not be computed.
# the cosine similarity between 👇 and 😍 could not be computed.
# the cosine similarity between 💋 and 👉 could not be computed.
# the cosine similarity between 🎧 and 🔥 could not be computed.
# the cosine similarity between ❤ and 🔁 could not be computed.
# the cosine similarity between 💯 and 👉 could not be computed.
# the cosine similarity between 👉 and ❌ could not be computed.
# the cosine similarity between 👏 and ⏩ could not be computed.
# the cosine similarity between 💞 and 👈 could not be computed.
# the cosine similarity between ⏭ and 👏 could not be computed.
# the cosine similarity between 🎶 and 👉 could not be computed.
# the cosine similarity between 👀 and ✨ could not be computed.
# the cosine similarity between 💯 and ✊ could not be computed.
# the cosine similarity between 🎶 and 💯 could not be computed.
# the cosine similarity between 🙈 and 👣 could not be computed.
# the cosine similarity between 🎈 and 👉 could not be computed.
# the cosine similarity between 📢 and 🙈 could not be computed.
# the cosine similarity between 🎉 and 🔥 could not be computed.
# the cosine similarity between 💕 and 👈 could not be computed.
# the cosine similarity between 😍 and 👉 could not be computed.
# the cosine similarity between © and 😍 could not be computed.
# the cosine similarity between 😂 and 🔥 could not be computed.
# the cosine similarity between 🇳🇬 and 🎶 could not be computed.
# the cosine similarity between © and 💛 could not be computed.
# the cosine similarity between ➡ and 👏 could not be computed.
# the cosine similarity between 👇 and 🔥 could not be computed.
# the cosine similarity between © and 😊 could not be computed.
# the cosine similarity between 💯 and 🌃 could not be computed.
# the cosine similarity between 🌴 and 😍 could not be computed.
# the cosine similarity between 🎶 and 🔥 could not be computed.
# the cosine similarity between 🙈 and 💯 could not be computed.
# the cosine similarity between 🙌 and 😩 could not be computed.
# the cosine similarity between 💖 and 👉 could not be computed.
# the cosine similarity between 👇 and 📲 could not be computed.
# the cosine similarity between 💦 and 👉 could not be computed.
# the cosine similarity between 👈 and ❤ could not be computed.
# the cosine similarity between 👏 and ↪ could not be computed.
# the cosine similarity between 🔥 and 👏 could not be computed.
# the cosine similarity between ✨ and 🙏 could not be computed.
# the cosine similarity between © and 😘 could not be computed.
# the cosine similarity between 👍 and 👀 could not be computed.
# the cosine similarity between ♻ and 📢 could not be computed.
# the cosine similarity between 📢 and 👣 could not be computed.
# the cosine similarity between ‼ and 📍 could not be computed.
# the cosine similarity between 👈 and ✨ could not be computed.
# the cosine similarity between © and 💙 could not be computed.
# the cosine similarity between © and 😂 could not be computed.
# the cosine similarity between 🙈 and ♻ could not be computed.
# the cosine similarity between 🙉 and ♻ could not be computed.
# the cosine similarity between ♻ and 🙊 could not be computed.
# 1
# 1
# Der Spearman Rank Correlation Coefficient is SpearmanrResult(correlation=nan, pvalue=nan)
# /anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
goldstandard
# Out:
# [0.97716975]
