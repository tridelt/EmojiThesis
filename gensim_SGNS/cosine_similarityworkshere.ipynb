# %%
from __future__ import absolute_import, division, print_function

# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from numpy  import array
from scipy import stats

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
corpus_filename = '../data/extracted_emoji_sequences.txt'

# %%
corpus = open(corpus_filename).read().splitlines()

# %%
def tokenize_corpus(corpus):
    tokens = [x.split() for x in corpus]
    return tokens

# %%
def onlyEmojiSequences(tokens):
    threshold_emojis = [x for x in tokens if len(x) > 1]
    return threshold_emojis

# %%
tokenized_corpus = tokenize_corpus(corpus)
emojiSequences = onlyEmojiSequences(tokenized_corpus)

# %%
token_count = sum([len(sentence) for sentence in emojiSequences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 610,256 tokens

# %% [markdown]
# # training the model

# %%
# Dimensionality of the resulting word vectors.
num_features = 300

# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 8

# Downsample setting for frequent words.
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
seed = 1

# think of how to set those variables so that variables from different tweets are not learned from together!

# %%
thrones2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(emojiSequences)
# Out:
# 2019-01-31 17:54:26,827 : INFO : collecting all words and their counts
# 2019-01-31 17:54:26,828 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-01-31 17:54:26,835 : INFO : PROGRESS: at sentence #10000, processed 26070 words, keeping 818 word types
# 2019-01-31 17:54:26,843 : INFO : PROGRESS: at sentence #20000, processed 52738 words, keeping 935 word types
# 2019-01-31 17:54:26,852 : INFO : PROGRESS: at sentence #30000, processed 80617 words, keeping 993 word types
# 2019-01-31 17:54:26,859 : INFO : PROGRESS: at sentence #40000, processed 106997 words, keeping 1019 word types
# 2019-01-31 17:54:26,867 : INFO : PROGRESS: at sentence #50000, processed 134684 words, keeping 1038 word types
# 2019-01-31 17:54:26,874 : INFO : PROGRESS: at sentence #60000, processed 161638 words, keeping 1053 word types
# 2019-01-31 17:54:26,881 : INFO : PROGRESS: at sentence #70000, processed 189166 words, keeping 1065 word types
# 2019-01-31 17:54:26,888 : INFO : PROGRESS: at sentence #80000, processed 216247 words, keeping 1071 word types
# 2019-01-31 17:54:26,894 : INFO : PROGRESS: at sentence #90000, processed 242719 words, keeping 1086 word types
# 2019-01-31 17:54:26,902 : INFO : PROGRESS: at sentence #100000, processed 270352 words, keeping 1090 word types
# 2019-01-31 17:54:26,909 : INFO : PROGRESS: at sentence #110000, processed 297903 words, keeping 1114 word types
# 2019-01-31 17:54:26,915 : INFO : PROGRESS: at sentence #120000, processed 325655 words, keeping 1120 word types
# 2019-01-31 17:54:26,922 : INFO : PROGRESS: at sentence #130000, processed 353170 words, keeping 1130 word types
# 2019-01-31 17:54:26,928 : INFO : PROGRESS: at sentence #140000, processed 380910 words, keeping 1139 word types
# 2019-01-31 17:54:26,935 : INFO : PROGRESS: at sentence #150000, processed 408180 words, keeping 1142 word types
# 2019-01-31 17:54:26,942 : INFO : PROGRESS: at sentence #160000, processed 435571 words, keeping 1148 word types
# 2019-01-31 17:54:26,948 : INFO : PROGRESS: at sentence #170000, processed 463321 words, keeping 1150 word types
# 2019-01-31 17:54:26,954 : INFO : PROGRESS: at sentence #180000, processed 490214 words, keeping 1152 word types
# 2019-01-31 17:54:26,961 : INFO : PROGRESS: at sentence #190000, processed 516726 words, keeping 1156 word types
# 2019-01-31 17:54:26,966 : INFO : PROGRESS: at sentence #200000, processed 542786 words, keeping 1157 word types
# 2019-01-31 17:54:26,972 : INFO : PROGRESS: at sentence #210000, processed 568495 words, keeping 1158 word types
# 2019-01-31 17:54:26,979 : INFO : PROGRESS: at sentence #220000, processed 596239 words, keeping 1158 word types
# 2019-01-31 17:54:26,982 : INFO : collected 1158 word types from a corpus of 610256 raw words and 225292 sentences
# 2019-01-31 17:54:26,983 : INFO : Loading a fresh vocabulary
# 2019-01-31 17:54:26,988 : INFO : min_count=3 retains 1082 unique words (93% of original 1158, drops 76)
# 2019-01-31 17:54:26,989 : INFO : min_count=3 leaves 610147 word corpus (99% of original 610256, drops 109)
# 2019-01-31 17:54:26,992 : INFO : deleting the raw counts dictionary of 1158 items
# 2019-01-31 17:54:26,992 : INFO : sample=0.001 downsamples 83 most-common words
# 2019-01-31 17:54:26,993 : INFO : downsampling leaves estimated 388892 word corpus (63.7% of prior 610147)
# 2019-01-31 17:54:26,995 : INFO : estimated required memory for 1082 words and 300 dimensions: 3137800 bytes
# 2019-01-31 17:54:26,995 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 1082

# %%
thrones2vec.wv.vocab
# Out:
# {'⚠': <gensim.models.keyedvectors.Vocab at 0x1a22aee2b0>,
#  '😀': <gensim.models.keyedvectors.Vocab at 0x1a2c128710>,
#  '🎷': <gensim.models.keyedvectors.Vocab at 0x1a2c128a90>,
#  '🙌': <gensim.models.keyedvectors.Vocab at 0x1a2c128898>,
#  '💐': <gensim.models.keyedvectors.Vocab at 0x1a2c128ba8>,
#  '🌈': <gensim.models.keyedvectors.Vocab at 0x1a2c128be0>,
#  '🍸': <gensim.models.keyedvectors.Vocab at 0x1a2c128c18>,
#  '🎶': <gensim.models.keyedvectors.Vocab at 0x1a2c128c88>,
#  '💜': <gensim.models.keyedvectors.Vocab at 0x1a2c128cc0>,
#  '🌼': <gensim.models.keyedvectors.Vocab at 0x1a2c128c50>,
#  '💛': <gensim.models.keyedvectors.Vocab at 0x1a2c128cf8>,
#  '❤': <gensim.models.keyedvectors.Vocab at 0x1a2c128d30>,
#  '☮': <gensim.models.keyedvectors.Vocab at 0x1a2c128d68>,
#  '✨': <gensim.models.keyedvectors.Vocab at 0x1a2c128da0>,
#  '🏕': <gensim.models.keyedvectors.Vocab at 0x1a2c128dd8>,
#  '💖': <gensim.models.keyedvectors.Vocab at 0x1a2c128e10>,
#  '🌤': <gensim.models.keyedvectors.Vocab at 0x1a2c128e48>,
#  '🌸': <gensim.models.keyedvectors.Vocab at 0x1a2c128e80>,
#  '🌷': <gensim.models.keyedvectors.Vocab at 0x1a2c128eb8>,
#  '\u200d': <gensim.models.keyedvectors.Vocab at 0x1a2c128ef0>,
#  '🏔': <gensim.models.keyedvectors.Vocab at 0x1a2c128f28>,
#  '️': <gensim.models.keyedvectors.Vocab at 0x1a2c128f60>,
#  '🍀': <gensim.models.keyedvectors.Vocab at 0x1a2c128f98>,
#  '🌎': <gensim.models.keyedvectors.Vocab at 0x1a2c128fd0>,
#  '🥀': <gensim.models.keyedvectors.Vocab at 0x1a2c136048>,
#  '🌱': <gensim.models.keyedvectors.Vocab at 0x1a2c136080>,
#  '🌳': <gensim.models.keyedvectors.Vocab at 0x1a2c1360b8>,
#  '🚴': <gensim.models.keyedvectors.Vocab at 0x1a2c1360f0>,
#  '🌻': <gensim.models.keyedvectors.Vocab at 0x1a2c136128>,
#  '♀': <gensim.models.keyedvectors.Vocab at 0x1a2c136160>,
#  '🇦': <gensim.models.keyedvectors.Vocab at 0x1a2c136198>,
#  '🇿': <gensim.models.keyedvectors.Vocab at 0x1a2c1361d0>,
#  '🇸': <gensim.models.keyedvectors.Vocab at 0x1a2c136208>,
#  '🇺': <gensim.models.keyedvectors.Vocab at 0x1a2c136240>,
#  '🇩': <gensim.models.keyedvectors.Vocab at 0x1a2c136278>,
#  '🇪': <gensim.models.keyedvectors.Vocab at 0x1a2c1362b0>,
#  '🇮': <gensim.models.keyedvectors.Vocab at 0x1a2c1362e8>,
#  '🇧': <gensim.models.keyedvectors.Vocab at 0x1a2c136320>,
#  '😭': <gensim.models.keyedvectors.Vocab at 0x1a2c136358>,
#  '🤦': <gensim.models.keyedvectors.Vocab at 0x1a2c136390>,
#  '♂': <gensim.models.keyedvectors.Vocab at 0x1a2c1363c8>,
#  '👉': <gensim.models.keyedvectors.Vocab at 0x1a2c136400>,
#  '🚖': <gensim.models.keyedvectors.Vocab at 0x1a2c136438>,
#  '🏾': <gensim.models.keyedvectors.Vocab at 0x1a2c136470>,
#  '🎈': <gensim.models.keyedvectors.Vocab at 0x1a2c1364a8>,
#  '💃': <gensim.models.keyedvectors.Vocab at 0x1a2c1364e0>,
#  '💞': <gensim.models.keyedvectors.Vocab at 0x1a2c136518>,
#  '😳': <gensim.models.keyedvectors.Vocab at 0x1a2c136550>,
#  '😉': <gensim.models.keyedvectors.Vocab at 0x1a2c136588>,
#  '⚽': <gensim.models.keyedvectors.Vocab at 0x1a2c1365c0>,
#  '🍬': <gensim.models.keyedvectors.Vocab at 0x1a2c1365f8>,
#  '🍭': <gensim.models.keyedvectors.Vocab at 0x1a2c136630>,
#  '💕': <gensim.models.keyedvectors.Vocab at 0x1a2c136668>,
#  '🔋': <gensim.models.keyedvectors.Vocab at 0x1a2c1366a0>,
#  '🙊': <gensim.models.keyedvectors.Vocab at 0x1a2c1366d8>,
#  '👍': <gensim.models.keyedvectors.Vocab at 0x1a2c136710>,
#  '🍳': <gensim.models.keyedvectors.Vocab at 0x1a2c136748>,
#  '🥚': <gensim.models.keyedvectors.Vocab at 0x1a2c136780>,
#  '😞': <gensim.models.keyedvectors.Vocab at 0x1a2c1367b8>,
#  '😢': <gensim.models.keyedvectors.Vocab at 0x1a2c1367f0>,
#  '😘': <gensim.models.keyedvectors.Vocab at 0x1a2c136828>,
#  '😍': <gensim.models.keyedvectors.Vocab at 0x1a2c136860>,
#  '🤧': <gensim.models.keyedvectors.Vocab at 0x1a2c136898>,
#  '🤗': <gensim.models.keyedvectors.Vocab at 0x1a2c1368d0>,
#  '🎉': <gensim.models.keyedvectors.Vocab at 0x1a2c136908>,
#  '🍾': <gensim.models.keyedvectors.Vocab at 0x1a2c136940>,
#  '🍷': <gensim.models.keyedvectors.Vocab at 0x1a2c136978>,
#  '🎊': <gensim.models.keyedvectors.Vocab at 0x1a2c1369b0>,
#  '📱': <gensim.models.keyedvectors.Vocab at 0x1a2c1369e8>,
#  '💋': <gensim.models.keyedvectors.Vocab at 0x1a2c136a20>,
#  '😊': <gensim.models.keyedvectors.Vocab at 0x1a2c136a58>,
#  '⃣': <gensim.models.keyedvectors.Vocab at 0x1a2c136a90>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x1a2c136ac8>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x1a2c136b00>,
#  '🎵': <gensim.models.keyedvectors.Vocab at 0x1a2c136b38>,
#  '💌': <gensim.models.keyedvectors.Vocab at 0x1a2c136b70>,
#  '👟': <gensim.models.keyedvectors.Vocab at 0x1a2c136ba8>,
#  '🎁': <gensim.models.keyedvectors.Vocab at 0x1a2c136be0>,
#  '🔥': <gensim.models.keyedvectors.Vocab at 0x1a2c136c18>,
#  '🐶': <gensim.models.keyedvectors.Vocab at 0x1a2c136c50>,
#  '🎹': <gensim.models.keyedvectors.Vocab at 0x1a2c136c88>,
#  '😂': <gensim.models.keyedvectors.Vocab at 0x1a2c136cc0>,
#  '🍑': <gensim.models.keyedvectors.Vocab at 0x1a2c136cf8>,
#  '😋': <gensim.models.keyedvectors.Vocab at 0x1a2c136d30>,
#  '🙏': <gensim.models.keyedvectors.Vocab at 0x1a2c136d68>,
#  '💿': <gensim.models.keyedvectors.Vocab at 0x1a2c136da0>,
#  '💘': <gensim.models.keyedvectors.Vocab at 0x1a2c136dd8>,
#  '🌧': <gensim.models.keyedvectors.Vocab at 0x1a2c136e10>,
#  '💙': <gensim.models.keyedvectors.Vocab at 0x1a2c136e48>,
#  '😃': <gensim.models.keyedvectors.Vocab at 0x1a2c136e80>,
#  '🏽': <gensim.models.keyedvectors.Vocab at 0x1a2c136eb8>,
#  '🕵': <gensim.models.keyedvectors.Vocab at 0x1a2c136ef0>,
#  '‼': <gensim.models.keyedvectors.Vocab at 0x1a2c136f28>,
#  '📌': <gensim.models.keyedvectors.Vocab at 0x1a2c136f60>,
#  '❕': <gensim.models.keyedvectors.Vocab at 0x1a2c136f98>,
#  '🙆': <gensim.models.keyedvectors.Vocab at 0x1a2c136fd0>,
#  '😌': <gensim.models.keyedvectors.Vocab at 0x1a2c138048>,
#  '🎤': <gensim.models.keyedvectors.Vocab at 0x1a2c138080>,
#  '😆': <gensim.models.keyedvectors.Vocab at 0x1a2c1380b8>,
#  '😅': <gensim.models.keyedvectors.Vocab at 0x1a2c1380f0>,
#  '🙄': <gensim.models.keyedvectors.Vocab at 0x1a2c138128>,
#  '📹': <gensim.models.keyedvectors.Vocab at 0x1a2c138160>,
#  '🍽': <gensim.models.keyedvectors.Vocab at 0x1a2c138198>,
#  '🏌': <gensim.models.keyedvectors.Vocab at 0x1a2c1381d0>,
#  '⛳': <gensim.models.keyedvectors.Vocab at 0x1a2c138208>,
#  '👌': <gensim.models.keyedvectors.Vocab at 0x1a2c138240>,
#  '💪': <gensim.models.keyedvectors.Vocab at 0x1a2c138278>,
#  '🏆': <gensim.models.keyedvectors.Vocab at 0x1a2c1382b0>,
#  '🏻': <gensim.models.keyedvectors.Vocab at 0x1a2c1382e8>,
#  '♥': <gensim.models.keyedvectors.Vocab at 0x1a2c138320>,
#  '🤟': <gensim.models.keyedvectors.Vocab at 0x1a2c138358>,
#  '😈': <gensim.models.keyedvectors.Vocab at 0x1a2c138390>,
#  '🏼': <gensim.models.keyedvectors.Vocab at 0x1a2c1383c8>,
#  '⭐': <gensim.models.keyedvectors.Vocab at 0x1a2c138400>,
#  '🇷': <gensim.models.keyedvectors.Vocab at 0x1a2c138438>,
#  '🌺': <gensim.models.keyedvectors.Vocab at 0x1a2c138470>,
#  '🐾': <gensim.models.keyedvectors.Vocab at 0x1a2c1384a8>,
#  '🐠': <gensim.models.keyedvectors.Vocab at 0x1a2c1384e0>,
#  '🐇': <gensim.models.keyedvectors.Vocab at 0x1a2c138518>,
#  '👑': <gensim.models.keyedvectors.Vocab at 0x1a2c138550>,
#  '🐣': <gensim.models.keyedvectors.Vocab at 0x1a2c138588>,
#  '🐧': <gensim.models.keyedvectors.Vocab at 0x1a2c1385c0>,
#  '👣': <gensim.models.keyedvectors.Vocab at 0x1a2c1385f8>,
#  '🔞': <gensim.models.keyedvectors.Vocab at 0x1a2c138630>,
#  '📽': <gensim.models.keyedvectors.Vocab at 0x1a2c138668>,
#  '🤷': <gensim.models.keyedvectors.Vocab at 0x1a2c1386a0>,
#  '🏃': <gensim.models.keyedvectors.Vocab at 0x1a2c1386d8>,
#  '💨': <gensim.models.keyedvectors.Vocab at 0x1a2c138710>,
#  '🍰': <gensim.models.keyedvectors.Vocab at 0x1a2c138748>,
#  '💰': <gensim.models.keyedvectors.Vocab at 0x1a2c138780>,
#  '👋': <gensim.models.keyedvectors.Vocab at 0x1a2c1387b8>,
#  '😫': <gensim.models.keyedvectors.Vocab at 0x1a2c1387f0>,
#  '🎥': <gensim.models.keyedvectors.Vocab at 0x1a2c138828>,
#  '🙈': <gensim.models.keyedvectors.Vocab at 0x1a2c138860>,
#  '👏': <gensim.models.keyedvectors.Vocab at 0x1a2c138898>,
#  '🌊': <gensim.models.keyedvectors.Vocab at 0x1a2c1388d0>,
#  '🤴': <gensim.models.keyedvectors.Vocab at 0x1a2c138908>,
#  '👸': <gensim.models.keyedvectors.Vocab at 0x1a2c138940>,
#  '👀': <gensim.models.keyedvectors.Vocab at 0x1a2c138978>,
#  '😏': <gensim.models.keyedvectors.Vocab at 0x1a2c1389b0>,
#  '😩': <gensim.models.keyedvectors.Vocab at 0x1a2c1389e8>,
#  '📐': <gensim.models.keyedvectors.Vocab at 0x1a2c138a20>,
#  '🕶': <gensim.models.keyedvectors.Vocab at 0x1a2c138a58>,
#  '☀': <gensim.models.keyedvectors.Vocab at 0x1a2c138a90>,
#  '😲': <gensim.models.keyedvectors.Vocab at 0x1a2c138ac8>,
#  '🌍': <gensim.models.keyedvectors.Vocab at 0x1a2c138b00>,
#  '🇯': <gensim.models.keyedvectors.Vocab at 0x1a2c138b38>,
#  '🇵': <gensim.models.keyedvectors.Vocab at 0x1a2c138b70>,
#  '💀': <gensim.models.keyedvectors.Vocab at 0x1a2c138ba8>,
#  '🤭': <gensim.models.keyedvectors.Vocab at 0x1a2c138be0>,
#  '😎': <gensim.models.keyedvectors.Vocab at 0x1a2c138c18>,
#  '🇲': <gensim.models.keyedvectors.Vocab at 0x1a2c138c50>,
#  '💥': <gensim.models.keyedvectors.Vocab at 0x1a2c138c88>,
#  '✅': <gensim.models.keyedvectors.Vocab at 0x1a2c138cc0>,
#  '📢': <gensim.models.keyedvectors.Vocab at 0x1a2c138cf8>,
#  '🚗': <gensim.models.keyedvectors.Vocab at 0x1a2c138d30>,
#  '🔑': <gensim.models.keyedvectors.Vocab at 0x1a2c138d68>,
#  '🇨': <gensim.models.keyedvectors.Vocab at 0x1a2c138da0>,
#  '🤞': <gensim.models.keyedvectors.Vocab at 0x1a2c138dd8>,
#  '📲': <gensim.models.keyedvectors.Vocab at 0x1a2c138e10>,
#  '🆘': <gensim.models.keyedvectors.Vocab at 0x1a2c138e48>,
#  '🏁': <gensim.models.keyedvectors.Vocab at 0x1a2c138e80>,
#  '🚩': <gensim.models.keyedvectors.Vocab at 0x1a2c138eb8>,
#  '🍃': <gensim.models.keyedvectors.Vocab at 0x1a2c138ef0>,
#  '🤣': <gensim.models.keyedvectors.Vocab at 0x1a2c138f28>,
#  '📷': <gensim.models.keyedvectors.Vocab at 0x1a2c138f60>,
#  '🌴': <gensim.models.keyedvectors.Vocab at 0x1a2c138f98>,
#  '🤘': <gensim.models.keyedvectors.Vocab at 0x1a2c138fd0>,
#  '🙃': <gensim.models.keyedvectors.Vocab at 0x1a2c13b048>,
#  '👯': <gensim.models.keyedvectors.Vocab at 0x1a2c13b080>,
#  '🕺': <gensim.models.keyedvectors.Vocab at 0x1a2c13b0b8>,
#  '💚': <gensim.models.keyedvectors.Vocab at 0x1a2c13b0f0>,
#  '😱': <gensim.models.keyedvectors.Vocab at 0x1a2c13b128>,
#  '⚡': <gensim.models.keyedvectors.Vocab at 0x1a2c13b160>,
#  '📉': <gensim.models.keyedvectors.Vocab at 0x1a2c13b198>,
#  '👠': <gensim.models.keyedvectors.Vocab at 0x1a2c13b1d0>,
#  '🎓': <gensim.models.keyedvectors.Vocab at 0x1a2c13b208>,
#  '🐪': <gensim.models.keyedvectors.Vocab at 0x1a2c13b240>,
#  '💔': <gensim.models.keyedvectors.Vocab at 0x1a2c13b278>,
#  '🏀': <gensim.models.keyedvectors.Vocab at 0x1a2c13b2b0>,
#  '👥': <gensim.models.keyedvectors.Vocab at 0x1a2c13b2e8>,
#  '👇': <gensim.models.keyedvectors.Vocab at 0x1a2c13b320>,
#  '😒': <gensim.models.keyedvectors.Vocab at 0x1a2c13b358>,
#  '🤔': <gensim.models.keyedvectors.Vocab at 0x1a2c13b390>,
#  '🤯': <gensim.models.keyedvectors.Vocab at 0x1a2c13b3c8>,
#  '📖': <gensim.models.keyedvectors.Vocab at 0x1a2c13b400>,
#  '👂': <gensim.models.keyedvectors.Vocab at 0x1a2c13b438>,
#  '🧠': <gensim.models.keyedvectors.Vocab at 0x1a2c13b470>,
#  '📚': <gensim.models.keyedvectors.Vocab at 0x1a2c13b4a8>,
#  '🎙': <gensim.models.keyedvectors.Vocab at 0x1a2c13b4e0>,
#  '💦': <gensim.models.keyedvectors.Vocab at 0x1a2c13b518>,
#  '💯': <gensim.models.keyedvectors.Vocab at 0x1a2c13b550>,
#  '💫': <gensim.models.keyedvectors.Vocab at 0x1a2c13b588>,
#  '🎂': <gensim.models.keyedvectors.Vocab at 0x1a2c13b5c0>,
#  '👊': <gensim.models.keyedvectors.Vocab at 0x1a2c13b5f8>,
#  '😁': <gensim.models.keyedvectors.Vocab at 0x1a2c13b630>,
#  '🐎': <gensim.models.keyedvectors.Vocab at 0x1a2c13b668>,
#  '😻': <gensim.models.keyedvectors.Vocab at 0x1a2c13b6a0>,
#  '🍉': <gensim.models.keyedvectors.Vocab at 0x1a2c13b6d8>,
#  '😽': <gensim.models.keyedvectors.Vocab at 0x1a2c13b710>,
#  '☺': <gensim.models.keyedvectors.Vocab at 0x1a2c13b748>,
#  '😸': <gensim.models.keyedvectors.Vocab at 0x1a2c13b780>,
#  '🍫': <gensim.models.keyedvectors.Vocab at 0x1a2c13b7b8>,
#  '😔': <gensim.models.keyedvectors.Vocab at 0x1a2c13b7f0>,
#  '🔊': <gensim.models.keyedvectors.Vocab at 0x1a2c13b828>,
#  '🇱': <gensim.models.keyedvectors.Vocab at 0x1a2c13b860>,
#  '🌟': <gensim.models.keyedvectors.Vocab at 0x1a2c13b898>,
#  '🛴': <gensim.models.keyedvectors.Vocab at 0x1a2c13b8d0>,
#  '💟': <gensim.models.keyedvectors.Vocab at 0x1a2c13b908>,
#  '🦋': <gensim.models.keyedvectors.Vocab at 0x1a2c13b940>,
#  '🖤': <gensim.models.keyedvectors.Vocab at 0x1a2c13b978>,
#  '🏳': <gensim.models.keyedvectors.Vocab at 0x1a2c13b9b0>,
#  '🤡': <gensim.models.keyedvectors.Vocab at 0x1a2c13b9e8>,
#  '😬': <gensim.models.keyedvectors.Vocab at 0x1a2c13ba20>,
#  '😠': <gensim.models.keyedvectors.Vocab at 0x1a2c13ba58>,
#  '✋': <gensim.models.keyedvectors.Vocab at 0x1a2c13ba90>,
#  '🏿': <gensim.models.keyedvectors.Vocab at 0x1a2c13bac8>,
#  '🧡': <gensim.models.keyedvectors.Vocab at 0x1a2c13bb00>,
#  '🙋': <gensim.models.keyedvectors.Vocab at 0x1a2c13bb38>,
#  '🌹': <gensim.models.keyedvectors.Vocab at 0x1a2c13bb70>,
#  '💗': <gensim.models.keyedvectors.Vocab at 0x1a2c13bba8>,
#  '😚': <gensim.models.keyedvectors.Vocab at 0x1a2c13bbe0>,
#  '🌂': <gensim.models.keyedvectors.Vocab at 0x1a2c13bc18>,
#  '😕': <gensim.models.keyedvectors.Vocab at 0x1a2c13bc50>,
#  '🌅': <gensim.models.keyedvectors.Vocab at 0x1a2c13bc88>,
#  '🛎': <gensim.models.keyedvectors.Vocab at 0x1a2c13bcc0>,
#  '🏐': <gensim.models.keyedvectors.Vocab at 0x1a2c13bcf8>,
#  '👈': <gensim.models.keyedvectors.Vocab at 0x1a2c13bd30>,
#  '😤': <gensim.models.keyedvectors.Vocab at 0x1a2c13bd68>,
#  '👨': <gensim.models.keyedvectors.Vocab at 0x1a2c13bda0>,
#  '🦍': <gensim.models.keyedvectors.Vocab at 0x1a2c13bdd8>,
#  '🌦': <gensim.models.keyedvectors.Vocab at 0x1a2c13be10>,
#  '🌿': <gensim.models.keyedvectors.Vocab at 0x1a2c13be48>,
#  '😮': <gensim.models.keyedvectors.Vocab at 0x1a2c13be80>,
#  '🍌': <gensim.models.keyedvectors.Vocab at 0x1a2c13beb8>,
#  '🍞': <gensim.models.keyedvectors.Vocab at 0x1a2c13bef0>,
#  '🍆': <gensim.models.keyedvectors.Vocab at 0x1a2c13bf28>,
#  '💅': <gensim.models.keyedvectors.Vocab at 0x1a2c13bf60>,
#  '😜': <gensim.models.keyedvectors.Vocab at 0x1a2c13bf98>,
#  '🌌': <gensim.models.keyedvectors.Vocab at 0x1a2c13bfd0>,
#  '🐈': <gensim.models.keyedvectors.Vocab at 0x1a2c13f048>,
#  '🐱': <gensim.models.keyedvectors.Vocab at 0x1a2c13f080>,
#  '➡': <gensim.models.keyedvectors.Vocab at 0x1a2c13f0b8>,
#  '🇳': <gensim.models.keyedvectors.Vocab at 0x1a2c13f0f0>,
#  '🌆': <gensim.models.keyedvectors.Vocab at 0x1a2c13f128>,
#  '🌞': <gensim.models.keyedvectors.Vocab at 0x1a2c13f160>,
#  '🤤': <gensim.models.keyedvectors.Vocab at 0x1a2c13f198>,
#  '✊': <gensim.models.keyedvectors.Vocab at 0x1a2c13f1d0>,
#  '💎': <gensim.models.keyedvectors.Vocab at 0x1a2c13f208>,
#  '💷': <gensim.models.keyedvectors.Vocab at 0x1a2c13f240>,
#  '👫': <gensim.models.keyedvectors.Vocab at 0x1a2c13f278>,
#  '💓': <gensim.models.keyedvectors.Vocab at 0x1a2c13f2b0>,
#  '🐻': <gensim.models.keyedvectors.Vocab at 0x1a2c13f2e8>,
#  '🏩': <gensim.models.keyedvectors.Vocab at 0x1a2c13f320>,
#  '👗': <gensim.models.keyedvectors.Vocab at 0x1a2c13f358>,
#  '📗': <gensim.models.keyedvectors.Vocab at 0x1a2c13f390>,
#  '🌚': <gensim.models.keyedvectors.Vocab at 0x1a2c13f3c8>,
#  '🕛': <gensim.models.keyedvectors.Vocab at 0x1a2c13f400>,
#  '🍋': <gensim.models.keyedvectors.Vocab at 0x1a2c13f438>,
#  '🔅': <gensim.models.keyedvectors.Vocab at 0x1a2c13f470>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x1a2c13f4a8>,
#  '🤠': <gensim.models.keyedvectors.Vocab at 0x1a2c13f4e0>,
#  '🤜': <gensim.models.keyedvectors.Vocab at 0x1a2c13f518>,
#  '🤢': <gensim.models.keyedvectors.Vocab at 0x1a2c13f550>,
#  '🇬': <gensim.models.keyedvectors.Vocab at 0x1a2c13f588>,
#  '🇭': <gensim.models.keyedvectors.Vocab at 0x1a2c13f5c0>,
#  '💝': <gensim.models.keyedvectors.Vocab at 0x1a2c13f5f8>,
#  '❣': <gensim.models.keyedvectors.Vocab at 0x1a2c13f630>,
#  '🛍': <gensim.models.keyedvectors.Vocab at 0x1a2c13f668>,
#  '🐴': <gensim.models.keyedvectors.Vocab at 0x1a2c13f6a0>,
#  '✔': <gensim.models.keyedvectors.Vocab at 0x1a2c13f6d8>,
#  '❗': <gensim.models.keyedvectors.Vocab at 0x1a2c13f710>,
#  '📡': <gensim.models.keyedvectors.Vocab at 0x1a2c13f748>,
#  '🎇': <gensim.models.keyedvectors.Vocab at 0x1a2c13f780>,
#  '😣': <gensim.models.keyedvectors.Vocab at 0x1a2c13f7b8>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x1a2c13f7f0>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x1a2c13f828>,
#  '🔴': <gensim.models.keyedvectors.Vocab at 0x1a2c13f860>,
#  '⚪': <gensim.models.keyedvectors.Vocab at 0x1a2c13f898>,
#  '🎼': <gensim.models.keyedvectors.Vocab at 0x1a2c13f8d0>,
#  '😑': <gensim.models.keyedvectors.Vocab at 0x1a2c13f908>,
#  '🚶': <gensim.models.keyedvectors.Vocab at 0x1a2c13f940>,
#  '🚪': <gensim.models.keyedvectors.Vocab at 0x1a2c13f978>,
#  '💣': <gensim.models.keyedvectors.Vocab at 0x1a2c13f9b0>,
#  '🚨': <gensim.models.keyedvectors.Vocab at 0x1a2c13f9e8>,
#  '🍪': <gensim.models.keyedvectors.Vocab at 0x1a2c13fa20>,
#  '📻': <gensim.models.keyedvectors.Vocab at 0x1a2c13fa58>,
#  '🐥': <gensim.models.keyedvectors.Vocab at 0x1a2c13fa90>,
#  '🐔': <gensim.models.keyedvectors.Vocab at 0x1a2c13fac8>,
#  '🐦': <gensim.models.keyedvectors.Vocab at 0x1a2c13fb00>,
#  '🐤': <gensim.models.keyedvectors.Vocab at 0x1a2c13fb38>,
#  '🕗': <gensim.models.keyedvectors.Vocab at 0x1a2c13fb70>,
#  '😶': <gensim.models.keyedvectors.Vocab at 0x1a2c13fba8>,
#  '🙂': <gensim.models.keyedvectors.Vocab at 0x1a2c13fbe0>,
#  '🏟': <gensim.models.keyedvectors.Vocab at 0x1a2c13fc18>,
#  '👅': <gensim.models.keyedvectors.Vocab at 0x1a2c13fc50>,
#  '🐊': <gensim.models.keyedvectors.Vocab at 0x1a2c13fc88>,
#  '🎖': <gensim.models.keyedvectors.Vocab at 0x1a2c13fcc0>,
#  '🍔': <gensim.models.keyedvectors.Vocab at 0x1a2c13fcf8>,
#  '🎸': <gensim.models.keyedvectors.Vocab at 0x1a2c13fd30>,
#  '🎆': <gensim.models.keyedvectors.Vocab at 0x1a2c13fd68>,
#  '💁': <gensim.models.keyedvectors.Vocab at 0x1a2c13fda0>,
#  '🥂': <gensim.models.keyedvectors.Vocab at 0x1a2c13fdd8>,
#  '🤪': <gensim.models.keyedvectors.Vocab at 0x1a2c13fe10>,
#  '🇾': <gensim.models.keyedvectors.Vocab at 0x1a2c13fe48>,
#  '🦁': <gensim.models.keyedvectors.Vocab at 0x1a2c13fe80>,
#  '🔝': <gensim.models.keyedvectors.Vocab at 0x1a2c13feb8>,
#  '📸': <gensim.models.keyedvectors.Vocab at 0x1a2c13fef0>,
#  '🚀': <gensim.models.keyedvectors.Vocab at 0x1a2c13ff28>,
#  '🦌': <gensim.models.keyedvectors.Vocab at 0x1a2c13ff60>,
#  '😇': <gensim.models.keyedvectors.Vocab at 0x1a2c13ff98>,
#  '🚕': <gensim.models.keyedvectors.Vocab at 0x1a2c13ffd0>,
#  '🙅': <gensim.models.keyedvectors.Vocab at 0x1a2c142048>,
#  '😥': <gensim.models.keyedvectors.Vocab at 0x1a2c142080>,
#  '🗣': <gensim.models.keyedvectors.Vocab at 0x1a2c1420b8>,
#  '🏊': <gensim.models.keyedvectors.Vocab at 0x1a2c1420f0>,
#  '🤕': <gensim.models.keyedvectors.Vocab at 0x1a2c142128>,
#  '😡': <gensim.models.keyedvectors.Vocab at 0x1a2c142160>,
#  '⏰': <gensim.models.keyedvectors.Vocab at 0x1a2c142198>,
#  '🌙': <gensim.models.keyedvectors.Vocab at 0x1a2c1421d0>,
#  '🖐': <gensim.models.keyedvectors.Vocab at 0x1a2c142208>,
#  '🏡': <gensim.models.keyedvectors.Vocab at 0x1a2c142240>,
#  '🙉': <gensim.models.keyedvectors.Vocab at 0x1a2c142278>,
#  '🐽': <gensim.models.keyedvectors.Vocab at 0x1a2c1422b0>,
#  '🌶': <gensim.models.keyedvectors.Vocab at 0x1a2c1422e8>,
#  '🥁': <gensim.models.keyedvectors.Vocab at 0x1a2c142320>,
#  '🥇': <gensim.models.keyedvectors.Vocab at 0x1a2c142358>,
#  '🐢': <gensim.models.keyedvectors.Vocab at 0x1a2c142390>,
#  '🗽': <gensim.models.keyedvectors.Vocab at 0x1a2c1423c8>,
#  '🔪': <gensim.models.keyedvectors.Vocab at 0x1a2c142400>,
#  '😄': <gensim.models.keyedvectors.Vocab at 0x1a2c142438>,
#  '🚫': <gensim.models.keyedvectors.Vocab at 0x1a2c142470>,
#  '🧢': <gensim.models.keyedvectors.Vocab at 0x1a2c1424a8>,
#  '🐕': <gensim.models.keyedvectors.Vocab at 0x1a2c1424e0>,
#  '🕒': <gensim.models.keyedvectors.Vocab at 0x1a2c142518>,
#  '🐬': <gensim.models.keyedvectors.Vocab at 0x1a2c142550>,
#  '🔵': <gensim.models.keyedvectors.Vocab at 0x1a2c142588>,
#  '🔜': <gensim.models.keyedvectors.Vocab at 0x1a2c1425c0>,
#  '➗': <gensim.models.keyedvectors.Vocab at 0x1a2c1425f8>,
#  '🍊': <gensim.models.keyedvectors.Vocab at 0x1a2c142630>,
#  '👦': <gensim.models.keyedvectors.Vocab at 0x1a2c142668>,
#  '🕯': <gensim.models.keyedvectors.Vocab at 0x1a2c1426a0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x1a2c1426d8>,
#  '🧚': <gensim.models.keyedvectors.Vocab at 0x1a2c142710>,
#  '🚲': <gensim.models.keyedvectors.Vocab at 0x1a2c142748>,
#  '🌏': <gensim.models.keyedvectors.Vocab at 0x1a2c142780>,
#  '🆓': <gensim.models.keyedvectors.Vocab at 0x1a2c1427b8>,
#  '✍': <gensim.models.keyedvectors.Vocab at 0x1a2c1427f0>,
#  '😝': <gensim.models.keyedvectors.Vocab at 0x1a2c142828>,
#  '🥥': <gensim.models.keyedvectors.Vocab at 0x1a2c142860>,
#  '🌠': <gensim.models.keyedvectors.Vocab at 0x1a2c142898>,
#  '🇫': <gensim.models.keyedvectors.Vocab at 0x1a2c1428d0>,
#  '😛': <gensim.models.keyedvectors.Vocab at 0x1a2c142908>,
#  '🥊': <gensim.models.keyedvectors.Vocab at 0x1a2c142940>,
#  '🍗': <gensim.models.keyedvectors.Vocab at 0x1a2c142978>,
#  '😯': <gensim.models.keyedvectors.Vocab at 0x1a2c1429b0>,
#  '👧': <gensim.models.keyedvectors.Vocab at 0x1a2c1429e8>,
#  '🎀': <gensim.models.keyedvectors.Vocab at 0x1a2c142a20>,
#  '👩': <gensim.models.keyedvectors.Vocab at 0x1a2c142a58>,
#  '🦒': <gensim.models.keyedvectors.Vocab at 0x1a2c142a90>,
#  '🐝': <gensim.models.keyedvectors.Vocab at 0x1a2c142ac8>,
#  '🇰': <gensim.models.keyedvectors.Vocab at 0x1a2c142b00>,
#  '🏦': <gensim.models.keyedvectors.Vocab at 0x1a2c142b38>,
#  '🔨': <gensim.models.keyedvectors.Vocab at 0x1a2c142b70>,
#  '🖕': <gensim.models.keyedvectors.Vocab at 0x1a2c142ba8>,
#  '🔔': <gensim.models.keyedvectors.Vocab at 0x1a2c142be0>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x1a2c142c18>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x1a2c142c50>,
#  '🍁': <gensim.models.keyedvectors.Vocab at 0x1a2c142c88>,
#  '🆔': <gensim.models.keyedvectors.Vocab at 0x1a2c142cc0>,
#  '📝': <gensim.models.keyedvectors.Vocab at 0x1a2c142cf8>,
#  '😰': <gensim.models.keyedvectors.Vocab at 0x1a2c142d30>,
#  '😨': <gensim.models.keyedvectors.Vocab at 0x1a2c142d68>,
#  '🤫': <gensim.models.keyedvectors.Vocab at 0x1a2c142da0>,
#  '🍕': <gensim.models.keyedvectors.Vocab at 0x1a2c142dd8>,
#  '😙': <gensim.models.keyedvectors.Vocab at 0x1a2c142e10>,
#  '❌': <gensim.models.keyedvectors.Vocab at 0x1a2c142e48>,
#  '🏄': <gensim.models.keyedvectors.Vocab at 0x1a2c142e80>,
#  '🍟': <gensim.models.keyedvectors.Vocab at 0x1a2c142eb8>,
#  '🗯': <gensim.models.keyedvectors.Vocab at 0x1a2c142ef0>,
#  '📬': <gensim.models.keyedvectors.Vocab at 0x1a2c142f28>,
#  '🛑': <gensim.models.keyedvectors.Vocab at 0x1a2c142f60>,
#  '🍒': <gensim.models.keyedvectors.Vocab at 0x1a2c142f98>,
#  '🚚': <gensim.models.keyedvectors.Vocab at 0x1a2c142fd0>,
#  '🏏': <gensim.models.keyedvectors.Vocab at 0x1a2c145048>,
#  '🦅': <gensim.models.keyedvectors.Vocab at 0x1a2c145080>,
#  '🏅': <gensim.models.keyedvectors.Vocab at 0x1a2c1450b8>,
#  '🎨': <gensim.models.keyedvectors.Vocab at 0x1a2c1450f0>,
#  '🎻': <gensim.models.keyedvectors.Vocab at 0x1a2c145128>,
#  '🎬': <gensim.models.keyedvectors.Vocab at 0x1a2c145160>,
#  '🤽': <gensim.models.keyedvectors.Vocab at 0x1a2c145198>,
#  '🐷': <gensim.models.keyedvectors.Vocab at 0x1a2c1451d0>,
#  '💶': <gensim.models.keyedvectors.Vocab at 0x1a2c145208>,
#  '😹': <gensim.models.keyedvectors.Vocab at 0x1a2c145240>,
#  '🎮': <gensim.models.keyedvectors.Vocab at 0x1a2c145278>,
#  '🤾': <gensim.models.keyedvectors.Vocab at 0x1a2c1452b0>,
#  '❄': <gensim.models.keyedvectors.Vocab at 0x1a2c1452e8>,
#  '🌡': <gensim.models.keyedvectors.Vocab at 0x1a2c145320>,
#  '🛸': <gensim.models.keyedvectors.Vocab at 0x1a2c145358>,
#  '💢': <gensim.models.keyedvectors.Vocab at 0x1a2c145390>,
#  '💬': <gensim.models.keyedvectors.Vocab at 0x1a2c1453c8>,
#  '💭': <gensim.models.keyedvectors.Vocab at 0x1a2c145400>,
#  '🌝': <gensim.models.keyedvectors.Vocab at 0x1a2c145438>,
#  '⚓': <gensim.models.keyedvectors.Vocab at 0x1a2c145470>,
#  '🔁': <gensim.models.keyedvectors.Vocab at 0x1a2c1454a8>,
#  '💸': <gensim.models.keyedvectors.Vocab at 0x1a2c1454e0>,
#  '🤑': <gensim.models.keyedvectors.Vocab at 0x1a2c145518>,
#  '💂': <gensim.models.keyedvectors.Vocab at 0x1a2c145550>,
#  '🔈': <gensim.models.keyedvectors.Vocab at 0x1a2c145588>,
#  '😺': <gensim.models.keyedvectors.Vocab at 0x1a2c1455c0>,
#  '✌': <gensim.models.keyedvectors.Vocab at 0x1a2c1455f8>,
#  '💮': <gensim.models.keyedvectors.Vocab at 0x1a2c145630>,
#  '🚮': <gensim.models.keyedvectors.Vocab at 0x1a2c145668>,
#  '🤮': <gensim.models.keyedvectors.Vocab at 0x1a2c1456a0>,
#  '🥗': <gensim.models.keyedvectors.Vocab at 0x1a2c1456d8>,
#  '👁': <gensim.models.keyedvectors.Vocab at 0x1a2c145710>,
#  '🥩': <gensim.models.keyedvectors.Vocab at 0x1a2c145748>,
#  '🧀': <gensim.models.keyedvectors.Vocab at 0x1a2c145780>,
#  '🤩': <gensim.models.keyedvectors.Vocab at 0x1a2c1457b8>,
#  '👺': <gensim.models.keyedvectors.Vocab at 0x1a2c1457f0>,
#  '👹': <gensim.models.keyedvectors.Vocab at 0x1a2c145828>,
#  '❔': <gensim.models.keyedvectors.Vocab at 0x1a2c145860>,
#  '🍦': <gensim.models.keyedvectors.Vocab at 0x1a2c145898>,
#  '🏒': <gensim.models.keyedvectors.Vocab at 0x1a2c1458d0>,
#  '⛸': <gensim.models.keyedvectors.Vocab at 0x1a2c145908>,
#  '🥅': <gensim.models.keyedvectors.Vocab at 0x1a2c145940>,
#  '☔': <gensim.models.keyedvectors.Vocab at 0x1a2c145978>,
#  '💡': <gensim.models.keyedvectors.Vocab at 0x1a2c1459b0>,
#  '💻': <gensim.models.keyedvectors.Vocab at 0x1a2c1459e8>,
#  '😾': <gensim.models.keyedvectors.Vocab at 0x1a2c145a20>,
#  '📰': <gensim.models.keyedvectors.Vocab at 0x1a2c145a58>,
#  '🍝': <gensim.models.keyedvectors.Vocab at 0x1a2c145a90>,
#  '🍜': <gensim.models.keyedvectors.Vocab at 0x1a2c145ac8>,
#  '💑': <gensim.models.keyedvectors.Vocab at 0x1a2c145b00>,
#  '🍿': <gensim.models.keyedvectors.Vocab at 0x1a2c145b38>,
#  '🔬': <gensim.models.keyedvectors.Vocab at 0x1a2c145b70>,
#  '🤺': <gensim.models.keyedvectors.Vocab at 0x1a2c145ba8>,
#  '🍇': <gensim.models.keyedvectors.Vocab at 0x1a2c145be0>,
#  '💄': <gensim.models.keyedvectors.Vocab at 0x1a2c145c18>,
#  '🏍': <gensim.models.keyedvectors.Vocab at 0x1a2c145c50>,
#  '🐯': <gensim.models.keyedvectors.Vocab at 0x1a2c145c88>,
#  '🚄': <gensim.models.keyedvectors.Vocab at 0x1a2c145cc0>,
#  '🥛': <gensim.models.keyedvectors.Vocab at 0x1a2c145cf8>,
#  '🦈': <gensim.models.keyedvectors.Vocab at 0x1a2c145d30>,
#  '💤': <gensim.models.keyedvectors.Vocab at 0x1a2c145d68>,
#  '🐍': <gensim.models.keyedvectors.Vocab at 0x1a2c145da0>,
#  '🐐': <gensim.models.keyedvectors.Vocab at 0x1a2c145dd8>,
#  '🤓': <gensim.models.keyedvectors.Vocab at 0x1a2c145e10>,
#  '🕷': <gensim.models.keyedvectors.Vocab at 0x1a2c145e48>,
#  '👶': <gensim.models.keyedvectors.Vocab at 0x1a2c145e80>,
#  '🌾': <gensim.models.keyedvectors.Vocab at 0x1a2c145eb8>,
#  '🐑': <gensim.models.keyedvectors.Vocab at 0x1a2c145ef0>,
#  '🏝': <gensim.models.keyedvectors.Vocab at 0x1a2c145f28>,
#  '😵': <gensim.models.keyedvectors.Vocab at 0x1a2c145f60>,
#  '👭': <gensim.models.keyedvectors.Vocab at 0x1a2c145f98>,
#  '👵': <gensim.models.keyedvectors.Vocab at 0x1a2c145fd0>,
#  '👱': <gensim.models.keyedvectors.Vocab at 0x1a2c149048>,
#  '🥤': <gensim.models.keyedvectors.Vocab at 0x1a2c149080>,
#  '😴': <gensim.models.keyedvectors.Vocab at 0x1a2c1490b8>,
#  '🤖': <gensim.models.keyedvectors.Vocab at 0x1a2c1490f0>,
#  '👄': <gensim.models.keyedvectors.Vocab at 0x1a2c149128>,
#  '🐰': <gensim.models.keyedvectors.Vocab at 0x1a2c149160>,
#  '🌃': <gensim.models.keyedvectors.Vocab at 0x1a2c149198>,
#  '🚙': <gensim.models.keyedvectors.Vocab at 0x1a2c1491d0>,
#  '💊': <gensim.models.keyedvectors.Vocab at 0x1a2c149208>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x1a2c149240>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x1a2c149278>,
#  '👙': <gensim.models.keyedvectors.Vocab at 0x1a2c1492b0>,
#  '🎲': <gensim.models.keyedvectors.Vocab at 0x1a2c1492e8>,
#  '😖': <gensim.models.keyedvectors.Vocab at 0x1a2c149320>,
#  '™': <gensim.models.keyedvectors.Vocab at 0x1a2c149358>,
#  '♣': <gensim.models.keyedvectors.Vocab at 0x1a2c149390>,
#  '🤒': <gensim.models.keyedvectors.Vocab at 0x1a2c1493c8>,
#  '🙀': <gensim.models.keyedvectors.Vocab at 0x1a2c149400>,
#  '👼': <gensim.models.keyedvectors.Vocab at 0x1a2c149438>,
#  '💉': <gensim.models.keyedvectors.Vocab at 0x1a2c149470>,
#  '🍻': <gensim.models.keyedvectors.Vocab at 0x1a2c1494a8>,
#  '🗳': <gensim.models.keyedvectors.Vocab at 0x1a2c1494e0>,
#  '✏': <gensim.models.keyedvectors.Vocab at 0x1a2c149518>,
#  '🦊': <gensim.models.keyedvectors.Vocab at 0x1a2c149550>,
#  '🐘': <gensim.models.keyedvectors.Vocab at 0x1a2c149588>,
#  '🇽': <gensim.models.keyedvectors.Vocab at 0x1a2c1495c0>,
#  '🏫': <gensim.models.keyedvectors.Vocab at 0x1a2c1495f8>,
#  '🍓': <gensim.models.keyedvectors.Vocab at 0x1a2c149630>,
#  '🏖': <gensim.models.keyedvectors.Vocab at 0x1a2c149668>,
#  '👮': <gensim.models.keyedvectors.Vocab at 0x1a2c1496a0>,
#  '🤙': <gensim.models.keyedvectors.Vocab at 0x1a2c1496d8>,
#  '⭕': <gensim.models.keyedvectors.Vocab at 0x1a2c149710>,
#  '❓': <gensim.models.keyedvectors.Vocab at 0x1a2c149748>,
#  '☎': <gensim.models.keyedvectors.Vocab at 0x1a2c149780>,
#  '📺': <gensim.models.keyedvectors.Vocab at 0x1a2c1497b8>,
#  '🔌': <gensim.models.keyedvectors.Vocab at 0x1a2c1497f0>,
#  '🏈': <gensim.models.keyedvectors.Vocab at 0x1a2c149828>,
#  '🌐': <gensim.models.keyedvectors.Vocab at 0x1a2c149860>,
#  '🥦': <gensim.models.keyedvectors.Vocab at 0x1a2c149898>,
#  '🥒': <gensim.models.keyedvectors.Vocab at 0x1a2c1498d0>,
#  '🍏': <gensim.models.keyedvectors.Vocab at 0x1a2c149908>,
#  '🚥': <gensim.models.keyedvectors.Vocab at 0x1a2c149940>,
#  '🔰': <gensim.models.keyedvectors.Vocab at 0x1a2c149978>,
#  '\U000e007f': <gensim.models.keyedvectors.Vocab at 0x1a2c1499b0>,
#  '\U000e0073': <gensim.models.keyedvectors.Vocab at 0x1a2c1499e8>,
#  '\U000e0063': <gensim.models.keyedvectors.Vocab at 0x1a2c149a20>,
#  '\U000e0067': <gensim.models.keyedvectors.Vocab at 0x1a2c149a58>,
#  '\U000e0074': <gensim.models.keyedvectors.Vocab at 0x1a2c149a90>,
#  '\U000e0062': <gensim.models.keyedvectors.Vocab at 0x1a2c149ac8>,
#  '🏴': <gensim.models.keyedvectors.Vocab at 0x1a2c149b00>,
#  '🔺': <gensim.models.keyedvectors.Vocab at 0x1a2c149b38>,
#  '🔫': <gensim.models.keyedvectors.Vocab at 0x1a2c149b70>,
#  '☠': <gensim.models.keyedvectors.Vocab at 0x1a2c149ba8>,
#  '🌛': <gensim.models.keyedvectors.Vocab at 0x1a2c149be0>,
#  '▶': <gensim.models.keyedvectors.Vocab at 0x1a2c149c18>,
#  '💽': <gensim.models.keyedvectors.Vocab at 0x1a2c149c50>,
#  '😷': <gensim.models.keyedvectors.Vocab at 0x1a2c149c88>,
#  '😦': <gensim.models.keyedvectors.Vocab at 0x1a2c149cc0>,
#  '🐄': <gensim.models.keyedvectors.Vocab at 0x1a2c149cf8>,
#  '⛵': <gensim.models.keyedvectors.Vocab at 0x1a2c149d30>,
#  '⛏': <gensim.models.keyedvectors.Vocab at 0x1a2c149d68>,
#  '💧': <gensim.models.keyedvectors.Vocab at 0x1a2c149da0>,
#  '🍮': <gensim.models.keyedvectors.Vocab at 0x1a2c149dd8>,
#  '🥧': <gensim.models.keyedvectors.Vocab at 0x1a2c149e10>,
#  '♓': <gensim.models.keyedvectors.Vocab at 0x1a2c149e48>,
#  '🏠': <gensim.models.keyedvectors.Vocab at 0x1a2c149e80>,
#  '🏭': <gensim.models.keyedvectors.Vocab at 0x1a2c149eb8>,
#  '🏢': <gensim.models.keyedvectors.Vocab at 0x1a2c149ef0>,
#  '🤸': <gensim.models.keyedvectors.Vocab at 0x1a2c149f28>,
#  '📀': <gensim.models.keyedvectors.Vocab at 0x1a2c149f60>,
#  '🏎': <gensim.models.keyedvectors.Vocab at 0x1a2c149f98>,
#  '🚦': <gensim.models.keyedvectors.Vocab at 0x1a2c149fd0>,
#  '🔗': <gensim.models.keyedvectors.Vocab at 0x1a2c14d048>,
#  '👰': <gensim.models.keyedvectors.Vocab at 0x1a2c14d080>,
#  '💍': <gensim.models.keyedvectors.Vocab at 0x1a2c14d0b8>,
#  '🎟': <gensim.models.keyedvectors.Vocab at 0x1a2c14d0f0>,
#  '🎪': <gensim.models.keyedvectors.Vocab at 0x1a2c14d128>,
#  '🆕': <gensim.models.keyedvectors.Vocab at 0x1a2c14d160>,
#  '👕': <gensim.models.keyedvectors.Vocab at 0x1a2c14d198>,
#  '🍩': <gensim.models.keyedvectors.Vocab at 0x1a2c14d1d0>,
#  '🛫': <gensim.models.keyedvectors.Vocab at 0x1a2c14d208>,
#  '🦄': <gensim.models.keyedvectors.Vocab at 0x1a2c14d240>,
#  '🕊': <gensim.models.keyedvectors.Vocab at 0x1a2c14d278>,
#  '🙁': <gensim.models.keyedvectors.Vocab at 0x1a2c14d2b0>,
#  '🚓': <gensim.models.keyedvectors.Vocab at 0x1a2c14d2e8>,
#  '🚑': <gensim.models.keyedvectors.Vocab at 0x1a2c14d320>,
#  '🎯': <gensim.models.keyedvectors.Vocab at 0x1a2c14d358>,
#  '⬅': <gensim.models.keyedvectors.Vocab at 0x1a2c14d390>,
#  '🇹': <gensim.models.keyedvectors.Vocab at 0x1a2c14d3c8>,
#  '®': <gensim.models.keyedvectors.Vocab at 0x1a2c14d400>,
#  '🐸': <gensim.models.keyedvectors.Vocab at 0x1a2c14d438>,
#  '☕': <gensim.models.keyedvectors.Vocab at 0x1a2c14d470>,
#  '🙇': <gensim.models.keyedvectors.Vocab at 0x1a2c14d4a8>,
#  '💒': <gensim.models.keyedvectors.Vocab at 0x1a2c14d4e0>,
#  '💏': <gensim.models.keyedvectors.Vocab at 0x1a2c14d518>,
#  '🤵': <gensim.models.keyedvectors.Vocab at 0x1a2c14d550>,
#  '🐙': <gensim.models.keyedvectors.Vocab at 0x1a2c14d588>,
#  '😐': <gensim.models.keyedvectors.Vocab at 0x1a2c14d5c0>,
#  '😟': <gensim.models.keyedvectors.Vocab at 0x1a2c14d5f8>,
#  '📈': <gensim.models.keyedvectors.Vocab at 0x1a2c14d630>,
#  '💆': <gensim.models.keyedvectors.Vocab at 0x1a2c14d668>,
#  '🗓': <gensim.models.keyedvectors.Vocab at 0x1a2c14d6a0>,
#  '🚂': <gensim.models.keyedvectors.Vocab at 0x1a2c14d6d8>,
#  '⏱': <gensim.models.keyedvectors.Vocab at 0x1a2c14d710>,
#  '⚙': <gensim.models.keyedvectors.Vocab at 0x1a2c14d748>,
#  '↔': <gensim.models.keyedvectors.Vocab at 0x1a2c14d780>,
#  '🚺': <gensim.models.keyedvectors.Vocab at 0x1a2c14d7b8>,
#  '🔉': <gensim.models.keyedvectors.Vocab at 0x1a2c14d7f0>,
#  '🤝': <gensim.models.keyedvectors.Vocab at 0x1a2c14d828>,
#  '🍺': <gensim.models.keyedvectors.Vocab at 0x1a2c14d860>,
#  '👢': <gensim.models.keyedvectors.Vocab at 0x1a2c14d898>,
#  '🛣': <gensim.models.keyedvectors.Vocab at 0x1a2c14d8d0>,
#  '⛄': <gensim.models.keyedvectors.Vocab at 0x1a2c14d908>,
#  '🌬': <gensim.models.keyedvectors.Vocab at 0x1a2c14d940>,
#  '🌩': <gensim.models.keyedvectors.Vocab at 0x1a2c14d978>,
#  '♠': <gensim.models.keyedvectors.Vocab at 0x1a2c14d9b0>,
#  '🚍': <gensim.models.keyedvectors.Vocab at 0x1a2c14d9e8>,
#  '🌜': <gensim.models.keyedvectors.Vocab at 0x1a2c14da20>,
#  '🍹': <gensim.models.keyedvectors.Vocab at 0x1a2c14da58>,
#  '👔': <gensim.models.keyedvectors.Vocab at 0x1a2c14da90>,
#  '🌕': <gensim.models.keyedvectors.Vocab at 0x1a2c14dac8>,
#  '👻': <gensim.models.keyedvectors.Vocab at 0x1a2c14db00>,
#  '🍂': <gensim.models.keyedvectors.Vocab at 0x1a2c14db38>,
#  '🎋': <gensim.models.keyedvectors.Vocab at 0x1a2c14db70>,
#  '🕔': <gensim.models.keyedvectors.Vocab at 0x1a2c14dba8>,
#  '🕑': <gensim.models.keyedvectors.Vocab at 0x1a2c14dbe0>,
#  '🕚': <gensim.models.keyedvectors.Vocab at 0x1a2c14dc18>,
#  '🕦': <gensim.models.keyedvectors.Vocab at 0x1a2c14dc50>,
#  '🕕': <gensim.models.keyedvectors.Vocab at 0x1a2c14dc88>,
#  '🕖': <gensim.models.keyedvectors.Vocab at 0x1a2c14dcc0>,
#  '🕓': <gensim.models.keyedvectors.Vocab at 0x1a2c14dcf8>,
#  '🕥': <gensim.models.keyedvectors.Vocab at 0x1a2c14dd30>,
#  '🕧': <gensim.models.keyedvectors.Vocab at 0x1a2c14dd68>,
#  '🕐': <gensim.models.keyedvectors.Vocab at 0x1a2c14dda0>,
#  '🕤': <gensim.models.keyedvectors.Vocab at 0x1a2c14ddd8>,
#  '📃': <gensim.models.keyedvectors.Vocab at 0x1a2c14de10>,
#  '🔆': <gensim.models.keyedvectors.Vocab at 0x1a2c14de48>,
#  '⌚': <gensim.models.keyedvectors.Vocab at 0x1a2c14de80>,
#  '🎧': <gensim.models.keyedvectors.Vocab at 0x1a2c14deb8>,
#  '⛷': <gensim.models.keyedvectors.Vocab at 0x1a2c14def0>,
#  '🌄': <gensim.models.keyedvectors.Vocab at 0x1a2c14df28>,
#  '🎩': <gensim.models.keyedvectors.Vocab at 0x1a2c14df60>,
#  '🔂': <gensim.models.keyedvectors.Vocab at 0x1a2c14df98>,
#  '😪': <gensim.models.keyedvectors.Vocab at 0x1a2c14dfd0>,
#  '👎': <gensim.models.keyedvectors.Vocab at 0x1a2c150048>,
#  '🍡': <gensim.models.keyedvectors.Vocab at 0x1a2c150080>,
#  '🍨': <gensim.models.keyedvectors.Vocab at 0x1a2c1500b8>,
#  '🍧': <gensim.models.keyedvectors.Vocab at 0x1a2c1500f0>,
#  '🚔': <gensim.models.keyedvectors.Vocab at 0x1a2c150128>,
#  '🚒': <gensim.models.keyedvectors.Vocab at 0x1a2c150160>,
#  '🎾': <gensim.models.keyedvectors.Vocab at 0x1a2c150198>,
#  '🌋': <gensim.models.keyedvectors.Vocab at 0x1a2c1501d0>,
#  '💼': <gensim.models.keyedvectors.Vocab at 0x1a2c150208>,
#  '🥈': <gensim.models.keyedvectors.Vocab at 0x1a2c150240>,
#  '⛓': <gensim.models.keyedvectors.Vocab at 0x1a2c150278>,
#  '🥉': <gensim.models.keyedvectors.Vocab at 0x1a2c1502b0>,
#  '👃': <gensim.models.keyedvectors.Vocab at 0x1a2c1502e8>,
#  '🖌': <gensim.models.keyedvectors.Vocab at 0x1a2c150320>,
#  '🍅': <gensim.models.keyedvectors.Vocab at 0x1a2c150358>,
#  '🥟': <gensim.models.keyedvectors.Vocab at 0x1a2c150390>,
#  '🥐': <gensim.models.keyedvectors.Vocab at 0x1a2c1503c8>,
#  '🌮': <gensim.models.keyedvectors.Vocab at 0x1a2c150400>,
#  '🍣': <gensim.models.keyedvectors.Vocab at 0x1a2c150438>,
#  '🦇': <gensim.models.keyedvectors.Vocab at 0x1a2c150470>,
#  '🗒': <gensim.models.keyedvectors.Vocab at 0x1a2c1504a8>,
#  '🖍': <gensim.models.keyedvectors.Vocab at 0x1a2c1504e0>,
#  '🗞': <gensim.models.keyedvectors.Vocab at 0x1a2c150518>,
#  '🚘': <gensim.models.keyedvectors.Vocab at 0x1a2c150550>,
#  '🚣': <gensim.models.keyedvectors.Vocab at 0x1a2c150588>,
#  '🅰': <gensim.models.keyedvectors.Vocab at 0x1a2c1505c0>,
#  '🅿': <gensim.models.keyedvectors.Vocab at 0x1a2c1505f8>,
#  '📧': <gensim.models.keyedvectors.Vocab at 0x1a2c150630>,
#  '©': <gensim.models.keyedvectors.Vocab at 0x1a2c150668>,
#  '🔛': <gensim.models.keyedvectors.Vocab at 0x1a2c1506a0>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x1a2c1506d8>,
#  '⬇': <gensim.models.keyedvectors.Vocab at 0x1a2c150710>,
#  '✖': <gensim.models.keyedvectors.Vocab at 0x1a2c150748>,
#  '🔮': <gensim.models.keyedvectors.Vocab at 0x1a2c150780>,
#  '🗿': <gensim.models.keyedvectors.Vocab at 0x1a2c1507b8>,
#  '🎒': <gensim.models.keyedvectors.Vocab at 0x1a2c1507f0>,
#  '⚫': <gensim.models.keyedvectors.Vocab at 0x1a2c150828>,
#  '🍱': <gensim.models.keyedvectors.Vocab at 0x1a2c150860>,
#  '🧐': <gensim.models.keyedvectors.Vocab at 0x1a2c150898>,
#  '⛪': <gensim.models.keyedvectors.Vocab at 0x1a2c1508d0>,
#  '🗡': <gensim.models.keyedvectors.Vocab at 0x1a2c150908>,
#  '🏋': <gensim.models.keyedvectors.Vocab at 0x1a2c150940>,
#  '🐼': <gensim.models.keyedvectors.Vocab at 0x1a2c150978>,
#  '🚌': <gensim.models.keyedvectors.Vocab at 0x1a2c1509b0>,
#  '💇': <gensim.models.keyedvectors.Vocab at 0x1a2c1509e8>,
#  '🏉': <gensim.models.keyedvectors.Vocab at 0x1a2c150a20>,
#  '⚔': <gensim.models.keyedvectors.Vocab at 0x1a2c150a58>,
#  '☝': <gensim.models.keyedvectors.Vocab at 0x1a2c150a90>,
#  '🌔': <gensim.models.keyedvectors.Vocab at 0x1a2c150ac8>,
#  '⤵': <gensim.models.keyedvectors.Vocab at 0x1a2c150b00>,
#  '💵': <gensim.models.keyedvectors.Vocab at 0x1a2c150b38>,
#  '☄': <gensim.models.keyedvectors.Vocab at 0x1a2c150b70>,
#  '🐺': <gensim.models.keyedvectors.Vocab at 0x1a2c150ba8>,
#  '🧕': <gensim.models.keyedvectors.Vocab at 0x1a2c150be0>,
#  '🐉': <gensim.models.keyedvectors.Vocab at 0x1a2c150c18>,
#  '🆙': <gensim.models.keyedvectors.Vocab at 0x1a2c150c50>,
#  '🧙': <gensim.models.keyedvectors.Vocab at 0x1a2c150c88>,
#  '👿': <gensim.models.keyedvectors.Vocab at 0x1a2c150cc0>,
#  '🤳': <gensim.models.keyedvectors.Vocab at 0x1a2c150cf8>,
#  '🐂': <gensim.models.keyedvectors.Vocab at 0x1a2c150d30>,
#  '👤': <gensim.models.keyedvectors.Vocab at 0x1a2c150d68>,
#  '🌽': <gensim.models.keyedvectors.Vocab at 0x1a2c150da0>,
#  '🇴': <gensim.models.keyedvectors.Vocab at 0x1a2c150dd8>,
#  '🤐': <gensim.models.keyedvectors.Vocab at 0x1a2c150e10>,
#  '🗝': <gensim.models.keyedvectors.Vocab at 0x1a2c150e48>,
#  '🌲': <gensim.models.keyedvectors.Vocab at 0x1a2c150e80>,
#  '🌀': <gensim.models.keyedvectors.Vocab at 0x1a2c150eb8>,
#  '🔚': <gensim.models.keyedvectors.Vocab at 0x1a2c150ef0>,
#  '🍖': <gensim.models.keyedvectors.Vocab at 0x1a2c150f28>,
#  '🐚': <gensim.models.keyedvectors.Vocab at 0x1a2c150f60>,
#  '☘': <gensim.models.keyedvectors.Vocab at 0x1a2c150f98>,
#  '⛈': <gensim.models.keyedvectors.Vocab at 0x1a2c150fd0>,
#  '⚖': <gensim.models.keyedvectors.Vocab at 0x1a2c153048>,
#  '📵': <gensim.models.keyedvectors.Vocab at 0x1a2c153080>,
#  '🔐': <gensim.models.keyedvectors.Vocab at 0x1a2c1530b8>,
#  '🦕': <gensim.models.keyedvectors.Vocab at 0x1a2c1530f0>,
#  '👐': <gensim.models.keyedvectors.Vocab at 0x1a2c153128>,
#  '👓': <gensim.models.keyedvectors.Vocab at 0x1a2c153160>,
#  '🧦': <gensim.models.keyedvectors.Vocab at 0x1a2c153198>,
#  '🥃': <gensim.models.keyedvectors.Vocab at 0x1a2c1531d0>,
#  '🎡': <gensim.models.keyedvectors.Vocab at 0x1a2c153208>,
#  '☸': <gensim.models.keyedvectors.Vocab at 0x1a2c153240>,
#  '🏹': <gensim.models.keyedvectors.Vocab at 0x1a2c153278>,
#  '⌛': <gensim.models.keyedvectors.Vocab at 0x1a2c1532b0>,
#  '🥜': <gensim.models.keyedvectors.Vocab at 0x1a2c1532e8>,
#  '💠': <gensim.models.keyedvectors.Vocab at 0x1a2c153320>,
#  '🦆': <gensim.models.keyedvectors.Vocab at 0x1a2c153358>,
#  '✡': <gensim.models.keyedvectors.Vocab at 0x1a2c153390>,
#  '🕳': <gensim.models.keyedvectors.Vocab at 0x1a2c1533c8>,
#  '👽': <gensim.models.keyedvectors.Vocab at 0x1a2c153400>,
#  '⚾': <gensim.models.keyedvectors.Vocab at 0x1a2c153438>,
#  '🗻': <gensim.models.keyedvectors.Vocab at 0x1a2c153470>,
#  '🏰': <gensim.models.keyedvectors.Vocab at 0x1a2c1534a8>,
#  '🍴': <gensim.models.keyedvectors.Vocab at 0x1a2c1534e0>,
#  '🔱': <gensim.models.keyedvectors.Vocab at 0x1a2c153518>,
#  '🚹': <gensim.models.keyedvectors.Vocab at 0x1a2c153550>,
#  '⛽': <gensim.models.keyedvectors.Vocab at 0x1a2c153588>,
#  '🥓': <gensim.models.keyedvectors.Vocab at 0x1a2c1535c0>,
#  '🥪': <gensim.models.keyedvectors.Vocab at 0x1a2c1535f8>,
#  '🥨': <gensim.models.keyedvectors.Vocab at 0x1a2c153630>,
#  '🥖': <gensim.models.keyedvectors.Vocab at 0x1a2c153668>,
#  '🐞': <gensim.models.keyedvectors.Vocab at 0x1a2c1536a0>,
#  '🍎': <gensim.models.keyedvectors.Vocab at 0x1a2c1536d8>,
#  '☹': <gensim.models.keyedvectors.Vocab at 0x1a2c153710>,
#  '⛹': <gensim.models.keyedvectors.Vocab at 0x1a2c153748>,
#  '🤚': <gensim.models.keyedvectors.Vocab at 0x1a2c153780>,
#  '🌭': <gensim.models.keyedvectors.Vocab at 0x1a2c1537b8>,
#  '🦉': <gensim.models.keyedvectors.Vocab at 0x1a2c1537f0>,
#  '🛡': <gensim.models.keyedvectors.Vocab at 0x1a2c153828>,
#  '🍯': <gensim.models.keyedvectors.Vocab at 0x1a2c153860>,
#  '🕹': <gensim.models.keyedvectors.Vocab at 0x1a2c153898>,
#  '🌇': <gensim.models.keyedvectors.Vocab at 0x1a2c1538d0>,
#  '👞': <gensim.models.keyedvectors.Vocab at 0x1a2c153908>,
#  '🤛': <gensim.models.keyedvectors.Vocab at 0x1a2c153940>,
#  '🐟': <gensim.models.keyedvectors.Vocab at 0x1a2c153978>,
#  '🔽': <gensim.models.keyedvectors.Vocab at 0x1a2c1539b0>,
#  '👆': <gensim.models.keyedvectors.Vocab at 0x1a2c1539e8>,
#  '🏨': <gensim.models.keyedvectors.Vocab at 0x1a2c153a20>,
#  '🏥': <gensim.models.keyedvectors.Vocab at 0x1a2c153a58>,
#  '🔢': <gensim.models.keyedvectors.Vocab at 0x1a2c153a90>,
#  '⚛': <gensim.models.keyedvectors.Vocab at 0x1a2c153ac8>,
#  '🐨': <gensim.models.keyedvectors.Vocab at 0x1a2c153b00>,
#  '\U000e0065': <gensim.models.keyedvectors.Vocab at 0x1a2c153b38>,
#  '\U000e006e': <gensim.models.keyedvectors.Vocab at 0x1a2c153b70>,
#  '🎺': <gensim.models.keyedvectors.Vocab at 0x1a2c153ba8>,
#  '🍼': <gensim.models.keyedvectors.Vocab at 0x1a2c153be0>,
#  '⬛': <gensim.models.keyedvectors.Vocab at 0x1a2c153c18>,
#  '😗': <gensim.models.keyedvectors.Vocab at 0x1a2c153c50>,
#  '🕋': <gensim.models.keyedvectors.Vocab at 0x1a2c153c88>,
#  '📿': <gensim.models.keyedvectors.Vocab at 0x1a2c153cc0>,
#  '🚢': <gensim.models.keyedvectors.Vocab at 0x1a2c153cf8>,
#  '🥞': <gensim.models.keyedvectors.Vocab at 0x1a2c153d30>,
#  '🐹': <gensim.models.keyedvectors.Vocab at 0x1a2c153d68>,
#  '🥕': <gensim.models.keyedvectors.Vocab at 0x1a2c153da0>,
#  '🤰': <gensim.models.keyedvectors.Vocab at 0x1a2c153dd8>,
#  '⁉': <gensim.models.keyedvectors.Vocab at 0x1a2c153e10>,
#  '💲': <gensim.models.keyedvectors.Vocab at 0x1a2c153e48>,
#  '♑': <gensim.models.keyedvectors.Vocab at 0x1a2c153e80>,
#  '🐋': <gensim.models.keyedvectors.Vocab at 0x1a2c153eb8>,
#  '🐳': <gensim.models.keyedvectors.Vocab at 0x1a2c153ef0>,
#  '🦑': <gensim.models.keyedvectors.Vocab at 0x1a2c153f28>,
#  '🦀': <gensim.models.keyedvectors.Vocab at 0x1a2c153f60>,
#  '◾': <gensim.models.keyedvectors.Vocab at 0x1a2c153f98>,
#  '🔶': <gensim.models.keyedvectors.Vocab at 0x1a2c153fd0>,
#  '⏩': <gensim.models.keyedvectors.Vocab at 0x1a2c324048>,
#  '🐅': <gensim.models.keyedvectors.Vocab at 0x1a2c324080>,
#  '🤨': <gensim.models.keyedvectors.Vocab at 0x1a2c3240b8>,
#  '👷': <gensim.models.keyedvectors.Vocab at 0x1a2c3240f0>,
#  '🏘': <gensim.models.keyedvectors.Vocab at 0x1a2c324128>,
#  '🌪': <gensim.models.keyedvectors.Vocab at 0x1a2c324160>,
#  '🧛': <gensim.models.keyedvectors.Vocab at 0x1a2c324198>,
#  '✂': <gensim.models.keyedvectors.Vocab at 0x1a2c3241d0>,
#  '🔷': <gensim.models.keyedvectors.Vocab at 0x1a2c324208>,
#  '🔍': <gensim.models.keyedvectors.Vocab at 0x1a2c324240>,
#  '🔎': <gensim.models.keyedvectors.Vocab at 0x1a2c324278>,
#  '🌯': <gensim.models.keyedvectors.Vocab at 0x1a2c3242b0>,
#  '✝': <gensim.models.keyedvectors.Vocab at 0x1a2c3242e8>,
#  '➕': <gensim.models.keyedvectors.Vocab at 0x1a2c324320>,
#  '🖖': <gensim.models.keyedvectors.Vocab at 0x1a2c324358>,
#  '⚰': <gensim.models.keyedvectors.Vocab at 0x1a2c324390>,
#  '👾': <gensim.models.keyedvectors.Vocab at 0x1a2c3243c8>,
#  '⛩': <gensim.models.keyedvectors.Vocab at 0x1a2c324400>,
#  '🧥': <gensim.models.keyedvectors.Vocab at 0x1a2c324438>,
#  '📮': <gensim.models.keyedvectors.Vocab at 0x1a2c324470>,
#  '🎠': <gensim.models.keyedvectors.Vocab at 0x1a2c3244a8>,
#  '🎭': <gensim.models.keyedvectors.Vocab at 0x1a2c3244e0>,
#  '🎢': <gensim.models.keyedvectors.Vocab at 0x1a2c324518>,
#  '😼': <gensim.models.keyedvectors.Vocab at 0x1a2c324550>,
#  '🤲': <gensim.models.keyedvectors.Vocab at 0x1a2c324588>,
#  '🧜': <gensim.models.keyedvectors.Vocab at 0x1a2c3245c0>,
#  '🚬': <gensim.models.keyedvectors.Vocab at 0x1a2c3245f8>,
#  '🏇': <gensim.models.keyedvectors.Vocab at 0x1a2c324630>,
#  '🎄': <gensim.models.keyedvectors.Vocab at 0x1a2c324668>,
#  '🗂': <gensim.models.keyedvectors.Vocab at 0x1a2c3246a0>,
#  '🐀': <gensim.models.keyedvectors.Vocab at 0x1a2c3246d8>,
#  '🔸': <gensim.models.keyedvectors.Vocab at 0x1a2c324710>,
#  '👚': <gensim.models.keyedvectors.Vocab at 0x1a2c324748>,
#  '👡': <gensim.models.keyedvectors.Vocab at 0x1a2c324780>,
#  '👖': <gensim.models.keyedvectors.Vocab at 0x1a2c3247b8>,
#  '👜': <gensim.models.keyedvectors.Vocab at 0x1a2c3247f0>,
#  '🎞': <gensim.models.keyedvectors.Vocab at 0x1a2c324828>,
#  '♻': <gensim.models.keyedvectors.Vocab at 0x1a2c324860>,
#  '😓': <gensim.models.keyedvectors.Vocab at 0x1a2c324898>,
#  '📣': <gensim.models.keyedvectors.Vocab at 0x1a2c3248d0>,
#  '✴': <gensim.models.keyedvectors.Vocab at 0x1a2c324908>,
#  '🐭': <gensim.models.keyedvectors.Vocab at 0x1a2c324940>,
#  '🚧': <gensim.models.keyedvectors.Vocab at 0x1a2c324978>,
#  '♏': <gensim.models.keyedvectors.Vocab at 0x1a2c3249b0>,
#  '🆖': <gensim.models.keyedvectors.Vocab at 0x1a2c3249e8>,
#  '💩': <gensim.models.keyedvectors.Vocab at 0x1a2c324a20>,
#  '🍍': <gensim.models.keyedvectors.Vocab at 0x1a2c324a58>,
#  '🚁': <gensim.models.keyedvectors.Vocab at 0x1a2c324a90>,
#  '🌘': <gensim.models.keyedvectors.Vocab at 0x1a2c324ac8>,
#  '🍛': <gensim.models.keyedvectors.Vocab at 0x1a2c324b00>,
#  '🎅': <gensim.models.keyedvectors.Vocab at 0x1a2c324b38>,
#  '🚿': <gensim.models.keyedvectors.Vocab at 0x1a2c324b70>,
#  '🚐': <gensim.models.keyedvectors.Vocab at 0x1a2c324ba8>,
#  '🎌': <gensim.models.keyedvectors.Vocab at 0x1a2c324be0>,
#  '🎣': <gensim.models.keyedvectors.Vocab at 0x1a2c324c18>,
#  '♿': <gensim.models.keyedvectors.Vocab at 0x1a2c324c50>,
#  '🌵': <gensim.models.keyedvectors.Vocab at 0x1a2c324c88>,
#  '✒': <gensim.models.keyedvectors.Vocab at 0x1a2c324cc0>,
#  '📂': <gensim.models.keyedvectors.Vocab at 0x1a2c324cf8>,
#  '🔒': <gensim.models.keyedvectors.Vocab at 0x1a2c324d30>,
#  '👬': <gensim.models.keyedvectors.Vocab at 0x1a2c324d68>,
#  '📦': <gensim.models.keyedvectors.Vocab at 0x1a2c324da0>,
#  '🏚': <gensim.models.keyedvectors.Vocab at 0x1a2c324dd8>,
#  '✈': <gensim.models.keyedvectors.Vocab at 0x1a2c324e10>,
#  '🐓': <gensim.models.keyedvectors.Vocab at 0x1a2c324e48>,
#  '🛁': <gensim.models.keyedvectors.Vocab at 0x1a2c324e80>,
#  '▪': <gensim.models.keyedvectors.Vocab at 0x1a2c324eb8>,
#  '➖': <gensim.models.keyedvectors.Vocab at 0x1a2c324ef0>,
#  '⛴': <gensim.models.keyedvectors.Vocab at 0x1a2c324f28>,
#  '🍢': <gensim.models.keyedvectors.Vocab at 0x1a2c324f60>,
#  '🐮': <gensim.models.keyedvectors.Vocab at 0x1a2c324f98>,
#  '♌': <gensim.models.keyedvectors.Vocab at 0x1a2c324fd0>,
#  '🧟': <gensim.models.keyedvectors.Vocab at 0x1a2c327048>,
#  '🤬': <gensim.models.keyedvectors.Vocab at 0x1a2c327080>,
#  '💳': <gensim.models.keyedvectors.Vocab at 0x1a2c3270b8>,
#  '📊': <gensim.models.keyedvectors.Vocab at 0x1a2c3270f0>,
#  '🕉': <gensim.models.keyedvectors.Vocab at 0x1a2c327128>,
#  '🧘': <gensim.models.keyedvectors.Vocab at 0x1a2c327160>,
#  '🐩': <gensim.models.keyedvectors.Vocab at 0x1a2c327198>,
#  '💴': <gensim.models.keyedvectors.Vocab at 0x1a2c3271d0>,
#  '▫': <gensim.models.keyedvectors.Vocab at 0x1a2c327208>,
#  '📙': <gensim.models.keyedvectors.Vocab at 0x1a2c327240>,
#  '📓': <gensim.models.keyedvectors.Vocab at 0x1a2c327278>,
#  '🛅': <gensim.models.keyedvectors.Vocab at 0x1a2c3272b0>,
#  '🥋': <gensim.models.keyedvectors.Vocab at 0x1a2c3272e8>,
#  '🎍': <gensim.models.keyedvectors.Vocab at 0x1a2c327320>,
#  '🖥': <gensim.models.keyedvectors.Vocab at 0x1a2c327358>,
#  '🆒': <gensim.models.keyedvectors.Vocab at 0x1a2c327390>,
#  '🦖': <gensim.models.keyedvectors.Vocab at 0x1a2c3273c8>,
#  '🤼': <gensim.models.keyedvectors.Vocab at 0x1a2c327400>,
#  '🐿': <gensim.models.keyedvectors.Vocab at 0x1a2c327438>,
#  '🔭': <gensim.models.keyedvectors.Vocab at 0x1a2c327470>,
#  '🍄': <gensim.models.keyedvectors.Vocab at 0x1a2c3274a8>,
#  '🚾': <gensim.models.keyedvectors.Vocab at 0x1a2c3274e0>,
#  '🛒': <gensim.models.keyedvectors.Vocab at 0x1a2c327518>,
#  '◽': <gensim.models.keyedvectors.Vocab at 0x1a2c327550>,
#  '🔙': <gensim.models.keyedvectors.Vocab at 0x1a2c327588>,
#  '🍶': <gensim.models.keyedvectors.Vocab at 0x1a2c3275c0>,
#  '🔄': <gensim.models.keyedvectors.Vocab at 0x1a2c3275f8>,
#  '✉': <gensim.models.keyedvectors.Vocab at 0x1a2c327630>,
#  '🎐': <gensim.models.keyedvectors.Vocab at 0x1a2c327668>,
#  '🍚': <gensim.models.keyedvectors.Vocab at 0x1a2c3276a0>,
#  '⏳': <gensim.models.keyedvectors.Vocab at 0x1a2c3276d8>,
#  '🆚': <gensim.models.keyedvectors.Vocab at 0x1a2c327710>,
#  '💹': <gensim.models.keyedvectors.Vocab at 0x1a2c327748>,
#  '☪': <gensim.models.keyedvectors.Vocab at 0x1a2c327780>,
#  '🤱': <gensim.models.keyedvectors.Vocab at 0x1a2c3277b8>,
#  '🔦': <gensim.models.keyedvectors.Vocab at 0x1a2c3277f0>,
#  '📎': <gensim.models.keyedvectors.Vocab at 0x1a2c327828>,
#  '☢': <gensim.models.keyedvectors.Vocab at 0x1a2c327860>,
#  '🗼': <gensim.models.keyedvectors.Vocab at 0x1a2c327898>,
#  '👒': <gensim.models.keyedvectors.Vocab at 0x1a2c3278d0>,
#  '♨': <gensim.models.keyedvectors.Vocab at 0x1a2c327908>,
#  '🥘': <gensim.models.keyedvectors.Vocab at 0x1a2c327940>,
#  '👛': <gensim.models.keyedvectors.Vocab at 0x1a2c327978>,
#  '😧': <gensim.models.keyedvectors.Vocab at 0x1a2c3279b0>,
#  '🥝': <gensim.models.keyedvectors.Vocab at 0x1a2c3279e8>,
#  '📔': <gensim.models.keyedvectors.Vocab at 0x1a2c327a20>,
#  '📞': <gensim.models.keyedvectors.Vocab at 0x1a2c327a58>,
#  '🐡': <gensim.models.keyedvectors.Vocab at 0x1a2c327a90>,
#  '😿': <gensim.models.keyedvectors.Vocab at 0x1a2c327ac8>,
#  '🏑': <gensim.models.keyedvectors.Vocab at 0x1a2c327b00>,
#  '◼': <gensim.models.keyedvectors.Vocab at 0x1a2c327b38>,
#  '🍲': <gensim.models.keyedvectors.Vocab at 0x1a2c327b70>,
#  '❇': <gensim.models.keyedvectors.Vocab at 0x1a2c327ba8>,
#  '🌗': <gensim.models.keyedvectors.Vocab at 0x1a2c327be0>,
#  '🌖': <gensim.models.keyedvectors.Vocab at 0x1a2c327c18>,
#  '🙎': <gensim.models.keyedvectors.Vocab at 0x1a2c327c50>,
#  '❎': <gensim.models.keyedvectors.Vocab at 0x1a2c327c88>,
#  '♦': <gensim.models.keyedvectors.Vocab at 0x1a2c327cc0>,
#  '🍵': <gensim.models.keyedvectors.Vocab at 0x1a2c327cf8>,
#  '⛰': <gensim.models.keyedvectors.Vocab at 0x1a2c327d30>,
#  '🇶': <gensim.models.keyedvectors.Vocab at 0x1a2c327d68>,
#  '🐒': <gensim.models.keyedvectors.Vocab at 0x1a2c327da0>,
#  '⚒': <gensim.models.keyedvectors.Vocab at 0x1a2c327dd8>,
#  '🌫': <gensim.models.keyedvectors.Vocab at 0x1a2c327e10>,
#  '🥣': <gensim.models.keyedvectors.Vocab at 0x1a2c327e48>,
#  '⛅': <gensim.models.keyedvectors.Vocab at 0x1a2c327e80>,
#  '🛬': <gensim.models.keyedvectors.Vocab at 0x1a2c327eb8>,
#  '🥢': <gensim.models.keyedvectors.Vocab at 0x1a2c327ef0>,
#  '🍤': <gensim.models.keyedvectors.Vocab at 0x1a2c327f28>,
#  '📅': <gensim.models.keyedvectors.Vocab at 0x1a2c327f60>,
#  '🇼': <gensim.models.keyedvectors.Vocab at 0x1a2c327f98>,
#  '🎱': <gensim.models.keyedvectors.Vocab at 0x1a2c327fd0>,
#  '🦃': <gensim.models.keyedvectors.Vocab at 0x1a2c32a048>,
#  '🏸': <gensim.models.keyedvectors.Vocab at 0x1a2c32a080>,
#  '🌓': <gensim.models.keyedvectors.Vocab at 0x1a2c32a0b8>,
#  '🏙': <gensim.models.keyedvectors.Vocab at 0x1a2c32a0f0>,
#  '👴': <gensim.models.keyedvectors.Vocab at 0x1a2c32a128>,
#  '🚰': <gensim.models.keyedvectors.Vocab at 0x1a2c32a160>,
#  '🧒': <gensim.models.keyedvectors.Vocab at 0x1a2c32a198>,
#  '🎰': <gensim.models.keyedvectors.Vocab at 0x1a2c32a1d0>,
#  '🔹': <gensim.models.keyedvectors.Vocab at 0x1a2c32a208>,
#  '☁': <gensim.models.keyedvectors.Vocab at 0x1a2c32a240>,
#  '⬆': <gensim.models.keyedvectors.Vocab at 0x1a2c32a278>,
#  '🎃': <gensim.models.keyedvectors.Vocab at 0x1a2c32a2b0>,
#  '📍': <gensim.models.keyedvectors.Vocab at 0x1a2c32a2e8>,
#  '🛰': <gensim.models.keyedvectors.Vocab at 0x1a2c32a320>,
#  '📜': <gensim.models.keyedvectors.Vocab at 0x1a2c32a358>,
#  '⚗': <gensim.models.keyedvectors.Vocab at 0x1a2c32a390>,
#  '🐖': <gensim.models.keyedvectors.Vocab at 0x1a2c32a3c8>,
#  '♊': <gensim.models.keyedvectors.Vocab at 0x1a2c32a400>,
#  '🧔': <gensim.models.keyedvectors.Vocab at 0x1a2c32a438>,
#  '🛵': <gensim.models.keyedvectors.Vocab at 0x1a2c32a470>,
#  '🛏': <gensim.models.keyedvectors.Vocab at 0x1a2c32a4a8>,
#  '🏪': <gensim.models.keyedvectors.Vocab at 0x1a2c32a4e0>,
#  '🚵': <gensim.models.keyedvectors.Vocab at 0x1a2c32a518>,
#  '🦐': <gensim.models.keyedvectors.Vocab at 0x1a2c32a550>,
#  '📒': <gensim.models.keyedvectors.Vocab at 0x1a2c32a588>,
#  '🇻': <gensim.models.keyedvectors.Vocab at 0x1a2c32a5c0>,
#  '☑': <gensim.models.keyedvectors.Vocab at 0x1a2c32a5f8>,
#  '🖼': <gensim.models.keyedvectors.Vocab at 0x1a2c32a630>,
#  '🎽': <gensim.models.keyedvectors.Vocab at 0x1a2c32a668>,
#  '👝': <gensim.models.keyedvectors.Vocab at 0x1a2c32a6a0>,
#  '🐜': <gensim.models.keyedvectors.Vocab at 0x1a2c32a6d8>,
#  '📼': <gensim.models.keyedvectors.Vocab at 0x1a2c32a710>,
#  '🎗': <gensim.models.keyedvectors.Vocab at 0x1a2c32a748>,
#  '🔓': <gensim.models.keyedvectors.Vocab at 0x1a2c32a780>,
#  '🅾': <gensim.models.keyedvectors.Vocab at 0x1a2c32a7b8>,
#  '🅱': <gensim.models.keyedvectors.Vocab at 0x1a2c32a7f0>,
#  '⌨': <gensim.models.keyedvectors.Vocab at 0x1a2c32a828>,
#  '🕰': <gensim.models.keyedvectors.Vocab at 0x1a2c32a860>,
#  '🐏': <gensim.models.keyedvectors.Vocab at 0x1a2c32a898>,
#  '🛩': <gensim.models.keyedvectors.Vocab at 0x1a2c32a8d0>,
#  '🌒': <gensim.models.keyedvectors.Vocab at 0x1a2c32a908>,
#  '🧗': <gensim.models.keyedvectors.Vocab at 0x1a2c32a940>,
#  '🐆': <gensim.models.keyedvectors.Vocab at 0x1a2c32a978>,
#  '🛳': <gensim.models.keyedvectors.Vocab at 0x1a2c32a9b0>,
#  '🍈': <gensim.models.keyedvectors.Vocab at 0x1a2c32a9e8>,
#  '🛌': <gensim.models.keyedvectors.Vocab at 0x1a2c32aa20>,
#  '👪': <gensim.models.keyedvectors.Vocab at 0x1a2c32aa58>,
#  '🏵': <gensim.models.keyedvectors.Vocab at 0x1a2c32aa90>,
#  '🖋': <gensim.models.keyedvectors.Vocab at 0x1a2c32aac8>,
#  '🗑': <gensim.models.keyedvectors.Vocab at 0x1a2c32ab00>,
#  '🐲': <gensim.models.keyedvectors.Vocab at 0x1a2c32ab38>,
#  '⛱': <gensim.models.keyedvectors.Vocab at 0x1a2c32ab70>,
#  '🛋': <gensim.models.keyedvectors.Vocab at 0x1a2c32aba8>,
#  '🆎': <gensim.models.keyedvectors.Vocab at 0x1a2c32abe0>,
#  '📯': <gensim.models.keyedvectors.Vocab at 0x1a2c32ac18>,
#  '🏷': <gensim.models.keyedvectors.Vocab at 0x1a2c32ac50>,
#  'Ⓜ': <gensim.models.keyedvectors.Vocab at 0x1a2c32ac88>,
#  '🐛': <gensim.models.keyedvectors.Vocab at 0x1a2c32acc0>,
#  '🏂': <gensim.models.keyedvectors.Vocab at 0x1a2c32acf8>,
#  '🕸': <gensim.models.keyedvectors.Vocab at 0x1a2c32ad30>,
#  '🧝': <gensim.models.keyedvectors.Vocab at 0x1a2c32ad68>,
#  '🚜': <gensim.models.keyedvectors.Vocab at 0x1a2c32ada0>,
#  '🚤': <gensim.models.keyedvectors.Vocab at 0x1a2c32add8>,
#  '🛥': <gensim.models.keyedvectors.Vocab at 0x1a2c32ae10>,
#  '🧑': <gensim.models.keyedvectors.Vocab at 0x1a2c32ae48>,
#  '🃏': <gensim.models.keyedvectors.Vocab at 0x1a2c32ae80>,
#  '🚷': <gensim.models.keyedvectors.Vocab at 0x1a2c32aeb8>,
#  '🥑': <gensim.models.keyedvectors.Vocab at 0x1a2c32aef0>,
#  '♋': <gensim.models.keyedvectors.Vocab at 0x1a2c32af28>,
#  '🐁': <gensim.models.keyedvectors.Vocab at 0x1a2c32af60>,
#  '🗺': <gensim.models.keyedvectors.Vocab at 0x1a2c32af98>,
#  '👘': <gensim.models.keyedvectors.Vocab at 0x1a2c32afd0>,
#  '📥': <gensim.models.keyedvectors.Vocab at 0x1a2c32e048>,
#  '🆑': <gensim.models.keyedvectors.Vocab at 0x1a2c32e080>,
#  '➰': <gensim.models.keyedvectors.Vocab at 0x1a2c32e0b8>,
#  '🦓': <gensim.models.keyedvectors.Vocab at 0x1a2c32e0f0>,
#  '💈': <gensim.models.keyedvectors.Vocab at 0x1a2c32e128>,
#  '🖊': <gensim.models.keyedvectors.Vocab at 0x1a2c32e160>,
#  '⛺': <gensim.models.keyedvectors.Vocab at 0x1a2c32e198>,
#  '🐌': <gensim.models.keyedvectors.Vocab at 0x1a2c32e1d0>,
#  '🐫': <gensim.models.keyedvectors.Vocab at 0x1a2c32e208>,
#  '\U000e0077': <gensim.models.keyedvectors.Vocab at 0x1a2c32e240>,
#  '\U000e006c': <gensim.models.keyedvectors.Vocab at 0x1a2c32e278>,
#  '🧤': <gensim.models.keyedvectors.Vocab at 0x1a2c32e2b0>,
#  '🍐': <gensim.models.keyedvectors.Vocab at 0x1a2c32e2e8>,
#  '📩': <gensim.models.keyedvectors.Vocab at 0x1a2c32e320>,
#  '🔃': <gensim.models.keyedvectors.Vocab at 0x1a2c32e358>,
#  '📘': <gensim.models.keyedvectors.Vocab at 0x1a2c32e390>,
#  '🧖': <gensim.models.keyedvectors.Vocab at 0x1a2c32e3c8>,
#  '🌑': <gensim.models.keyedvectors.Vocab at 0x1a2c32e400>,
#  '🤥': <gensim.models.keyedvectors.Vocab at 0x1a2c32e438>,
#  '✳': <gensim.models.keyedvectors.Vocab at 0x1a2c32e470>,
#  '📶': <gensim.models.keyedvectors.Vocab at 0x1a2c32e4a8>,
#  '🌰': <gensim.models.keyedvectors.Vocab at 0x1a2c32e4e0>,
#  '🏧': <gensim.models.keyedvectors.Vocab at 0x1a2c32e518>,
#  '🛤': <gensim.models.keyedvectors.Vocab at 0x1a2c32e550>,
#  '🔧': <gensim.models.keyedvectors.Vocab at 0x1a2c32e588>,
#  '🤹': <gensim.models.keyedvectors.Vocab at 0x1a2c32e5c0>,
#  '📏': <gensim.models.keyedvectors.Vocab at 0x1a2c32e5f8>,
#  '☃': <gensim.models.keyedvectors.Vocab at 0x1a2c32e630>,
#  '⛲': <gensim.models.keyedvectors.Vocab at 0x1a2c32e668>,
#  '⚕': <gensim.models.keyedvectors.Vocab at 0x1a2c32e6a0>,
#  '🀄': <gensim.models.keyedvectors.Vocab at 0x1a2c32e6d8>,
#  '🚽': <gensim.models.keyedvectors.Vocab at 0x1a2c32e710>,
#  '🧓': <gensim.models.keyedvectors.Vocab at 0x1a2c32e748>,
#  '♈': <gensim.models.keyedvectors.Vocab at 0x1a2c32e780>,
#  '🍥': <gensim.models.keyedvectors.Vocab at 0x1a2c32e7b8>,
#  '🦔': <gensim.models.keyedvectors.Vocab at 0x1a2c32e7f0>,
#  '🥙': <gensim.models.keyedvectors.Vocab at 0x1a2c32e828>,
#  '🚅': <gensim.models.keyedvectors.Vocab at 0x1a2c32e860>,
#  '🚋': <gensim.models.keyedvectors.Vocab at 0x1a2c32e898>,
#  '🦂': <gensim.models.keyedvectors.Vocab at 0x1a2c32e8d0>,
#  ...}

# %%
thrones2vec.train(emojiSequences, total_examples=thrones2vec.corpus_count, epochs = 10)
# Out:
# 2019-01-31 17:54:27,053 : INFO : training model with 12 workers on 1082 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=8
# 2019-01-31 17:54:27,352 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-01-31 17:54:27,353 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-01-31 17:54:27,354 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-01-31 17:54:27,355 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-01-31 17:54:27,356 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 17:54:27,356 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 17:54:27,359 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 17:54:27,365 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 17:54:27,366 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 17:54:27,368 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 17:54:27,370 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 17:54:27,371 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 17:54:27,371 : INFO : EPOCH - 1 : training on 610256 raw words (388694 effective words) took 0.3s, 1270616 effective words/s
# 2019-01-31 17:54:27,648 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-01-31 17:54:27,650 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-01-31 17:54:27,655 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-01-31 17:54:27,656 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-01-31 17:54:27,656 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 17:54:27,657 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 17:54:27,658 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 17:54:27,658 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 17:54:27,665 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 17:54:27,667 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 17:54:27,668 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 17:54:27,669 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 17:54:27,669 : INFO : EPOCH - 2 : training on 610256 raw words (388886 effective words) took 0.3s, 1363052 effective words/s
# 2019-01-31 17:54:27,948 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-01-31 17:54:27,954 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-01-31 17:54:27,956 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-01-31 17:54:27,959 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-01-31 17:54:27,967 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 17:54:27,967 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 17:54:27,970 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 17:54:27,975 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 17:54:27,976 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 17:54:27,978 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 17:54:27,980 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 17:54:27,983 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 17:54:27,984 : INFO : EPOCH - 3 : training on 610256 raw words (388737 effective words) took 0.3s, 1282590 effective words/s
# 2019-01-31 17:54:28,251 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-01-31 17:54:28,253 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-01-31 17:54:28,254 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-01-31 17:54:28,258 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-01-31 17:54:28,261 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 17:54:28,263 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 17:54:28,265 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 17:54:28,265 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 17:54:28,267 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 17:54:28,268 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 17:54:28,269 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 17:54:28,271 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 17:54:28,273 : INFO : EPOCH - 4 : training on 610256 raw words (389064 effective words) took 0.3s, 1400290 effective words/s
# 2019-01-31 17:54:28,582 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-01-31 17:54:28,591 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-01-31 17:54:28,594 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-01-31 17:54:28,596 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-01-31 17:54:28,597 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 17:54:28,599 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 17:54:28,601 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 17:54:28,603 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 17:54:28,605 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 17:54:28,609 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 17:54:28,610 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 17:54:28,613 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 17:54:28,614 : INFO : EPOCH - 5 : training on 610256 raw words (388987 effective words) took 0.3s, 1177247 effective words/s
# 2019-01-31 17:54:28,935 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-01-31 17:54:28,936 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-01-31 17:54:28,938 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-01-31 17:54:28,939 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-01-31 17:54:28,945 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 17:54:28,947 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 17:54:28,948 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 17:54:28,949 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 17:54:28,950 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 17:54:28,952 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 17:54:28,953 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 17:54:28,954 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 17:54:28,957 : INFO : EPOCH - 6 : training on 610256 raw words (389395 effective words) took 0.3s, 1210803 effective words/s
# 2019-01-31 17:54:29,253 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-01-31 17:54:29,256 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-01-31 17:54:29,259 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-01-31 17:54:29,260 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-01-31 17:54:29,261 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 17:54:29,261 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 17:54:29,262 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 17:54:29,266 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 17:54:29,267 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 17:54:29,272 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 17:54:29,274 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 17:54:29,276 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 17:54:29,277 : INFO : EPOCH - 7 : training on 610256 raw words (389159 effective words) took 0.3s, 1261915 effective words/s
# 2019-01-31 17:54:29,615 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-01-31 17:54:29,621 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-01-31 17:54:29,624 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-01-31 17:54:29,625 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-01-31 17:54:29,627 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 17:54:29,628 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 17:54:29,629 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 17:54:29,630 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 17:54:29,631 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 17:54:29,641 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 17:54:29,643 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 17:54:29,644 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 17:54:29,645 : INFO : EPOCH - 8 : training on 610256 raw words (388761 effective words) took 0.4s, 1088319 effective words/s
# 2019-01-31 17:54:29,936 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-01-31 17:54:29,941 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-01-31 17:54:29,942 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-01-31 17:54:29,942 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-01-31 17:54:29,945 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 17:54:29,948 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 17:54:29,948 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 17:54:29,949 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 17:54:29,953 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 17:54:29,956 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 17:54:29,958 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 17:54:29,958 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 17:54:29,960 : INFO : EPOCH - 9 : training on 610256 raw words (389059 effective words) took 0.3s, 1283744 effective words/s
# 2019-01-31 17:54:30,249 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-01-31 17:54:30,252 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-01-31 17:54:30,253 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-01-31 17:54:30,253 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-01-31 17:54:30,254 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 17:54:30,255 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 17:54:30,260 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 17:54:30,261 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 17:54:30,262 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 17:54:30,264 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 17:54:30,267 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 17:54:30,268 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 17:54:30,268 : INFO : EPOCH - 10 : training on 610256 raw words (388399 effective words) took 0.3s, 1317648 effective words/s
# 2019-01-31 17:54:30,269 : INFO : training on a 6102560 raw words (3889141 effective words) took 3.2s, 1209613 effective words/s
# (3889141, 6102560)

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
thrones2vec.save(os.path.join("trained", "123.w2v"))
# Out:
# 2019-01-31 17:54:30,282 : INFO : saving Word2Vec object under trained/123.w2v, separately None
# 2019-01-31 17:54:30,284 : INFO : not storing attribute vectors_norm
# 2019-01-31 17:54:30,284 : INFO : not storing attribute cum_table
# 2019-01-31 17:54:30,309 : INFO : saved trained/123.w2v

# %% [markdown]
# # explore the trained model

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "123.w2v"))
# Out:
# 2019-01-31 17:54:30,315 : INFO : loading Word2Vec object from trained/123.w2v
# 2019-01-31 17:54:30,335 : INFO : loading wv recursively from trained/123.w2v.wv.* with mmap=None
# 2019-01-31 17:54:30,336 : INFO : setting ignored attribute vectors_norm to None
# 2019-01-31 17:54:30,337 : INFO : loading vocabulary recursively from trained/123.w2v.vocabulary.* with mmap=None
# 2019-01-31 17:54:30,338 : INFO : loading trainables recursively from trained/123.w2v.trainables.* with mmap=None
# 2019-01-31 17:54:30,339 : INFO : setting ignored attribute cum_table to None
# 2019-01-31 17:54:30,340 : INFO : loaded trained/123.w2v

# %%
vector1 = thrones2vec.wv['😳']

# %%
vector2 = thrones2vec.wv['😍']

# %%
vector3 = thrones2vec.wv['❤️']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-bc8e46fa6474> in <module>
# ----> 1 vector3 = thrones2vec.wv['❤️']
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     167         if isinstance(entities, string_types):
#     168             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 169             return self.get_vector(entities)
#     170
#     171         return vstack([self.get_vector(entity) for entity in entities])
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     275
#     276     def get_vector(self, word):
# --> 277         return self.word_vec(word)
#     278
#     279     def words_closer_than(self, w1, w2):
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     272             return result
#     273         else:
# --> 274             raise KeyError("word '%s' not in vocabulary" % word)
#     275
#     276     def get_vector(self, word):
#
# KeyError: "word '❤️' not in vocabulary"

# %%
thrones2vec.wv.similarity('🎶', '💜')

# %%
thrones2vec.wv.vocab

# %%
thrones2vec.wv.most_similar('😍')

# %%
# extracts the 508 Annotator Results as the Gold-Standard
corpus_filename = '../data/EmoSim508.json'
corpus = open(corpus_filename).read()
annotator_similarity_score_508 = list(array(re.findall('(?<=_Annotator_Agreement": )(.*?)(?=\})', corpus)))

# glyph_pairs_1016
unicode_pairs_1016 = re.findall('(?<=unicodelong": "\\\)(.*?)(?=")', corpus)    
glyph_pairs_1016 = [codecs.decode(unicode_pairs_1016[x].replace(str('\\\\'),str('\\')).replace('_',''), 'unicode_escape') for x in range(len(unicode_pairs_1016))]

# fdfdsfaf
goldstandard = []
selftrained = []
for x in range(len(annotator_similarity_score_508)):
    cosineSimilarity = None
    
    emoji1 = glyph_pairs_1016.pop(0)
    emoji2 = glyph_pairs_1016.pop(0)
    
    try:
        cosineSimilarity = thrones2vec.wv.similarity(emoji1, emoji2)
    except:
        print('the cosine similarity between ' + emoji1 + ' and ' + emoji2 + ' could not be computed.')
    
    if(cosineSimilarity is not None):
        goldstandard.append(cosineSimilarity)
        selftrained.append(annotator_similarity_score_508.pop(0))
print(len(goldstandard))
print(len(selftrained))

spearmanRank = stats.spearmanr(goldstandard, selftrained)

print('Der Spearman Rank Correlation Coefficient is {}'.format(spearmanRank))
# Out:
# the cosine similarity between 🇬🇧 and 🇺🇸 could not be computed.
# the cosine similarity between 🏅 and 🇺🇸 could not be computed.
# the cosine similarity between 🇺🇸 and ❤ could not be computed.
# the cosine similarity between 🇺🇸 and 💥 could not be computed.
# the cosine similarity between 🎤 and 🇳🇬 could not be computed.
# the cosine similarity between 🇳🇬 and 📲 could not be computed.
# the cosine similarity between 👇 and 🇳🇬 could not be computed.
# the cosine similarity between 🎧 and 🇳🇬 could not be computed.
# the cosine similarity between 🇳🇬 and 🎶 could not be computed.
# the cosine similarity between 👏 and ↪ could not be computed.
# 498
# 498
# Der Spearman Rank Correlation Coefficient is SpearmanrResult(correlation=0.5670391172266186, pvalue=1.041390648609959e-43)
# /Users/smoky/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
goldstandard
# Out:
# [0.4554447095126947,
#  0.4653041509014776,
#  0.5107784652063863,
#  0.307404959982498,
#  0.3874710917320384,
#  0.3757104390832654,
#  0.4052640782098556,
#  0.3191670239683293,
#  0.36933443032082014,
#  0.36306718720597575,
#  0.43314122841582725,
#  0.37948764192162526,
#  0.3716206850232139,
#  0.4136558156538691,
#  0.3791055459433768,
#  0.3099475646183907,
#  0.32991150260512286,
#  0.43136173991732435,
#  0.42690563233602097,
#  0.4101891074174304,
#  0.3012748692703059,
#  0.30987919067804054,
#  0.411032381012099,
#  0.42132665401025327,
#  0.42909041896442623,
#  0.43456883626219506,
#  0.3507494695908241,
#  0.313012528879552,
#  0.6577179271348694,
#  0.3889187932826977,
#  0.5308508521317129,
#  0.33636026413096565,
#  0.26191562192416284,
#  0.45560631603169277,
#  0.3517402292445291,
#  0.45433971786156535,
#  0.49497135563967853,
#  0.267301625897338,
#  0.3724153912113354,
#  0.3175736077920138,
#  0.5178149073319843,
#  0.3209088824335746,
#  0.3777583194131311,
#  0.5494227158412353,
#  0.30169784551682644,
#  0.47024557554620705,
#  0.3701903890205816,
#  0.37322302998299006,
#  0.3974654754333846,
#  0.3975064959344878,
#  0.2791474258176387,
#  0.2582468134032271,
#  0.3587013636872797,
#  0.43885395453089837,
#  0.4095663226411618,
#  0.5060844179657348,
#  0.47178228327876204,
#  0.3391389433711423,
#  0.4470784907990896,
#  0.34031046735413817,
#  0.37763689011847845,
#  0.4735329227025415,
#  0.4309652317446023,
#  0.2527736244806209,
#  0.4186644282812789,
#  0.2686338313985242,
#  0.3681928438129654,
#  0.3788654258941567,
#  0.17386529100228978,
#  0.3231033855404124,
#  0.44781775807857505,
#  0.43662218754163507,
#  0.44172177338735785,
#  0.3702984247269826,
#  0.4014780450138974,
#  0.34604486760379377,
#  0.5414834720000715,
#  0.2721966485706605,
#  0.5130035475055813,
#  0.30557645626895613,
#  0.4426441720182952,
#  0.2588466292041268,
#  0.1517987310096074,
#  0.4411164718833823,
#  0.24055264919268188,
#  0.33814545448424904,
#  0.2559880833663187,
#  0.2848912510409015,
#  0.38341332763406966,
#  0.40401484080963945,
#  0.3115920880149827,
#  0.39073623440510086,
#  0.4635990129962128,
#  0.2887633129412132,
#  0.4025787880463928,
#  0.3448761331911666,
#  0.34383870055885063,
#  0.353532593427453,
#  0.26928034623901287,
#  0.2736719591993738,
#  0.2814405399721306,
#  0.41565080902210017,
#  0.7160963092156414,
#  0.34564170762302454,
#  0.2813194238281151,
#  0.32383924109613316,
#  0.6239302534819444,
#  0.3410013660842969,
#  0.5612748682193694,
#  0.5312373812761264,
#  0.3659489767438932,
#  0.3942165198143558,
#  0.37595664021935815,
#  0.23581039229332326,
#  0.3376360708469711,
#  0.25017510477393307,
#  0.26193336824668967,
#  0.3533975465054587,
#  0.32847751087300553,
#  0.3375300643056346,
#  0.5003078376417229,
#  0.5215526858021349,
#  0.30551468984437036,
#  0.31638751657748543,
#  0.2511958355536657,
#  0.25053903250811643,
#  0.35689646827014565,
#  0.3932506244634151,
#  0.21434232600425723,
#  0.22719015770633433,
#  0.2312581196021123,
#  0.20996111663438305,
#  0.30244786981083027,
#  0.3580107247509038,
#  0.19217167911520672,
#  0.28588471202455396,
#  0.29110590847447826,
#  0.2636490949709854,
#  0.2834135302033059,
#  0.36374528407257584,
#  0.2667793086024751,
#  0.33996440663118216,
#  0.35134856383219654,
#  0.3183027388616446,
#  0.29139526922588876,
#  0.4786669867142779,
#  0.30262564985728724,
#  0.32086553557520575,
#  0.2439755871086021,
#  0.25626162176477796,
#  0.3235246789960603,
#  0.3059351952537265,
#  0.3859068306136311,
#  0.3096404843399685,
#  0.22334203727036978,
#  0.47676874754504434,
#  0.2885746752281855,
#  0.3551893636669206,
#  0.1522069163758053,
#  0.3000367905561178,
#  0.2535091401632842,
#  0.23937940137619104,
#  0.40729668488532256,
#  0.28369811485128066,
#  0.09161176573052435,
#  0.38531199667286326,
#  0.32598114953681756,
#  0.3630606296040654,
#  0.2053484089275588,
#  0.24357546717768697,
#  0.44355577015629305,
#  0.3530694519201002,
#  0.28192689396127724,
#  0.30360457317247935,
#  0.2204310029800344,
#  0.3417521398904812,
#  0.3863350440032557,
#  0.3380662063071179,
#  0.29933142504328425,
#  0.5297003925615735,
#  0.2019643903572626,
#  0.26926479954893934,
#  0.27656395492744046,
#  0.27537333908232475,
#  0.41594761123415114,
#  0.3602821992364151,
#  0.23018814299293677,
#  0.3067903725537605,
#  0.2507117741606176,
#  0.3410873590434954,
#  0.28746212541361676,
#  0.36459687387248974,
#  0.3291710048881539,
#  0.42874668202385247,
#  0.16659959054386816,
#  0.2789476654362344,
#  0.20159680842055683,
#  0.3136971213657084,
#  0.11577281635741421,
#  0.3883347708214948,
#  0.4720926724960746,
#  0.24008874016296158,
#  0.17233902201155535,
#  0.32921775152719324,
#  0.19332319089470895,
#  0.19838495718947613,
#  0.2281902187208749,
#  0.2829539009717216,
#  0.22985480570806915,
#  0.314600488391873,
#  0.2633941386727986,
#  0.2551761349424104,
#  0.28958398975843647,
#  0.30578693409448165,
#  0.34423214825687376,
#  0.2721642898620964,
#  0.20394776914788904,
#  0.3103290332164227,
#  0.27208064980208946,
#  0.28586011805596734,
#  0.40991428129612506,
#  0.3802961926330728,
#  0.22066234567940426,
#  0.17582465386566987,
#  0.28837324544084875,
#  0.24852478234093686,
#  0.1728518383887554,
#  0.31937841013885543,
#  0.1493202337918573,
#  0.17581173388061266,
#  0.21828568828376801,
#  0.42132569777678897,
#  0.2709839392500923,
#  0.3948130282640425,
#  0.12595303577620695,
#  0.261027798059553,
#  0.31444611482730056,
#  0.3975813022502613,
#  0.12472264621471046,
#  0.3807548390920348,
#  0.2284993929351104,
#  0.2092778526987581,
#  0.321526833154232,
#  0.3381541630033681,
#  0.2229693080181747,
#  0.24101499525077297,
#  0.3972369682703077,
#  0.15032721020022283,
#  0.2929258157377208,
#  0.10398384453387513,
#  0.20384850455573728,
#  0.20560403098100924,
#  0.28411345816451306,
#  0.2600979824636367,
#  0.29869699142081935,
#  0.29383289950703095,
#  0.3616723200732328,
#  0.19849744628101307,
#  0.1370753845317042,
#  0.2807008301093958,
#  0.21738758868549532,
#  0.429669532123991,
#  0.35663163046029855,
#  0.2257750247090451,
#  0.5101554070969208,
#  0.40441005201724234,
#  0.5300404037816335,
#  0.29683962303233585,
#  0.14072441778772776,
#  0.22267399698110543,
#  0.2504411174083661,
#  0.3192007749653871,
#  0.3392267614954212,
#  0.28645409372183245,
#  0.2533795649878544,
#  0.2260538255871907,
#  0.30251131871532166,
#  0.26829386759495416,
#  0.36628785275293424,
#  0.21390424017814996,
#  0.27562101572296765,
#  0.26874780408828614,
#  0.19207078432164207,
#  0.31402956036740715,
#  0.38241216412304013,
#  0.4110284161498199,
#  0.38352042757979915,
#  0.221249302065402,
#  0.34603548208334733,
#  0.13626537785660753,
#  0.2076251031042654,
#  0.27846533024929265,
#  0.2792687495387991,
#  0.4539286115525734,
#  0.30718654222508013,
#  0.2578814924881306,
#  0.30773612042256904,
#  0.30307802810958934,
#  0.3821947902772105,
#  0.2931511370598412,
#  0.3084014612438161,
#  0.27508996751787623,
#  0.3228606182040647,
#  0.5109814190453714,
#  0.310784599609051,
#  0.44773468241955494,
#  0.4764947640723235,
#  0.3479999225546821,
#  0.45995244091497445,
#  0.175423518822708,
#  0.3008278139775725,
#  0.41593145152640354,
#  0.22278360845103967,
#  0.17643073554232194,
#  0.22920608734490316,
#  0.17108528352334648,
#  0.29583041938586513,
#  0.34741864355135177,
#  0.31351798399291064,
#  0.5814403122456835,
#  0.27431010120325605,
#  0.21495942006359509,
#  0.26328868526649174,
#  0.2129478711305175,
#  0.2312336982978189,
#  0.4143406411399023,
#  0.3691188117762697,
#  0.6275787957088048,
#  0.14972249710109226,
#  0.351859789085994,
#  0.2772047599408762,
#  0.1366376336013463,
#  0.07271294376859795,
#  0.4448334512772557,
#  0.2834418231218027,
#  0.18918320320609722,
#  0.06561167812076679,
#  0.16566937023015027,
#  0.3699691669566021,
#  0.3279206292168869,
#  0.3170818539153464,
#  0.19811597724056668,
#  0.3005848982446865,
#  0.2656346723809867,
#  0.2713292269345284,
#  0.1663596608624241,
#  0.2950398351647124,
#  0.2579831683346216,
#  0.25280151367520803,
#  0.2737868430729748,
#  0.060348780947860774,
#  0.1520677411633629,
#  0.20026188332110811,
#  0.3437867421418054,
#  0.32956115105165223,
#  0.15319159937051585,
#  0.1320173661589891,
#  0.206790986310127,
#  0.2594386694767627,
#  0.19693818123635412,
#  0.2946129674392446,
#  0.15301696077212196,
#  0.2164612465788944,
#  0.23121922874249717,
#  0.27750867888808106,
#  0.24684350924173837,
#  0.30781313086902423,
#  0.3042878170268889,
#  0.29786840961378125,
#  0.15937819188319044,
#  0.09136353251216345,
#  0.22649089456127522,
#  0.1737610508224502,
#  0.17234222862063786,
#  0.3405984310820183,
#  0.2642730463433695,
#  0.1940295666877077,
#  0.23315019229249545,
#  0.19077476946687327,
#  0.3132725285905972,
#  0.26393767221327546,
#  0.3916714243697735,
#  0.22897677128779947,
#  0.22693584485844676,
#  0.4270573072105931,
#  0.20836889294957434,
#  0.09180842063372341,
#  0.16130700722538216,
#  0.25871817018439197,
#  0.300082070249906,
#  0.1892365191764706,
#  0.33819062105508585,
#  0.48698266749274294,
#  0.21854064866246883,
#  0.21406614305532304,
#  0.29454558111380713,
#  0.4021170198096634,
#  0.21994013514923516,
#  0.21013534722862812,
#  0.5289426188585696,
#  0.33443990569064286,
#  0.25097697502937943,
#  0.28635003650261415,
#  0.31298405337221563,
#  0.33284963190396843,
#  0.3391957858466006,
#  0.07114573715369182,
#  0.29153270107886425,
#  0.3173783172163973,
#  0.27168623174893136,
#  0.18215265907609812,
#  0.08814810507671877,
#  0.28651008906562664,
#  0.2831496913585385,
#  0.33287649398263747,
#  0.10192493626054963,
#  0.21953363919612356,
#  0.24052147828325515,
#  0.12607268077879052,
#  0.28077579419498255,
#  0.27394403684412316,
#  0.21996363518474443,
#  0.09766397565526208,
#  0.143847278436665,
#  0.2519070257909249,
#  0.13296468061528782,
#  0.13259015875009703,
#  0.2893521904091909,
#  0.10940781619097126,
#  0.25805804525510745,
#  0.14422792999040163,
#  0.16596085942182992,
#  0.25318881085193773,
#  0.35711161742921227,
#  0.2114330770738197,
#  0.2649329178050135,
#  0.13431359034596488,
#  0.16560318953711048,
#  0.2558495704634161,
#  0.23045473066271782,
#  0.18727277591663302,
#  0.10376791262219537,
#  0.07412584055159836,
#  0.24669913477550115,
#  0.26835243600754266,
#  0.21943115606819508,
#  0.2126911419982272,
#  0.24208837129484795,
#  0.01903652213263263,
#  0.11415783362712159,
#  0.2390346535476828,
#  0.14569617818123543,
#  0.1895270987665721,
#  0.18426029482894868,
#  0.08516200944672002,
#  0.2681154573647828,
#  0.21256286494719367,
#  0.1947986238819211,
#  0.19422845247072607,
#  0.23073113507129417,
#  0.19399020416565635,
#  0.08927928678262533,
#  0.27003465124660975,
#  0.1363166910598018,
#  0.1483005880667012,
#  0.2604775665496721,
#  0.04927762321587387,
#  0.24916880727682775,
#  0.2744032009823997,
#  0.18157359704502965,
#  -0.0034555099867141087,
#  0.2711505776164722,
#  0.08716652023815152,
#  0.05510063435071074,
#  0.24736157979647327,
#  0.11304373693405133,
#  0.271232385404244,
#  0.11305573553527459,
#  0.2855444726269111,
#  0.17164610014604148,
#  0.2815667917979104,
#  0.16473000645840843,
#  0.24490619494473465,
#  0.19827547333613962,
#  0.13748611212196316,
#  0.26882904464643953,
#  0.31205562220113253,
#  -0.0823672403565198,
#  0.19957619441401678,
#  0.26492610732435085,
#  0.1402211712637732,
#  0.1323354677496388,
#  0.0713685584410898,
#  0.03939559910135747,
#  0.11879459968475697,
#  0.16636937049323888,
#  0.28216730926520617,
#  0.16970381367181103]
